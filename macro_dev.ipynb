# %% [markdown]
# # How does the distribution of featuresn evolve due to repeated effect of substitutions?

# %% [markdown]
# ## Load and prep

# %%
# Duration of a timebag, in days
timebag_size = 1.0
# Type of exclusion from previous timebags
exclusion_type = 'no'
# Minimum number of days a cluster must have to be included in the analysis
min_days = 0
# Maximum number of days a cluster must have to be included in the analysis
max_days = 80
# Clusters filtering type to use
filtering_type = 'filtered'

file_postfix = ('_F{filtering_type}_R{min_days}-{max_days}_D{timebag_size}_'
                'E{exclusion_type}').format(filtering_type=filtering_type,
                                            min_days=min_days, max_days=max_days,
                                            timebag_size=timebag_size, exclusion_type=exclusion_type)

# %%
# First some imports
import textwrap

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

import settings as st
from linguistics.treetagger import get_tagger
from linguistics.wn import lemmatize as relemmatize
from linguistics.distance import levenshtein
from datainterface.redistools import RedisReader
import datainterface.picklesaver as ps
from util.generic import ProgressInfo, is_int
tagger = get_tagger()

# %%
# Load the clusters, the features, and initialize the results
clusters = RedisReader(st.__getattribute__('redis_mt_clusters_{}_pref'.format(filtering_type)))
features = dict((fsrc, dict((ftype, ps.load(fdetails['file'].format('all')))
                            for ftype, fdetails in fsrc_details.iteritems()))
                for fsrc, fsrc_details in st.mt_analysis_features.iteritems())
macro_features = dict((fsrc, dict((ftype, [])
                                  for ftype in fsrc_values.iterkeys()))
                      for fsrc, fsrc_values in features.iteritems())

# %%
from linguistics.distance import hamming_word, is_same_ending_us_uk_spelling

def is_in_sphere(ref_strings, string):
    """Test if `string` is in the sphere around `refstrings`.
    
    All strings are first lemmatized, morphy-relammatized, and
    any distance-1 found between strings are discarded if the two
    words differ by only a levenshtein distance of 1.
    
    Returns
    -------
    bool
        Whether or not `string` in in the sphere.
    set
        The `(string, position)` tuples of origins found for `string`
        in `ref_strings`.
    
    """
    
    in_sphere = False
    origins = set([])
    
    # Lemmatize BEFORE hamming
    string_tokens = tagger.Tokenize(string)
    string_lems = [relemmatize(lem) for lem in tagger.Lemmatize(string)]
    for ref_string in ref_strings:
        ref_string_tokens = tagger.Tokenize(ref_string)
        ref_string_lems = [relemmatize(ref_lem) for ref_lem in tagger.Lemmatize(ref_string)]
        
        # Hamming distance (=subs detect)
        if len(string_lems) != len(ref_string_lems):
            continue
        diff = np.where([w1 != w2 for w1, w2 in zip(ref_string_lems, string_lems)])[0]
        if len(diff) != 1:
            continue
        
        # Check this difference is not trivial (=test_real)
        w1, w2 = ref_string_tokens[diff], string_tokens[diff]
        l1, l2 = ref_string_lems[diff], string_lems[diff]
        # '21st'/'twenty-first', etc.
        if is_int(w1[0]) or is_int(w2[0]) or is_int(l1[0]) or is_int(l2[0]):
            continue
        # 'sen'/'senator', 'gov'/'governor', 'nov'/'november', etc.
        if w1 == w2[:3] or w2 == w1[:3] or l1 == l2[:3] or l2 == l1[:3]:
            continue
        # 'center'/'centre', etc
        if is_same_ending_us_uk_spelling(w1, w2):
            continue
        if is_same_ending_us_uk_spelling(l1, l2):
            continue
        if levenshtein(w1, w2) <= 1:
            continue
        if levenshtein(l1, l2) <= 1:
            continue
        
        in_sphere = True
        origins.add((ref_string, diff[0]))
    
    return in_sphere, origins


def novelty(tbg, ref_strings, excl_strings):
    """List the relemmatized words (once per occurrence) appearing in `tbg`,
    in the sphere around `ref_strings`, excluding strings in `excl_strings`.
    
    Strings are lemmatized and morphy-relammatized before computing distance,
    and the returned words are the lemmas.
    
    Parameters
    ----------
    tbg : TimeBag
        The timebag to work on.
    ref_strings : list of strings
        The reference string from which to compute distance; if None, then ignored.
    excl_strings : list of strings
        The reference string from which to exclude; if None, then ignored.
    
    Returns
    -------
    list
        The list of relemmatized words.
    set
        The set of new strings considered to the product of this iteration.
    dict
        The `destination, set of origins` dict of transitions between strings.
    
    """
    
    filtered_relems = []
    new_strings = set([])
    transitions = {}

    for string, freq in zip(tbg.strings, tbg.tot_freqs):
        # If our current string is in the set of banned strings,
        # jump to next one
        if excl_strings is not None and string in excl_strings:
            continue
        
        # If our current string is not in the sphere around ref_strings,
        # jump to next one
        if ref_strings is not None:
            in_sphere, origins = is_in_sphere(ref_strings, string)
            if not in_sphere:
                continue
        else:
            origins = set([])
        
        transitions[string] = origins
        new_strings.add(string)
        relems = [relemmatize(lem) for lem in tagger.Lemmatize(string)]
        filtered_relems.extend(relems * freq)

    return filtered_relems, new_strings, transitions

# %%
from IPython.utils import coloransi
tc = coloransi.TermColors()

def red(s):
    return tc.Red + s + tc.Normal

def blue(s):
    return tc.Blue + s + tc.Normal

def green(s):
    return tc.Green + s + tc.Normal

def black(s):
    return tc.Black + s + tc.Normal

# %% [markdown]
# ## Mining

# %%
class Excluder(object):
    
    def __init__(self):
        self.prevtbg = None
        self.prevall_strings = None

    def _exclusion_no(self):
        return None
    
    def _exclusion_prevall(self):
        if self.prevall_strings is not None:
            # Copy since we modify the prevall_strings in _update
            return self.prevall_strings.copy()
        else:
            return None
    
    def _exclusion_prevtbg(self):
        if self.prevtbg is not None:
            return self.prevtbg.strings
        else:
            return None
    
    def _update(self, tbg):
        self.prevtbg = tbg
        try:
            self.prevall_strings.update(tbg.strings)
        except AttributeError:
            self.prevall_strings = set(tbg.strings)

    def __call__(self, tbg):
        ret = self.__getattribute__('_exclusion_' + exclusion_type)()
        self._update(tbg)
        return ret

# %%
try:
    #raise IOError
    # See if we already computed this
    macro_features = ps.load('data/MemeTracker/macro/macro_features{}.pickle'.format(file_postfix))
    clusters_log = ps.load('data/MemeTracker/macro/clusters_log{}.pickle'.format(file_postfix))
    print 'Loaded from pickle.'
except IOError:
    n_clusters_kept = 0
    clusters_log = []
    progress = ProgressInfo(len(clusters), 10, 'clusters')
    
    for c in clusters.itervalues():
        progress.next_step()
        
        # Skip if out of min-max
        c.build_timeline()
        if c.timeline.span_days > max_days or c.timeline.span_days < min_days:
            continue
        n_clusters_kept += 1
        
        cluster_log = (c, [])
        should_log = False
        excluder = Excluder()
        tbgs = c.build_timebags(timebag_size)
        for i, tbg in enumerate(tbgs):
            # Substitutions
            relems, new_strings, transitions = novelty(tbg, None if i == 0 else new_strings, excluder(tbg))
            
            # Features
            for fsrc, fsrc_values in features.iteritems():
                for ftype, feature in fsrc_values.iteritems():
            
                    # Get the feature values for the extracted words
                    macro_features_tbg_this_cluster = [feature[relem] for relem in relems if relem in feature]
                    try:
                        # Either add it to the existing list
                        macro_features[fsrc][ftype][i].extend(macro_features_tbg_this_cluster)
                    except IndexError:
                        # Or create the list for this timebag if necessary
                        macro_features[fsrc][ftype].append(macro_features_tbg_this_cluster)
                        # Then check that the item we just created was indeed for the right timebag.
                        macro_features[fsrc][ftype][i]

            # Logging
            if i > 0 and len(new_strings) > 0:
                should_log = True
            index = dict((q.string, q) for q in c.quotes.itervalues() if q.string in tbg.strings)
            cluster_log[1].append((index, new_strings, transitions))
        
        # Logging
        if should_log:
            clusters_log.append(cluster_log)
    
    # Convert to numpy arrays
    print 'Kept {} clusters from days filter ({}-{}).'.format(n_clusters_kept, min_days, max_days)
    print '{} clusters have at least one occurrence considered new (logged).'.format(len(clusters_log))
    for fsrc, fsrc_values in features.iteritems():
        for ftype in fsrc_values.iterkeys():
            for i, macro_features_tbg in enumerate(macro_features[fsrc][ftype]):
                macro_features[fsrc][ftype][i] = np.array(macro_features_tbg)
    
    # Save to disk
    ps.save(macro_features, 'data/MemeTracker/macro/macro_features{}.pickle'.format(file_postfix))
    ps.save(clusters_log, 'data/MemeTracker/macro/clusters_log{}.pickle'.format(file_postfix))
# Out:
#   10 % (5548 / 55483 clusters)
#   20 % (11096 / 55483 clusters)
#   30 % (16644 / 55483 clusters)
#   40 % (22192 / 55483 clusters)
#   50 % (27740 / 55483 clusters)
#   60 % (33288 / 55483 clusters)
#   70 % (38836 / 55483 clusters)
#   80 % (44384 / 55483 clusters)
#   90 % (49932 / 55483 clusters)
#   100 % (55480 / 55483 clusters)
# Kept 34363 clusters from days filter (0-80).
# 516 clusters have at least one occurrence considered new (logged).

# %% [markdown]
# ## Meta-analysis

# %% [markdown]
# ### Until which timebag clusters keep having new quotes

# %%
last_novel_tbg_per_cluster = np.zeros(len(clusters_log), dtype=int)
for i, (c, tbgs_log) in enumerate(clusters_log):
    last_novel_tbg_per_cluster[i] = np.array([len(tbg_log[1]) for tbg_log in tbgs_log]).nonzero()[0][-1]

last_novel_tbg = last_novel_tbg_per_cluster.max()
bins = np.linspace(- 0.5, last_novel_tbg + 0.5, last_novel_tbg + 2)
plt.hist(last_novel_tbg_per_cluster, bins=bins, log=True)
# Out:
# (array([   0.,  336.,  115.,   36.,   16.,    4.,    6.,    3.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5]),
#  <a list of 8 Patch objects>)

# %% [markdown]
# ### Histograms of number of new quotes per timebag

# %%
n_new_per_tbg = []

# Collect values
for c, tbgs_log in clusters_log:
    for i, tbg_log in enumerate(tbgs_log):
        try:
            # Either add it to the existing list
            n_new_per_tbg[i].append(len(tbg_log[1]))
        except IndexError:
            # Or create the list for this timebag if necessary
            n_new_per_tbg.append([len(tbg_log[1])])
            # Then check that the item we just created was indeed for the right timebag.
            n_new_per_tbg[i]

# Convert to numpy arrays
np_n_new_per_tbg = []
for i, n_new_this_tbg in enumerate(n_new_per_tbg):
    np_n_new_per_tbg.append(np.array(n_new_this_tbg))
max_new_in_tbg = max([np_n_new_this_tbg.max() for np_n_new_this_tbg in np_n_new_per_tbg])

# Plot
bins = np.linspace(- 0.5, max_new_in_tbg + 0.5, max_new_in_tbg + 2)
fig, axs = plt.subplots(1, last_novel_tbg + 1, figsize=(3 * (last_novel_tbg - 1), 2), sharey=True)
for i in range(last_novel_tbg + 1):
    axs[i].hist(np_n_new_per_tbg[i], bins=bins, log=True)
    axs[i].set_xlim(bins[0], bins[-1])
    axs[i].set_xlabel('Bag {}'.format(i))

# %% [markdown]
# ### Detailed log

# %%
from numpy.random import permutation
log_range = permutation(len(clusters_log))[:20]

# %%
def plot_cluster_novelty(c, tbgs_log):
    blue = sb.color_palette()[5]
    red = sb.color_palette()[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(15, 3))
    ax.set_title('Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq))
    ax.set_xlim(- 0.5, last_novel_tbg - 0.5)
    ax.set_xticks(range(last_novel_tbg))
    ax.set_xlabel('Bag number')
    ax.set_ylim(- 0.5, c.n_quotes - 0.5)
    ax.set_yticks(range(c.n_quotes))
    ax.set_ylabel('Quote occurrences')
    
    qt_coords = dict((q.id, i) for i, q in enumerate(c.quotes.itervalues()))
    for i, (index, new_strings, transitions) in enumerate(tbgs_log[:last_novel_tbg]):
        tbg_qt_coords = np.array([qt_coords[q.id] for q in index.values()])
        tbg_new_qt_coords = np.array([qt_coords[index[s].id] for s in new_strings])
        ax.plot(np.ones_like(tbg_qt_coords) * i, tbg_qt_coords, 'o', color=blue, markersize=8)
        ax.plot(np.ones_like(tbg_new_qt_coords) * i, tbg_new_qt_coords, 'o', color=red, markersize=12)
    fig.show()


#plot_cluster_novelty(print_clusters[1][0], print_clusters[1][1])
for i in log_range:
    c, tbgs_log = clusters_log[i]
    plot_cluster_novelty(c, tbgs_log)
# Out:
# /home/sl/.virtualenvs/brainscopypaste/src/matplotlib/lib/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
width = 100

for i in log_range:
    c, tbgs_log = clusters_log[i]
    ctitle = '######### Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq)
    ctitle += ' ' + '-' * (width - len(ctitle) - 1)
    print ctitle
    
    previndex = {}
    for i, (index, new_strings, transitions) in enumerate(tbgs_log):
        print
        if i >= 10:
            break
        btitle = '     #### Bag {}'.format(i)
        btitle += ' ' + '-' * (width - len(btitle) - 1)
        print btitle
        print
        
        for q in index.values():
            idstring = '[#{}'.format(q.id)
            if q.string in new_strings:
                cstring = ''
                tokens = tagger.Tokenize(q.string)
                qtransitions = transitions[q.string]
                diffs = sorted(list(set([pos for ref_string, pos in qtransitions])))
                odiffs = dict((diff, [ref_string for ref_string, pos in qtransitions if pos == diff]) for diff in diffs)
                prevdiff = -1
                for i, diff in enumerate(diffs):
                    idstring += ', from ' + '-'.join(['#{}'.format(previndex[ref_string].id) for ref_string in odiffs[diff]])
                    origins = [tagger.Tokenize(ref_string)[diff] for ref_string in odiffs[diff]]
                    difftext = '{' + ', '.join(origins) + ' => {}}}'.format(tokens[diff])
                    cstring += blue(' '.join(tokens[prevdiff + 1:diff] + ['']))
                    cstring += red(difftext) + ' '
                    prevdiff = diff
                cstring += blue(' '.join(tokens[prevdiff + 1:] + ['']))
            else:
                cstring = q.string + ' '
            
            idstring += ']'.format(q.id)
            cstring += idstring
            
            cstring_wparts = textwrap.wrap(cstring, width - 10)
            cstring_indented = '          ' + cstring_wparts[0]
            cstring_indented += '\n'.join([''] + ['              ' + part for part in cstring_wparts[1:]])
            print cstring_indented
        previndex = index
    print
# Out:
# ######### Cluster #1463112, 4 quotes, total freq 51 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           when you got a nigger running for president you need a first stringer he 's
#               definitely a second stringer [#1450054]
#           when you got a negro running for president you need a first stringer he 's
#               definitely a second stringer [#1443726]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           when you got a {negro => nigger} running for president you
#               need a first stringer he 's definitely a second stringer [#1450054, from #1443726]
#           when you got a {nigger => negro} running for president you
#               need a first stringer he 's definitely a second stringer [#1443726, from #1450054]
#           when you got a {nigger => negra} running for president you
#               need a first stringer he 's definitely a second stringer [#1463112, from #1450054]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           when you got a {nigger => negra} running for president you
#               need a first stringer he 's definitely a second stringer [#1463112, from #1450054]
#           when you got a negro running for president you need a first-stringer he's definitely a
#               second-stringer [#1488044]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           when you got a negro running for president you need a first-stringer he's definitely a
#               second-stringer [#1488044]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           when you got a nigger running for president you need a first stringer he's definitely a
#               second stringer [#1450054]
#           when you got a negra running for president you need a first stringer he's definitely a
#               second stringer [#1463112]
#           when you got a negro running for president you need a first-stringer he's definitely a
#               second-stringer [#1488044]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           when you got a negra running for president you need a first stringer he's definitely a
#               second stringer [#1463112]
#           when you got a negro running for president you need a first-stringer he's definitely a
#               second-stringer [#1488044]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           when you got a negra running for president you need a first stringer he's definitely a
#               second stringer [#1463112]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#           when you got a negra running for president you need a first stringer he's definitely a
#               second stringer [#1463112]
#
# ######### Cluster #1397961, 5 quotes, total freq 192 -----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           along the lines that now is the time to lower tax rates for investors capital gains
#               tax dividend tax rates to make sure that we can get the economy jump-started
#               [#1409243]
#           now is the time to lower tax rates for investors [#1401684]
#           i think it goes along the lines that now is the time to lower tax rates for
#               investors capital gains tax dividend tax rates to make sure that we can get the economy
#               jump-started [#1397235]
#           i think it goes along the lines of now 's the time to lower tax rates for investors
#               capital gains tax to make sure that we can get the economy jump-started [#1398038]
#           i think it goes along the lines of now 's the time to lower tax rates for investors
#               capital gains tax dividend tax rates to make sure that we can get the economy jump-started
#               [#1397961]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           i think it goes along the lines {of => that} now is the time
#               to lower tax rates for investors capital gains tax dividend tax rates to make sure that we
#               can get the economy jump-started [#1397235, from #1397961]
#           i think it goes along the lines {that => of} now 's the time
#               to lower tax rates for investors capital gains tax dividend tax rates to make sure that we
#               can get the economy jump-started [#1397961, from #1397235]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           along the lines that now is the time to lower tax rates for investors capital gains tax
#               dividend tax rates to make sure that we can get the economy jump-started [#1409243]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           i think it goes along the lines of now's the time to lower tax rates for investors capital
#               gains tax dividend tax rates to make sure that we can get the economy jump-started
#               [#1397961]
#
# ######### Cluster #1070917, 4 quotes, total freq 33 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           you have five minutes to move your cars [#492746]
#           you have three minutes to move your cars [#497799]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           you have {five => three} minutes to move your cars
#               [#497799, from #492746]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#
#
# ######### Cluster #1065055, 2 quotes, total freq 19 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           i bowled as quick as i have for a long long time in that first spell i had the
#               opposition saying that is the quickest they have faced all season and when they say stuff
#               like that i 'd like to finish on that note [#1065055]
#           i bowled as quick as i have for a long long time in my first spell i had the
#               opposition saying that is the quickest they have faced all season and when they say stuff
#               like that i 'd like to finish on that note [#1066529]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           i bowled as quick as i have for a long long time in {my => that}
#               first spell i had the opposition saying that is the quickest they have faced all
#               season and when they say stuff like that i 'd like to finish on that note [#1065055,
#               from #1066529]
#           i bowled as quick as i have for a long long time in {that => my}
#               first spell i had the opposition saying that is the quickest they have faced all
#               season and when they say stuff like that i 'd like to finish on that note [#1066529,
#               from #1065055]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           i bowled as quick as i have for a long long time in {my => that}
#               first spell i had the opposition saying that is the quickest they have faced all
#               season and when they say stuff like that i 'd like to finish on that note [#1065055,
#               from #1066529]
#           i bowled as quick as i have for a long long time in {that => my}
#               first spell i had the opposition saying that is the quickest they have faced all
#               season and when they say stuff like that i 'd like to finish on that note [#1066529,
#               from #1065055]
#
# ######### Cluster #1314015, 2 quotes, total freq 66 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           if we get a good shot on tebow we 're going to try our best to take him out of the
#               game [#1314015]
#           if we get a good shot on him we 're going to try our best to take him out of the
#               game [#1331887]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           if we get a good shot on {him => tebow} we 're going to try
#               our best to take him out of the game [#1314015, from #1331887]
#           if we get a good shot on {tebow => him} we 're going to try
#               our best to take him out of the game [#1331887, from #1314015]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           if we get a good shot on {him => tebow} we 're going to try
#               our best to take him out of the game [#1314015, from #1331887]
#           if we get a good shot on {tebow => him} we 're going to try
#               our best to take him out of the game [#1331887, from #1314015]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           if we get a good shot on {him => tebow} we 're going to try
#               our best to take him out of the game [#1314015, from #1331887]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           if we get a good shot on tebow we're going to try our best to take him out of the game
#               [#1314015]
#
# ######### Cluster #1710973, 5 quotes, total freq 64 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           i would always fall for guys i wanted to save for the first time i fell in love
#               with someone who saved me [#1722712]
#           i 'd always fall for guys i wanted to save for the first time i fell in love with
#               someone who saved me [#1709113]
#           always fall ing for guys i wanted to save [#1715520]
#           for the first time i fell in love with someone who saved me [#1710973]
#           fell in love with someone who saved me [#1714162]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           i {would => 'd} always fall for guys i wanted to save for the
#               first time i fell in love with someone who saved me [#1709113, from #1722712]
#           always fall ing for guys i wanted to save [#1715520]
#           for the first time i fell in love with someone who saved me [#1710973]
#           fell in love with someone who saved me [#1714162]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           i {'d => would} always fall for guys i wanted to save for the
#               first time i fell in love with someone who saved me [#1722712, from #1709113]
#           i'd always fall for guys i wanted to save for the first time i fell in love with someone
#               who saved me [#1709113]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           i {would => 'd} always fall for guys i wanted to save for the
#               first time i fell in love with someone who saved me [#1709113, from #1722712]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           i'd always fall for guys i wanted to save for the first time i fell in love with someone
#               who saved me [#1709113]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           i would always fall for guys i wanted to save for the first time i fell in love with
#               someone who saved me [#1722712]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           always fall ing for guys i wanted to save [#1715520]
#           fell in love with someone who saved me [#1714162]
#
# ######### Cluster #2488389, 8 quotes, total freq 94 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           it is the best news we 've received in the past four weeks [#2489220]
#           this is a vital stabilizing development for satyam [#2496455]
#           it is the best news we 've received in the past few weeks [#2496456]
#           this is a vital stabilizing development for satyam and it marks the beginning of a
#               new chapter in the company 's history it is the best news we 've received in the past four
#               weeks [#2487784]
#           the best news we 've received in the past four weeks [#2488389]
#           this is a vital stabilising development for satyam [#2487828]
#           this is a vital stabilizing development for satyam and it marks the beginning of a
#               new chapter in the company 's history [#2488390]
#           this is a vital stabilising development for satyam and it marks the beginning of a
#               new chapter in the company 's history [#2490753]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           the best news we've received in the past four weeks [#2488389]
#           this is a vital stabilizing development for satyam [#2496455]
#           it is the best news we 've received in the past {four => few}
#               weeks [#2496456, from #2489220]
#           this is a vital stabilizing development for satyam and it marks the beginning of a new
#               chapter in the company's history it is the best news we've received in the past four weeks
#               [#2487784]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           the best news we've received in the past four weeks [#2488389]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           this is a vital stabilising development for satyam [#2487828]
#
# ######### Cluster #2308351, 3 quotes, total freq 33 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           to fight alongside the army if any war is imposed on pakistan [#2312147]
#           thousands of our well-armed militants are ready to fight alongside the army if any
#               war is imposed on pakistan [#2308351]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           thousands of our well-armed militants are ready to fight alongside the army if any war is
#               imposed on pakistan [#2308351]
#           thousands of our well-armed {militants => mujahideen} are
#               ready to fight alongside the army if any war is imposed on pakistan [#2324711, from
#               #2308351]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           to fight alongside the army if any war is imposed on pakistan [#2312147]
#           thousands of our well-armed mujahideen are ready to fight alongside the army if any war is
#               imposed on pakistan [#2324711]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           to fight alongside the army if any war is imposed on pakistan [#2312147]
#
# ######### Cluster #24786, 3 quotes, total freq 22 --------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           only inevitable that people from different countries and regions may not see eye to
#               eye with one another on some different issues [#34162]
#           it is only inevitable that people from different countries and regions may not see
#               eye to eye with one another on some different issues [#25441]
#           it is only inevitable for people from different countries and regions may not see
#               eye to eye with one another on some different issues [#24786]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           it is only inevitable {for => that} people from different
#               countries and regions may not see eye to eye with one another on some different issues
#               [#25441, from #24786]
#           only inevitable that people from different countries and regions may not see eye to eye
#               with one another on some different issues [#34162]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           it is only inevitable {that => for} people from different
#               countries and regions may not see eye to eye with one another on some different issues
#               [#24786, from #25441]
#
# ######### Cluster #391261, 4 quotes, total freq 97 -------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           we expect russia to meet its commitment to cease all military activities in georgia
#               and we expect all russian forces that have entered georgia in recent days to withdraw from
#               that country [#388937]
#           we expect russia to meet its commitment to cease all military activities in georgia
#               and we expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391261]
#           we expect all russian forces that entered georgia in recent days to withdraw from
#               that country [#391247]
#           we expect russia to meet its commitment to cease all military activities in georgia
#               and we expect all russian forces who have entered georgia in recent days to withdraw from
#               that country [#390534]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           we expect russia to meet its commitment to cease all military activities in georgia
#               and we expect all russian forces {that => who} have entered georgia
#               in recent days to withdraw from that country [#390534, from #388937]
#           we expect russia to meet its commitment to cease all military activities in georgia and we
#               expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391261]
#           we expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391247]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           we expect russia to meet its commitment to cease all military activities in georgia and we
#               expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391261]
#           we expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391247]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           we expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391247]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           we expect russia to meet its commitment to cease all military activities in georgia and we
#               expect all russian forces that entered georgia in recent days to withdraw from that
#               country [#391261]
#
# ######### Cluster #1535282, 11 quotes, total freq 621 ----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           failing march of his predecessor [#1534180]
#           al qaeda will have to support mccain in the coming elections so that he continues
#               the failing march of his predecessor bush [#1536991]
#           then al qaeda will have to support mccain in the coming elections so that he
#               continues the failing march of his predecessor bush [#1535791]
#           then al-qaida will have to support mccain in the coming elections so that he
#               continues the failing march of his predecessor bush [#1535282]
#           al-qaida will have to support mccain in the coming election [#1535268]
#           then al-qa'da will have to support mccain in the coming elections so that he
#               continues the failing march of his predecessor bush [#1541485]
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           then al-qaeda will have to support mccain in the coming elections so that he
#               continues the failing march of his predecessor bush [#1535612]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           al-qaeda will have to support mccain in the coming elections so that he continues
#               the failing march of his predecessor bush [#1542126]
#           the failing march of his predecessor [#1541510]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           {al => then} al-qaida will have to support mccain in the
#               coming elections so that he continues the failing march of his predecessor bush
#               [#1535282, from #1536991]
#           al-qaida will have to support mccain in the coming election [#1535268]
#           {al => then} al-qaeda will have to support mccain in the
#               coming elections so that he continues the failing march of his predecessor bush
#               [#1535612, from #1536991]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           failing march of his predecessor [#1534180]
#           the failing march of his predecessor [#1541510]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           {then, then => al} qaeda will have to support mccain in the
#               coming elections so that he continues the failing march of his predecessor bush
#               [#1536991, from #1535282-#1535612]
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           then al-qaida will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535282]
#           then al-qa'da will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1541485]
#           then al-qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535612]
#           failing march of his predecessor [#1534180]
#           the failing march of his predecessor [#1541510]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           {al => then} al-qaida will have to support mccain in the
#               coming elections so that he continues the failing march of his predecessor bush
#               [#1535282, from #1536991]
#           failing march of his predecessor [#1534180]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           failing march of his predecessor [#1534180]
#           then al-qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535612]
#           then al-qaida will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535282]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           al-qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1542126]
#           failing march of his predecessor [#1534180]
#           then al-qaida will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535282]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           then al qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535791]
#           then al-qaida will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535282]
#           al-qaida will have to support mccain in the coming election [#1535268]
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           failing march of his predecessor [#1534180]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           then al qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535791]
#           al qaeda will have to support mccain in the coming election [#1536384]
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           failing march of his predecessor [#1534180]
#           then al-qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535612]
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#           then al qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1535791]
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           failing march of his predecessor [#1534180]
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#           al-qaeda will have to support mccain in the coming election [#1534179]
#           failing march of his predecessor [#1534180]
#           al qaeda will have to support mccain in the coming elections so that he continues the
#               failing march of his predecessor bush [#1536991]
#
#
# ######### Cluster #1491978, 15 quotes, total freq 360 ----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis [#1493222]
#           it is essential that we preserve the foundations of democratic capitalism
#               [#1491643]
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#           preserve the foundations of democratic capitalism [#1493055]
#           it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1495810]
#           it is essential that we preserve the foundations of democratic capitalism
#               commitment to free markets free enterprise and free trade [#1500513]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism the
#               commitment to free markets free enterprise and free trade [#1491981]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism-a
#               commitment to free markets free enterprise and free trade [#1492369]
#           preserve the foundations of democratic capitalism a commitment to free markets free
#               enterprise and free trade [#1492948]
#           as we make the regulatory institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism
#               commitment to free markets free enterprise and free trade [#1491640]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of free enterprise and free
#               trade [#1492459]
#           it is essential that we preserve the foundations of democratic capitalism the
#               commitment to free markets free enterprise and free trade [#1493225]
#           the foundations of democratic capitalism the commitment to free markets free
#               enterprise and free trade [#1495467]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1491978]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis [#1493222]
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism
#               {a => the} commitment to free markets free enterprise and free trade
#               [#1491981, from #1491978]
#           it is essential that we preserve the foundations of democratic capitalism commitment to
#               free markets free enterprise and free trade [#1500513]
#           it is essential that we preserve the foundations of democratic capitalism [#1491643]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism-a
#               commitment to free markets free enterprise and free trade [#1492369]
#           preserve the foundations of democratic capitalism a commitment to free markets free
#               enterprise and free trade [#1492948]
#           as we make the regulatory institutional changes necessary to avoid a repeat of this crisis
#               it is essential that we preserve the foundations of democratic capitalism commitment to
#               free markets free enterprise and free trade [#1491640]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of free enterprise and free trade
#               [#1492459]
#           it is essential that we preserve the foundations of democratic capitalism
#               {a => the} commitment to free markets free enterprise and free trade
#               [#1493225, from #1495810]
#           the foundations of democratic capitalism the commitment to free markets free enterprise
#               and free trade [#1495467]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism
#               {the => a} commitment to free markets free enterprise and free trade
#               [#1491978, from #1491981]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           preserve the foundations of democratic capitalism [#1493055]
#           preserve the foundations of democratic capitalism a commitment to free markets free
#               enterprise and free trade [#1492948]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism
#               {a => the} commitment to free markets free enterprise and free trade
#               [#1491981, from #1491978]
#           it is essential that we preserve the foundations of democratic capitalism commitment to
#               free markets free enterprise and free trade [#1500513]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of
#               this crisis it is essential that we preserve the foundations of democratic capitalism
#               {the => a} commitment to free markets free enterprise and free trade
#               [#1491978, from #1491981]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           as we make the regulatory institutional changes necessary to avoid a repeat of this crisis
#               it is essential that we preserve the foundations of democratic capitalism commitment to
#               free markets free enterprise and free trade [#1491640]
#           the foundations of democratic capitalism the commitment to free markets free enterprise
#               and free trade [#1495467]
#           it is essential that we preserve the foundations of democratic capitalism a commitment to
#               free markets free enterprise and free trade [#1495810]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           it is essential that we preserve the foundations of democratic capitalism [#1491643]
#           it is essential that we preserve the foundations of democratic capitalism commitment to
#               free markets free enterprise and free trade [#1500513]
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1491978]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1491978]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#           it is essential we preserve the foundations of democratic capitalism [#1495214]
#           it is essential that we preserve the foundations of democratic capitalism [#1491643]
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1491978]
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#           as we make the regulatory and institutional changes necessary to avoid a repeat of this
#               crisis it is essential that we preserve the foundations of democratic capitalism a
#               commitment to free markets free enterprise and free trade [#1491978]
#
#
# ######### Cluster #2585351, 2 quotes, total freq 138 -----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           i am making a commitment to you as your next president that we are going to make
#               government work [#2585351]
#           i am making a commitment to you as the next president that we are going to make
#               government work [#2586014]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           i am making a commitment to you as {the => your} next
#               president that we are going to make government work [#2585351, from #2586014]
#           i am making a commitment to you as {your => the} next
#               president that we are going to make government work [#2586014, from #2585351]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           i am making a commitment to you as your next president that we are going to make
#               government work [#2585351]
#
# ######### Cluster #545213, 6 quotes, total freq 121 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           it 's clear to us and the american leadership does n't deny it that the so-called
#               missile shield in europe will be widened and modernised in that case russia will be
#               compelled to react and not only by diplomatic protests [#544532]
#           will be forced to react and not only through diplomatic demarches [#544803]
#           in this case russia will be forced to react and not only through diplomatic
#               [#545213]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           will be forced to react and not only through diplomatic demarches [#544803]
#           will be forced to react and not only through diplomatic {demarches =>
#               means} [#568010, from #544803]
#           in this case russia will be forced to react and not only through diplomatic [#545213]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           will be forced to react and not only through diplomatic {means =>
#               demarches} [#544803, from #568010]
#           will be forced to react and not only through diplomatic means [#568010]
#           in this case russia will be forced to react and not only through diplomatic [#545213]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           will be forced to react and not only through diplomatic {demarches =>
#               means} [#568010, from #544803]
#           in this case russia will be forced to react and not only through diplomatic [#545213]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           react and not only through diplomatic protests [#624705]
#           will be forced to react and not only through diplomatic means [#568010]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           react and not only through diplomatic protests [#624705]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           react and not only through diplomatic protests [#624705]
#           in this case russia will be forced to react and not only through diplomatic [#545213]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           to react and not only through diplomatic protests [#691529]
#           react and not only through diplomatic protests [#624705]
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#           to react and not only through diplomatic protests [#691529]
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#
#
# ######### Cluster #1443521, 4 quotes, total freq 127 -----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           guy is not involved in this equation [#1443520]
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together in over a year they have been privately separated madonna however wanted to
#               finish her world tour before divorcing [#1447241]
#           with or without a-rod madonna and guy have n't been together for over a year they
#               have been privately separated madonna however wanted to finish her world tour before
#               divorcing [#1443521]
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together for over a year they have been privately separated madonna however wanted to
#               finish her world tour before divorcing [#1444059]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           guy is not involved in this equation [#1443520]
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together {for => in} over a year they have been privately
#               separated madonna however wanted to finish her world tour before divorcing [#1447241,
#               from #1444059]
#           with or without a-rod madonna and guy haven't been together for over a year they have been
#               privately separated madonna however wanted to finish her world tour before divorcing
#               [#1443521]
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together {in => for} over a year they have been privately
#               separated madonna however wanted to finish her world tour before divorcing [#1444059,
#               from #1447241]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together {for => in} over a year they have been privately
#               separated madonna however wanted to finish her world tour before divorcing [#1447241,
#               from #1444059]
#           guy is not involved in this equation with or without a-rod madonna and guy have n't
#               been together {in => for} over a year they have been privately
#               separated madonna however wanted to finish her world tour before divorcing [#1444059,
#               from #1447241]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           guy is not involved in this equation [#1443520]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           guy is not involved in this equation with or without a-rod madonna and guy haven't been
#               together in over a year they have been privately separated madonna however wanted to
#               finish her world tour before divorcing [#1447241]
#           guy is not involved in this equation with or without a-rod madonna and guy haven't been
#               together for over a year they have been privately separated madonna however wanted to
#               finish her world tour before divorcing [#1444059]
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#
#
# ######### Cluster #2256810, 8 quotes, total freq 293 -----------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           a little bit like the addict returning to the drug [#2262977]
#           it seems a little bit like the addict returning to the drug [#2256810]
#           addict returning to the drug [#2256805]
#           like an addict returning to the drug [#2261017]
#           i worry about that because it seems a little bit like the addict returning to the
#               drug [#2257777]
#           an addict returning to the drug [#2268849]
#           an addict returning to a drug [#2257110]
#           the addict returning to the drug [#2258248]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           addict returning to the drug [#2256805]
#           it seems a little bit like the addict returning to the drug [#2256810]
#           {an => the} addict returning to the drug [#2258248, from
#               #2268849]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           a little bit like the addict returning to the drug [#2262977]
#           an addict returning to a drug [#2257110]
#           like an addict returning to the drug [#2261017]
#           the addict returning to the drug [#2258248]
#           i worry about that because it seems a little bit like the addict returning to the drug
#               [#2257777]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           an addict returning to a drug [#2257110]
#           like an addict returning to the drug [#2261017]
#           i worry about that because it seems a little bit like the addict returning to the drug
#               [#2257777]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           an addict returning to the drug [#2268849]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           a little bit like the addict returning to the drug [#2262977]
#           it seems a little bit like the addict returning to the drug [#2256810]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           addict returning to the drug [#2256805]
#           an addict returning to a drug [#2257110]
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#           an addict returning to the drug [#2268849]
#           an addict returning to a drug [#2257110]
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#           addict returning to the drug [#2256805]
#           an addict returning to the drug [#2268849]
#
#
# ######### Cluster #2437338, 4 quotes, total freq 62 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           she is usually very bubbly but she is more quiet and seems sad she usually hangs
#               out with the crew between takes but tuesday she is only hanging out with her bodyguard
#               [#2437925]
#           she is usually very bubbly but she is more quiet and seems sad she usually hangs
#               out with the crew between takes but now she is only hanging out with her bodyguard
#               [#2442233]
#           she is usually very bubbly but she is more quiet and seems sad [#2437338]
#           she usually hangs out with the crew between takes but tuesday she is only hanging
#               out with her bodyguard [#2437339]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           she is usually very bubbly but she is more quiet and seems sad she usually hangs
#               out with the crew between takes but {tuesday => now} she is only
#               hanging out with her bodyguard [#2442233, from #2437925]
#           she is usually very bubbly but she is more quiet and seems sad [#2437338]
#           she usually hangs out with the crew between takes but tuesday she is only hanging out with
#               her bodyguard [#2437339]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           she is usually very bubbly but she is more quiet and seems sad she usually hangs
#               out with the crew between takes but {now => tuesday} she is only
#               hanging out with her bodyguard [#2437925, from #2442233]
#           she is usually very bubbly but she is more quiet and seems sad [#2437338]
#           she usually hangs out with the crew between takes but tuesday she is only hanging out with
#               her bodyguard [#2437339]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           she is usually very bubbly but she is more quiet and seems sad [#2437338]
#
# ######### Cluster #2420576, 8 quotes, total freq 75 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           hi yall brit brit here just wanted to update you all on the size of my vagina it 's
#               about 4 feet wide with razor sharp teeth [#2428437]
#           4 feet wide with razor sharp teeth [#2421482]
#           hi yall brit brit here just wanted to update you on the size of my vagina it 's
#               about 4 feet wide with razor sharp teeth [#2428655]
#           hi yall brit brit here just wanted to update you on the size of my [#2423106]
#           hi yall brit brit here just wanted to update you all on the size of my vagina its
#               about 4 feet wide with razor sharp teeth [#2420576]
#           hi y'all brit brit here just wanted to update you all on the size of my vagina it
#               's about four feet wide with razor sharp teeth [#2429079]
#           about 4 feet wide with razor sharp teeth [#2422160]
#           hi y'all brit brit here just wanted to update you all on the size of my vagina its
#               sic about 4 feet wide with razor sharp teeth [#2421737]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           hi yall brit brit here just wanted to update you all on the size of my vagina it
#               {sic => 's} about 4 feet wide with razor sharp teeth [#2428437,
#               from #2421737]
#           hi yall brit brit here just wanted to update you on the size of my vagina it's about 4
#               feet wide with razor sharp teeth [#2428655]
#           hi yall brit brit here just wanted to update you on the size of my [#2423106]
#           hi yall brit brit here just wanted to update you all on the size of my vagina its about 4
#               feet wide with razor sharp teeth [#2420576]
#           hi y'all brit brit here just wanted to update you all on the size of my vagina it's about
#               four feet wide with razor sharp teeth [#2429079]
#           about 4 feet wide with razor sharp teeth [#2422160]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#           hi yall brit brit here just wanted to update you all on the size of my vagina it's about 4
#               feet wide with razor sharp teeth [#2428437]
#           hi yall brit brit here just wanted to update you all on the size of my vagina its about 4
#               feet wide with razor sharp teeth [#2420576]
#           hi yall brit brit here just wanted to update you on the size of my vagina it's about 4
#               feet wide with razor sharp teeth [#2428655]
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#           about 4 feet wide with razor sharp teeth [#2422160]
#           hi yall brit brit here just wanted to update you all on the size of my vagina its about 4
#               feet wide with razor sharp teeth [#2420576]
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#           hi y'all brit brit here just wanted to update you all on the size of my vagina its sic
#               about 4 feet wide with razor sharp teeth [#2421737]
#           hi yall brit brit here just wanted to update you all on the size of my vagina its about 4
#               feet wide with razor sharp teeth [#2420576]
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#
#      #### Bag 8 ------------------------------------------------------------------------------------
#
#
#      #### Bag 9 ------------------------------------------------------------------------------------
#
#
#
# ######### Cluster #2638469, 4 quotes, total freq 47 ------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           we have cooperated fully with all government agencies investigating this matter and
#               will do so in the future [#2625346]
#           kbr 's investigation has produced no evidence that kbr was responsible for sgt
#               maseth 's death [#2625345]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           kbr 's investigation has produced no evidence that kbr was responsible for
#               {sgt => sergeant} maseth 's death [#2638469, from #2625345]
#
#      #### Bag 2 ------------------------------------------------------------------------------------
#
#
#      #### Bag 3 ------------------------------------------------------------------------------------
#
#           we have cooperated fully with all government agencies investigating this matter and will
#               do so in the future [#2625346]
#
#      #### Bag 4 ------------------------------------------------------------------------------------
#
#
#      #### Bag 5 ------------------------------------------------------------------------------------
#
#           kbr's investigation has produced no evidence that kbr was responsible for sergeant
#               maseth's death [#2638469]
#
#      #### Bag 6 ------------------------------------------------------------------------------------
#
#
#      #### Bag 7 ------------------------------------------------------------------------------------
#
#           kbr's investigation has produced no evidence that kbr was responsible for sgt maseth's
#               death we have cooperated fully with all government agencies investigating this matter and
#               will do so in the future [#2704859]
#
# ######### Cluster #853075, 3 quotes, total freq 21 -------------------------------------------------
#
#      #### Bag 0 ------------------------------------------------------------------------------------
#
#           using the radio he got direction from the chief surgeon and was able to stop the
#               bleeding thereby saving that soldier 's life [#843430]
#           using a radio he got direction from the chief surgeon and was able to stop the
#               bleeding thereby saving that soldier 's life [#853075]
#           using the radio he got some direction from the chief surgeon and was able to stop
#               the bleeding thereby saving the soldier 's life [#846831]
#
#      #### Bag 1 ------------------------------------------------------------------------------------
#
#           using {a => the} radio he got direction from the chief
#               surgeon and was able to stop the bleeding thereby saving that soldier 's life
#               [#843430, from #853075]
