# %% [markdown]
# # How does the distribution of features evolve when we go through the timebags?

# %% [markdown]
# ## Some loading and prep code

# %%
# First some imports
import numpy as np
import matplotlib as mpl
import seaborn as sb
# %matplotlib inline

import settings as st
from linguistics.treetagger import get_tagger
from linguistics.wn import lemmatize as relemmatize
from datainterface.redistools import RedisReader
import datainterface.picklesaver as ps
from util.generic import ProgressInfo
tagger = get_tagger()

# %%
# Load the clusters, the features, and initialize the results
clusters = RedisReader(st.redis_mt_clusters_filtered_pref)
features = dict((fsrc, dict((ftype, ps.load(fdetails['file'].format('all')))
                            for ftype, fdetails in fsrc_details.iteritems()))
                for fsrc, fsrc_details in st.mt_analysis_features.iteritems())
empirical_features = dict((fsrc, dict((ftype, [])
                                      for ftype in fsrc_values.iterkeys()))
                          for fsrc, fsrc_values in features.iteritems())

# %%
from linguistics.distance import hamming_word
    
def is_in_sphere(ref_strings, string):
    """Whether or not `string` is in the hamming_word-sphere at
    distance 1 surrounding the `ref_strings`."""
    
    for ref_str in ref_strings:
        if hamming_word(ref_str, string) == 1:
            return True
    return False


def get_filtered_relems_and_strings(tbg, ref_strings, excl_strings):
    """List the relemmatized words (once per occurrence) appearing in `tbg`,
    and at distance one from `ref_strings`, excluding strings in `excl_strings`.
    
    Quotes are first lemmatized with the TreeTagger lemmatizer, then
    relemmatized as in the mining analysis, with the WordNet morphy
    method.
    
    Parameters
    ----------
    tbg : TimeBag
        The timebag to work on.
    ref_strings : list of strings
        The reference string from which to compute distance; if None, then ignored.
    excl_strings : list of strings
        The reference string from which to exclude; if None, then ignored.
    
    Returns
    -------
    list
        The list of relemmatized words.
    set
        The set of new strings considered to the product of this iteration.
    
    """
    
    filtered_relems = []
    new_strings = set([])

    for string, freq in zip(tbg.strings, tbg.tot_freqs):
        # If our current string is in the set of banned strings,
        # jump to next one
        if excl_strings is not None and string in excl_strings:
            continue
        
        # If our current string is not in the sphere around ref_strings,
        # jump to next one
        if ref_strings is not None and not is_in_sphere(ref_strings, string):
            continue

        new_strings.add(string)
        relems = [relemmatize(lem) for lem in tagger.Lemmatize(string)]
        filtered_relems.extend(relems * freq)

    return filtered_relems, new_strings

# %% [markdown]
# ## The analysis itself
#
# We want to look at the distribution of features in *new* quotes produced by susbtitution (i.e. not those reinjected from outside as part of the continuous process). So for each cluster, we look at the first timebag, and take it as a reference and include all quotes in the second timebag that aren't in the first but are at distance *d* from a quote in the first. We repeat this operation for each later timebag, but basing ourselves on the set of new quotes produced by the previous step. Then on each of these sets of quotes, we compute the distribution of features. This gives us the distribution of features on the novel quotes.

# %%
# Duration of a timebag, in days
timebag_size = 2.0
# Minimum number of timebags a cluster must have to be included in the analysis
min_number_of_timebags = 20 
# Number of timebags included in 'new quotes' plot below
n_tbgs_new_quotes = 20

# %%
try:
    #raise IOError
    # See if we already computed this
    empirical_features = ps.load('data/analyses/empirical_features_recursive_min-20-tbgs.pickle')
    np_new_quotes_counts = ps.load('data/analyses/new_quotes_counts_recursive_min-20-tbgs.pickle')
    print 'Loaded from pickle.'
except IOError:
    n_clusters_kept = 0
    new_quotes_counts = []
    print_clusters = []
    
    # A progress indicator
    progress = ProgressInfo(len(clusters), 10, 'clusters')
    
    # For each cluster
    for c in clusters.itervalues():
        progress.next_step()
        
        # Build timebags, skip if we don't have enough bags
        tbgs = c.build_timebags(timebag_size)
        if len(tbgs) < min_number_of_timebags:
            continue
        
        print_cluster = (c, [])
        max_new_qts_per_tbg = 0
        
        n_clusters_kept += 1
        tbgs_n_new_quotes = []
        for i, tbg in enumerate(tbgs):
            # Update the set of base strings considered as we go
            filtered_relems, new_strings = get_filtered_relems_and_strings(tbg,
                                                                           None if i == 0 else new_strings,
                                                                           None if i == 0 else new_strings)#prevtbg.strings)
            prevtbg = tbg

            if i > 0:
                max_new_qts_per_tbg = max(max_new_qts_per_tbg, len(new_strings))
            print_cluster[1].append(([q for q in c.quotes.itervalues() if q.string in tbg.strings],
                                     [q for q in c.quotes.itervalues() if q.string in new_strings]))
            
            # Update number of new strings
            if 0 < i and i < n_tbgs_new_quotes:
                tbgs_n_new_quotes.append(len(new_strings))
            
            # For each feature
            for fsrc, fsrc_values in features.iteritems():
                for ftype, feature in fsrc_values.iteritems():
            
                    # Get the feature values for the extracted words
                    tbg_empirical_features = [feature[relem] for relem in filtered_relems if relem in feature]
                    try:
                        # Either add it to the existing list
                        empirical_features[fsrc][ftype][i].extend(tbg_empirical_features)
                    except IndexError:
                        # Or create the list for this timebag if necessary
                        empirical_features[fsrc][ftype].append(tbg_empirical_features)
                        # Then check that the item we just created was indeed for the right timebag.
                        empirical_features[fsrc][ftype][i]
                        
        new_quotes_counts.append(np.array(tbgs_n_new_quotes))
        if max_new_qts_per_tbg > 0:
            print_clusters.append(print_cluster)
    
    # Convert to numpy arrays
    print 'Kept {} clusters.'.format(n_clusters_kept)
    np_new_quotes_counts = np.array(new_quotes_counts)
    for fsrc, fsrc_values in features.iteritems():
        for ftype in fsrc_values.iterkeys():
            for i, all_tbg_empirical_features in enumerate(empirical_features[fsrc][ftype]):
                empirical_features[fsrc][ftype][i] = np.array(all_tbg_empirical_features)
    
    # Save to disk
    ps.save(empirical_features, 'data/analyses/empirical_features_recursive_min-20-tbgs.pickle')
    ps.save(np_new_quotes_counts, 'data/analyses/new_quotes_counts_recursive_min-20-tbgs.pickle')
# Out:
#   10 % (5548 / 55483 clusters)
#   20 % (11096 / 55483 clusters)
#   30 % (16644 / 55483 clusters)
#   40 % (22192 / 55483 clusters)
#   50 % (27740 / 55483 clusters)
#   60 % (33288 / 55483 clusters)
#   70 % (38836 / 55483 clusters)
#   80 % (44384 / 55483 clusters)
#   90 % (49932 / 55483 clusters)
#   100 % (55480 / 55483 clusters)
# Kept 27104 clusters.

# %%
import matplotlib.pyplot as plt
bins = np.linspace(0, np_new_quotes_counts.max(), np_new_quotes_counts.max() + 1) - 0.5
fig, axs = plt.subplots(1, 10, figsize=(20, 2))
for i in range(10):
    axs[i].hist(np_new_quotes_counts[:, i], bins=bins, log=True)
    axs[i].set_xlim(bins[0], bins[-1])

# %%
len(print_clusters)
# Out:
# 456

# %%
def plot_cluster_novelty(c, tbgs_details):
    n_tbgs_shown = 30
    blue = sb.color_palette()[5]
    red = sb.color_palette()[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(15, 3))
    ax.set_title('Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq))
    ax.set_xlim(- 0.5, n_tbgs_shown - 0.5)
    ax.set_ylim(- 0.5, c.n_quotes - 0.5)
    ax.set_xticks(range(n_tbgs_shown))
    ax.set_yticks(range(c.n_quotes))
    
    qt_coords = dict((q.id, i) for i, q in enumerate(c.quotes.itervalues()))
    for i, tbg_details in enumerate(tbgs_details[:n_tbgs_shown]):
        tbg_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[0]])
        tbg_new_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[1]])
        ax.plot(np.ones_like(tbg_qt_coords) * i, tbg_qt_coords, 'o', color=blue, markersize=8)
        ax.plot(np.ones_like(tbg_new_qt_coords) * i, tbg_new_qt_coords, 'o', color=red, markersize=12)
    fig.show()


#plot_cluster_novelty(print_clusters[1][0], print_clusters[1][1])
for c, tbgs_details in print_clusters[:10]:
    plot_cluster_novelty(c, tbgs_details)
# Out:
# /home/sl/.virtualenvs/brainscopypaste/src/matplotlib/lib/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
for c, tbgs_details in print_clusters[:10]:
    print '### Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq)
    for i, tbg_details in enumerate(tbgs_details):
        if i >= 10:
            break
        print ' ## Bag {}'.format(i)
        for q in tbg_details[0]:
            print '  {} {} [#{}]'.format('n' if q in tbg_details[1] else ' ', q.string, q.id)
    print
# Out:
# ### Cluster #472352, 5 quotes, total freq 79
#  ## Bag 0
#   n you know what today is [#277907]
#   n do you know what today is [#246120]
#  ## Bag 1
#   n do you know what that is [#356105]
#  ## Bag 2
#  ## Bag 3
#  ## Bag 4
#     do you know what that would have meant the net effect is it would have effectively shut down mortgage lending in that state [#472352]
#  ## Bag 5
#     do you know what that is [#356105]
#     do you know what that would have meant the net effect is it would have effectively shut down mortgage lending in that state [#472352]
#     do you know what today is [#246120]
#  ## Bag 6
#     do you know what that would have meant the net effect is it would have effectively shut down mortgage lending in that state [#472352]
#  ## Bag 7
#     do you know what that is [#356105]
#  ## Bag 8
#     do you know what that was [#616995]
#  ## Bag 9
#     do you know what that is [#356105]
#
# ### Cluster #702548, 3 quotes, total freq 15
#  ## Bag 0
#   n i decided i won't wear that pin on my chest instead i'm going to try to tell the american people what i believe will make this country great and hopefully that will be a testament to my patriotism [#224696]
#  ## Bag 1
#     i decided i won't wear that pin on my chest instead i'm going to try to tell the american people what i believe will make this country great and hopefully that will be a testament to my patriotism [#224696]
#   n i decided i won't wear that pin on my chest instead i'm going to try to tell the american people what i believe will make this country great and hopefully that will be a testimony to my patriotism [#276073]
#  ## Bag 2
#     i decided i won't wear that pin on my chest instead i'm going to try to tell the american people what i believe will make this country great and hopefully that will be a testimony to my patriotism [#276073]
#  ## Bag 3
#  ## Bag 4
#  ## Bag 5
#  ## Bag 6
#  ## Bag 7
#  ## Bag 8
#  ## Bag 9
#
# ### Cluster #1952654, 7 quotes, total freq 359
#  ## Bag 0
#   n we don't have time [#132980]
#  ## Bag 1
#   n we don't have to [#237584]
#  ## Bag 2
#   n we don't have time [#132980]
#  ## Bag 3
#  ## Bag 4
#     we don't have time [#132980]
#     we don't have to [#237584]
#  ## Bag 5
#  ## Bag 6
#  ## Bag 7
#     we don't have time [#132980]
#  ## Bag 8
#     we don't have time [#132980]
#     we don't have any water to waste [#563000]
#  ## Bag 9
#
# ### Cluster #98279, 13 quotes, total freq 329
#  ## Bag 0
#   n the sin of the world [#85960]
#   n lamb of god who takes away the sins of the world [#81084]
#   n take away the sins of the world [#115313]
#   n the lamb of god who takes away the sin of the world [#115319]
#   n look the lamb of god who takes away the sin of the world [#113740]
#   n behold the lamb of god [#102767]
#   n behold the lamb of god who takes away the sin of the world [#98279]
#   n behold the lamb of god who takes away the sins of the world [#115314]
#  ## Bag 1
#     look the lamb of god who takes away the sin of the world [#113740]
#   n look the lamb of god [#216692]
#     behold the lamb of god [#102767]
#     behold the lamb of god who takes away the sin of the world [#98279]
#     behold the lamb of god who takes away the sins of the world [#115314]
#  ## Bag 2
#     lamb of god who takes away the sin of the world [#238221]
#   n behold the lamb of god [#102767]
#     behold the lamb of god who takes away the sin of the world [#98279]
#  ## Bag 3
#     behold the lamb of god [#102767]
#  ## Bag 4
#     behold the lamb of god [#102767]
#  ## Bag 5
#     the lamb of god who takes away the sins of the world [#406944]
#     behold the lamb of god [#102767]
#     behold the lamb of god who takes away the sin of the world [#98279]
#  ## Bag 6
#     the lamb of god who takes away the sin of the world [#115319]
#     look the lamb of god [#216692]
#     behold the lamb of god [#102767]
#  ## Bag 7
#     look the lamb of god who takes away the sin of the world [#113740]
#     behold the lamb of god who takes away the sin of the world [#98279]
#  ## Bag 8
#     lamb of god who takes away the sin of the world [#238221]
#     the lamb of god who takes away the sin of the world [#115319]
#     look the lamb of god [#216692]
#     behold the lamb of god [#102767]
#     behold the lamb of god who takes away the sins of the world [#115314]
#  ## Bag 9
#     behold the lamb of god [#102767]
#     behold the lamb of god who takes away the sin of the world [#98279]
#     behold the lamb of god who takes away the sins of the world [#115314]
#
# ### Cluster #308437, 8 quotes, total freq 92
#  ## Bag 0
#   n is there anything i can help you with [#60553]
#   n good anything i can help you with [#33246]
#  ## Bag 1
#   n is there something i can help you with [#157449]
#  ## Bag 2
#     is there something i can help you with [#157449]
#  ## Bag 3
#     is there anything else i can help you with today [#253682]
#  ## Bag 4
#     is there anything else i can help you with [#308437]
#  ## Bag 5
#     is there anything else i can help you with today [#253682]
#     is there anything else i can help you with [#308437]
#  ## Bag 6
#  ## Bag 7
#     is there anything i can help you with [#60553]
#     is there something i can help you with [#157449]
#  ## Bag 8
#     good anything i can help you with [#33246]
#  ## Bag 9
#
# ### Cluster #449708, 5 quotes, total freq 259
#  ## Bag 0
#   n approaching a pull-the-plug kind of decision [#463818]
#   n this is like a last stand for webcasting [#449709]
#   n we're approaching a pull-the-plug kind of decision this is like a last stand for webcasting [#475293]
#   n we're approaching a pull-the-plug kind of decision [#449708]
#  ## Bag 1
#   n we're reaching a pull-the-plug kind of decision this is like a last stand for webcasting [#500673]
#     approaching a pull-the-plug kind of decision [#463818]
#     this is like a last stand for webcasting [#449709]
#     we're approaching a pull-the-plug kind of decision this is like a last stand for webcasting [#475293]
#     we're approaching a pull-the-plug kind of decision [#449708]
#  ## Bag 2
#     approaching a pull-the-plug kind of decision [#463818]
#     this is like a last stand for webcasting [#449709]
#   n we're approaching a pull-the-plug kind of decision this is like a last stand for webcasting [#475293]
#     we're approaching a pull-the-plug kind of decision [#449708]
#  ## Bag 3
#     this is like a last stand for webcasting [#449709]
#     we're approaching a pull-the-plug kind of decision this is like a last stand for webcasting [#475293]
#     we're approaching a pull-the-plug kind of decision [#449708]
#  ## Bag 4
#     this is like a last stand for webcasting [#449709]
#     we're approaching a pull-the-plug kind of decision [#449708]
#  ## Bag 5
#     approaching a pull-the-plug kind of decision [#463818]
#     we're approaching a pull-the-plug kind of decision this is like a last stand for webcasting [#475293]
#  ## Bag 6
#     this is like a last stand for webcasting [#449709]
#  ## Bag 7
#  ## Bag 8
#  ## Bag 9
#
# ### Cluster #221651, 3 quotes, total freq 54
#  ## Bag 0
#   n greenest tech company on the planet [#229777]
#   n the greenest technology company on the planet [#221651]
#  ## Bag 1
#   n greenest technology company on the planet [#262389]
#     the greenest technology company on the planet [#221651]
#  ## Bag 2
#  ## Bag 3
#  ## Bag 4
#  ## Bag 5
#  ## Bag 6
#  ## Bag 7
#  ## Bag 8
#  ## Bag 9
#
# ### Cluster #270807, 7 quotes, total freq 114
#  ## Bag 0
#   n you will know them by their fruits [#270807]
#   n you shall know them by their fruits [#232072]
#  ## Bag 1
#     you will know them by their fruits [#270807]
#   n you will recognize them by their fruits [#310062]
#  ## Bag 2
#   n you will know them by their fruits [#270807]
#     so then you will know them by their fruits [#340009]
#  ## Bag 3
#     you will know them by their fruits [#270807]
#     so then you will know them by their fruits [#340009]
#  ## Bag 4
#  ## Bag 5
#     you shall know them by their fruits [#232072]
#  ## Bag 6
#     you shall know them by their fruit [#521119]
#     you will know them by their fruits [#270807]
#  ## Bag 7
#     you will know them by their fruits [#270807]
#  ## Bag 8
#     know them by their fruits [#615155]
#     you will know them by their fruit [#616042]
#  ## Bag 9
#     you shall know them by their fruits [#232072]
#
# ### Cluster #683632, 2 quotes, total freq 52
#  ## Bag 0
#   n tim and tom an american comedy in black and white [#683632]
#  ## Bag 1
#   n tim amp tom an american comedy in black and white [#734505]
#  ## Bag 2
#  ## Bag 3
#  ## Bag 4
#  ## Bag 5
#  ## Bag 6
#  ## Bag 7
#  ## Bag 8
#  ## Bag 9
#     tim and tom an american comedy in black and white [#683632]
#
# ### Cluster #2627238, 9 quotes, total freq 338
#  ## Bag 0
#   n what how do you know that [#61814]
#   n how do you know that [#61683]
#  ## Bag 1
#     how do you know that [#61683]
#   n and how do you know that [#153378]
#     what how do you know [#136890]
#  ## Bag 2
#     how do you know all that [#238806]
#  ## Bag 3
#     how do you know all that [#238806]
#     how do you know that [#61683]
#     and how do you know that [#153378]
#  ## Bag 4
#     how do you know that [#61683]
#  ## Bag 5
#     how do you know that [#61683]
#     how do you justify that [#369866]
#  ## Bag 6
#     how do you know that [#61683]
#  ## Bag 7
#     how do you know that [#61683]
#  ## Bag 8
#     how do you know that [#61683]
#  ## Bag 9
#     how do you know that [#61683]

# %% [markdown]
# ## A quick check
#
# Just to have a look, here we count the average number of *new* quotes that appear in the first ten timebags of each cluster (*new* according to the definition above).

# %%
x = np.arange(1, n_tbgs_new_quotes)
y = np_new_quotes_counts.mean(0)
ci = 1.96 * np_new_quotes_counts.std(0) / np.sqrt(len(np_new_quotes_counts[:, 0]) - 1)
mpl.pyplot.plot(x, np_new_quotes_counts.mean(0))
mpl.pyplot.fill_between(x, y - ci, y + ci, alpha=0.2, color='grey')

# %% [markdown]
# ## Plot the results
#
# We now plot the distribution of features for novel quotes, for each feature, for a number of timebags. And see if it evolves.

# %%
# How many bins we want
nbins = 10

# How many timebags to plot
n_timebags_shown = 10

# Step between two plotted timebags
n_timebags_step = 2

# For each feature
for fsrc, fsrc_empirical_values in empirical_features.iteritems():
    for ftype, tbgs_empirical_values in fsrc_empirical_values.iteritems():
        
        # Check if we're using a log-scale
        if st.mt_analysis_features[fsrc][ftype]['log']:
            log = True
            logtext = ' (log)'
        else:
            log = False
            logtext = ''
        
        # Create axes
        fig, axs = mpl.pyplot.subplots(1, n_timebags_shown, figsize=(20, 3), sharex=True)
        fig.text(0.5, 1, '{} {}'.format(fsrc, ftype.replace('_', ' ')) + logtext)
        
        # Convert values
        vals = []
        for lvals in tbgs_empirical_values[:n_timebags_shown * n_timebags_step:n_timebags_step]:
            
            if log:
                vals.append(np.log(lvals))
            else:
                vals.append(lvals)
            
        names = ['tbg {}'.format(i) for i in range(0, n_timebags_shown * n_timebags_step, n_timebags_step)]
        
        # Add histograms
        for i in range(n_timebags_shown):
            if i == 0:
                bins = axs[i].hist(vals[i], bins=nbins, log=log, normed=True, color="#6495ED")[1]
            else:
                axs[i].hist(vals[i], bins=bins, log=log, normed=True, color="#6495ED")
            axs[i].set_xlabel('tbg {} ({} pts)'.format(i * n_timebags_step, len(vals[i])))
            axs[i].set_xlim([bins.min(), bins.max()])
            axs[i].set_xticklabels(axs[i].get_xticks(), rotation=60)
