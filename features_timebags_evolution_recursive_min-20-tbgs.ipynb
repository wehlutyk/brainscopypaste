# %% [markdown]
# # How does the distribution of features evolve when we go through the timebags?

# %% [markdown]
# ## Some loading and prep code

# %%
# First some imports
import numpy as np
import matplotlib as mpl
import seaborn as sb
# %matplotlib inline

import settings as st
from linguistics.treetagger import get_tagger
from linguistics.wn import lemmatize as relemmatize
from datainterface.redistools import RedisReader
import datainterface.picklesaver as ps
from util.generic import ProgressInfo
tagger = get_tagger()

# %%
# Load the clusters, the features, and initialize the results
clusters = RedisReader(st.redis_mt_clusters_filtered_pref)
features = dict((fsrc, dict((ftype, ps.load(fdetails['file'].format('all')))
                            for ftype, fdetails in fsrc_details.iteritems()))
                for fsrc, fsrc_details in st.mt_analysis_features.iteritems())
empirical_features = dict((fsrc, dict((ftype, [])
                                      for ftype in fsrc_values.iterkeys()))
                          for fsrc, fsrc_values in features.iteritems())

# %%
from linguistics.distance import hamming_word
    
def is_in_sphere(ref_strings, string):
    """Whether or not `string` is in the hamming_word-sphere at
    distance 1 surrounding the `ref_strings`."""
    
    for ref_str in ref_strings:
        if hamming_word(ref_str, string) == 1:
            return True
    return False


def get_filtered_relems_and_strings(tbg, ref_strings, excl_strings):
    """List the relemmatized words (once per occurrence) appearing in `tbg`,
    and at distance one from `ref_strings`, excluding strings in `excl_strings`.
    
    Quotes are first lemmatized with the TreeTagger lemmatizer, then
    relemmatized as in the mining analysis, with the WordNet morphy
    method.
    
    Parameters
    ----------
    tbg : TimeBag
        The timebag to work on.
    ref_strings : list of strings
        The reference string from which to compute distance; if None, then ignored.
    excl_strings : list of strings
        The reference string from which to exclude; if None, then ignored.
    
    Returns
    -------
    list
        The list of relemmatized words.
    set
        The set of new strings considered to the product of this iteration.
    
    """
    
    filtered_relems = []
    new_strings = set([])

    for string, freq in zip(tbg.strings, tbg.tot_freqs):
        # If our current string is in the set of banned strings,
        # jump to next one
        if excl_strings is not None and string in excl_strings:
            continue
        
        # If our current string is not in the sphere around ref_strings,
        # jump to next one
        if ref_strings is not None and not is_in_sphere(ref_strings, string):
            continue

        new_strings.add(string)
        relems = [relemmatize(lem) for lem in tagger.Lemmatize(string)]
        filtered_relems.extend(relems * freq)

    return filtered_relems, new_strings

# %% [markdown]
# ## The analysis itself
#
# We want to look at the distribution of features in *new* quotes produced by susbtitution (i.e. not those reinjected from outside as part of the continuous process). So for each cluster, we look at the first timebag, and take it as a reference and include all quotes in the second timebag that aren't in the first but are at distance *d* from a quote in the first. We repeat this operation for each later timebag, but basing ourselves on the set of new quotes produced by the previous step. Then on each of these sets of quotes, we compute the distribution of features. This gives us the distribution of features on the novel quotes.

# %%
# Duration of a timebag, in days
timebag_size = 2.0
# Minimum number of timebags a cluster must have to be included in the analysis
min_number_of_timebags = 20 
# Number of timebags included in 'new quotes' plot below
n_tbgs_new_quotes = 20

# %%
try:
    raise IOError
    # See if we already computed this
    empirical_features = ps.load('data/analyses/empirical_features_recursive_min-20-tbgs_no-exclusion.pickle')
    np_new_quotes_counts = ps.load('data/analyses/new_quotes_counts_recursive_min-20-tbgs_no-exclusion.pickle')
    print 'Loaded from pickle.'
except IOError:
    n_clusters_kept = 0
    new_quotes_counts = []
    print_clusters = []
    
    # A progress indicator
    progress = ProgressInfo(len(clusters), 10, 'clusters')
    
    # For each cluster
    for c in clusters.itervalues():
        progress.next_step()
        
        # Build timebags, skip if we don't have enough bags
        tbgs = c.build_timebags(timebag_size)
        if len(tbgs) < min_number_of_timebags:
            continue
        
        print_cluster = (c, [])
        max_new_qts_per_tbg = 0
        
        n_clusters_kept += 1
        tbgs_n_new_quotes = []
        for i, tbg in enumerate(tbgs):
            # Update the set of base strings considered as we go
            filtered_relems, new_strings = get_filtered_relems_and_strings(tbg,
                                                                           None if i == 0 else new_strings,
                                                                           None) # no exclusion
            prevtbg = tbg

            if i > 0:
                max_new_qts_per_tbg = max(max_new_qts_per_tbg, len(new_strings))
            print_cluster[1].append(([q for q in c.quotes.itervalues() if q.string in tbg.strings],
                                     [q for q in c.quotes.itervalues() if q.string in new_strings]))
            
            # Update number of new strings
            if 0 < i and i < n_tbgs_new_quotes:
                tbgs_n_new_quotes.append(len(new_strings))
            
            # For each feature
            for fsrc, fsrc_values in features.iteritems():
                for ftype, feature in fsrc_values.iteritems():
            
                    # Get the feature values for the extracted words
                    tbg_empirical_features = [feature[relem] for relem in filtered_relems if relem in feature]
                    try:
                        # Either add it to the existing list
                        empirical_features[fsrc][ftype][i].extend(tbg_empirical_features)
                    except IndexError:
                        # Or create the list for this timebag if necessary
                        empirical_features[fsrc][ftype].append(tbg_empirical_features)
                        # Then check that the item we just created was indeed for the right timebag.
                        empirical_features[fsrc][ftype][i]
                        
        new_quotes_counts.append(np.array(tbgs_n_new_quotes))
        if max_new_qts_per_tbg > 0:
            print_clusters.append(print_cluster)
    
    # Convert to numpy arrays
    print 'Kept {} clusters.'.format(n_clusters_kept)
    np_new_quotes_counts = np.array(new_quotes_counts)
    for fsrc, fsrc_values in features.iteritems():
        for ftype in fsrc_values.iterkeys():
            for i, all_tbg_empirical_features in enumerate(empirical_features[fsrc][ftype]):
                empirical_features[fsrc][ftype][i] = np.array(all_tbg_empirical_features)
    
    # Save to disk
    ps.save(empirical_features, 'data/analyses/empirical_features_recursive_min-20-tbgs_no-exclusion.pickle')
    ps.save(np_new_quotes_counts, 'data/analyses/new_quotes_counts_recursive_min-20-tbgs_no-exclusion.pickle')
# Out:
#   10 % (5548 / 55483 clusters)
#   20 % (11096 / 55483 clusters)
#   30 % (16644 / 55483 clusters)
#   40 % (22192 / 55483 clusters)
#   50 % (27740 / 55483 clusters)
#   60 % (33288 / 55483 clusters)
#   70 % (38836 / 55483 clusters)
#   80 % (44384 / 55483 clusters)
#   90 % (49932 / 55483 clusters)
#   100 % (55480 / 55483 clusters)
# Kept 27104 clusters.

# %%
import matplotlib.pyplot as plt
bins = np.linspace(0, np_new_quotes_counts.max(), np_new_quotes_counts.max() + 1) - 0.5
fig, axs = plt.subplots(1, 10, figsize=(20, 2), sharey=True)
for i in range(10):
    axs[i].hist(np_new_quotes_counts[:, i], bins=bins, log=True)
    axs[i].set_xlim(bins[0], bins[-1])

# %%
len(print_clusters)
# Out:
# 1216

# %%
# Find until which timebag clusters keep having new quotes
last_tbg_new_quotes = np.zeros(len(print_clusters), dtype=int)
for i, (c, tbgs_details) in enumerate(print_clusters):
    last_tbg_new_quotes[i] = np.array([len(tbg_details[1]) for tbg_details in tbgs_details]).nonzero()[0][-1]

bins = np.linspace(- 0.5, 20 + 0.5, 20 + 2)
plt.hist(last_tbg_new_quotes, bins=bins, log=True)
# Out:
# (array([   0.,  674.,  278.,  130.,   47.,   25.,   17.,    8.,    4.,
#           6.,   10.,    3.,    4.,    2.,    1.,    0.,    1.,    1.,
#           0.,    0.,    0.]),
#  array([ -0.5,   0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,
#          8.5,   9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,
#         17.5,  18.5,  19.5,  20.5]),
#  <a list of 21 Patch objects>)

# %%
def plot_cluster_novelty(c, tbgs_details):
    n_tbgs_shown = 30
    blue = sb.color_palette()[5]
    red = sb.color_palette()[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(15, 3))
    ax.set_title('Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq))
    ax.set_xlim(- 0.5, n_tbgs_shown - 0.5)
    ax.set_ylim(- 0.5, c.n_quotes - 0.5)
    ax.set_xticks(range(n_tbgs_shown))
    ax.set_yticks(range(c.n_quotes))
    
    qt_coords = dict((q.id, i) for i, q in enumerate(c.quotes.itervalues()))
    for i, tbg_details in enumerate(tbgs_details[:n_tbgs_shown]):
        tbg_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[0]])
        tbg_new_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[1]])
        ax.plot(np.ones_like(tbg_qt_coords) * i, tbg_qt_coords, 'o', color=blue, markersize=8)
        ax.plot(np.ones_like(tbg_new_qt_coords) * i, tbg_new_qt_coords, 'o', color=red, markersize=12)
    fig.show()


#plot_cluster_novelty(print_clusters[1][0], print_clusters[1][1])
for i in np.where(last_tbg_new_quotes >= 10)[0]:
    c, tbgs_details = print_clusters[i]
    plot_cluster_novelty(c, tbgs_details)

# %%
for i in np.where(last_tbg_new_quotes >= 10)[0]:
    c, tbgs_details = print_clusters[i]
    print '### Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq)
    for i, tbg_details in enumerate(tbgs_details):
        if i >= 10:
            break
        print ' ## Bag {}'.format(i)
        for q in tbg_details[0]:
            print '  {} {} [#{}]'.format('n' if q in tbg_details[1] else ' ', q.string, q.id)
    print
# Out:
# ### Cluster #80230, 10 quotes, total freq 441
#  ## Bag 0
#   n i and my father are one [#80230]
#   n i and the father are one [#15347]
#  ## Bag 1
#   n i and my father are one [#80230]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 2
#   n i and my father are one [#80230]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 3
#   n i and my father are one [#80230]
#     my sheep hear my voice [#267322]
#     my sheep listen to my voice i know them and they follow me [#267646]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 4
#   n i and my father are one [#80230]
#     my sheep listen to my voice i know them and they follow me [#267646]
#   n i and the father are one [#15347]
#  ## Bag 5
#   n i and my father are one [#80230]
#     my sheep listen to my voice i know them and they follow me [#267646]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 6
#   n i and my father are one [#80230]
#     my sheep listen to my voice i know them and they follow me [#267646]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 7
#     i and my father are one [#80230]
#     i know them and they follow me and i give them eternal life and they shall never perish and no one shall snatch them out of my hand [#450040]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#  ## Bag 8
#   n i and my father are one [#80230]
#     i and the father are one [#15347]
#  ## Bag 9
#     i and my father are one [#80230]
#   n i and the father are one [#15347]
#     my sheep hear my voice and i know them and they follow me [#99532]
#
# ### Cluster #21555, 14 quotes, total freq 549
#  ## Bag 0
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approve of this message [#82264]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 1
#     and i approved this message [#157852]
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approve this ad [#111817]
#     i'm john mccain and i approve this message a president has to be funny they just have to be [#176288]
#     i'm john mccain and i approve of this message [#82264]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 2
#   n i am john mccain and i approve this message [#187658]
#     and i approve this message [#209761]
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approved this ad [#224659]
#     i'm john mccain and i approve this message a president has to be funny they just have to be [#176288]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 3
#     i approve of this message [#250378]
#     and i approved this message [#157852]
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approved this ad [#224659]
#   n i'm john mccain and i approve this ad [#111817]
#     i'm john mccain and i approve this message a president has to be funny they just have to be [#176288]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 4
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approved this ad [#224659]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 5
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approved this ad [#224659]
#   n i'm john mccain and i approve this ad [#111817]
#  ## Bag 6
#   n i'm john mccain and i approved this message [#21555]
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 7
#   n i'm john mccain and i approved this message [#21555]
#  ## Bag 8
#   n i'm john mccain and i approve this message [#40545]
#  ## Bag 9
#   n i'm john mccain and i approved this message [#21555]
#
# ### Cluster #19122, 16 quotes, total freq 673
#  ## Bag 0
#   n all have sinned and fallen short of the glory of god [#16098]
#   n for all have sinned and come short of the glory of god [#19122]
#   n for all have sinned and fall short of the glory of god [#72079]
#   n sinned and fallen short of the glory of god [#61159]
#  ## Bag 1
#     for all have sinned and fall short of the glory of god and are justified by his grace as a gift through the redemption that is in christ jesus [#101046]
#   n for all have sinned and come short of the glory of god [#19122]
#   n all have sinned and fall short of the glory of god [#99286]
#   n all have sinned and come short of the glory of god [#105825]
#     falling short of the glory of god [#147322]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 2
#   n all have sinned and fallen short of the glory of god [#16098]
#   n for all have sinned and come short of the glory of god [#19122]
#   n all have sinned and come short of the glory of god [#105825]
#   n for all have sinned and fall short of the glory of god [#72079]
#     sinned and fallen short of the glory of god [#61159]
#  ## Bag 3
#     f or all have sinned and fall short of the glory of god [#246414]
#   n all have sinned and fallen short of the glory of god [#16098]
#   n for all have sinned and come short of the glory of god [#19122]
#   n all have sinned and fall short of the glory of god [#99286]
#   n all have sinned and come short of the glory of god [#105825]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 4
#   n for all have sinned and fallen short of the glory of god [#280697]
#     for all have sinned and fall short of the glory of god and are justified by his grace as a gift through the redemption that is in christ jesus [#101046]
#   n for all have sinned and come short of the glory of god [#19122]
#   n all have sinned and fall short of the glory of god [#99286]
#   n all have sinned and come short of the glory of god [#105825]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 5
#   n for all have sinned and fallen short of the glory of god [#280697]
#   n for all have sinned and come short of the glory of god [#19122]
#  ## Bag 6
#   n for all have sinned and come short of the glory of god [#19122]
#     all have sinned and fall short of the glory of god [#99286]
#     all have sinned and come short of the glory of god [#105825]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 7
#   n for all have sinned and fallen short of the glory of god [#280697]
#   n for all have sinned and come short of the glory of god [#19122]
#     all have sinned and fall short of the glory of god [#99286]
#     all have sinned and come short of the glory of god [#105825]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 8
#     f or all have sinned and fall short of the glory of god [#246414]
#   n for all have sinned and come short of the glory of god [#19122]
#     all have sinned and fall short of the glory of god [#99286]
#   n for all have sinned and fall short of the glory of god [#72079]
#  ## Bag 9
#     this righteousness from god comes through faith in jesus christ to all who believe there is no difference for all have sinned and fall short of the glory of god and are justified freely by his grace through the redemption that came by christ jesus [#520887]
#   n for all have sinned and come short of the glory of god [#19122]
#     all have sinned and fall short of the glory of god [#99286]
#   n for all have sinned and fall short of the glory of god [#72079]
#     sinned and fallen short of the glory of god [#61159]
#
# ### Cluster #46588, 2 quotes, total freq 171
#  ## Bag 0
#   n harold amp kumar go to white castle [#25274]
#   n harold and kumar go to white castle [#46588]
#  ## Bag 1
#   n harold amp kumar go to white castle [#25274]
#  ## Bag 2
#   n harold and kumar go to white castle [#46588]
#  ## Bag 3
#   n harold amp kumar go to white castle [#25274]
#     harold and kumar go to white castle [#46588]
#  ## Bag 4
#     harold amp kumar go to white castle [#25274]
#   n harold and kumar go to white castle [#46588]
#  ## Bag 5
#   n harold amp kumar go to white castle [#25274]
#  ## Bag 6
#   n harold and kumar go to white castle [#46588]
#  ## Bag 7
#   n harold amp kumar go to white castle [#25274]
#  ## Bag 8
#   n harold and kumar go to white castle [#46588]
#  ## Bag 9
#   n harold amp kumar go to white castle [#25274]
#     harold and kumar go to white castle [#46588]
#
# ### Cluster #40929, 29 quotes, total freq 986
#  ## Bag 0
#   n what do you want to eat [#15871]
#   n what do you want to be when you grow up [#54162]
#   n what do you want to do [#40929]
#   n and what do you want to be when you grow up [#90750]
#   n what do you want it to equal [#13097]
#  ## Bag 1
#     what would you like to be when you grow up [#158047]
#   n what do you want to see [#110803]
#     do you want something to drink [#143270]
#     what do you want to be when you grow up [#54162]
#   n what do you want it to be [#154489]
#   n what do you want to be [#125101]
#   n what do you want to do [#40929]
#   n what do you want to know [#157347]
#  ## Bag 2
#   n what do you want to drink [#225902]
#   n what do you want to watch [#180946]
#   n what do you want to see [#110803]
#     what do you want to be when you grow up [#54162]
#   n what do you want to be [#125101]
#   n what do you want to do [#40929]
#   n what do you want it to equal [#13097]
#  ## Bag 3
#   n what do you want to drink [#225902]
#   n what do you want to say [#247476]
#   n what do you want to see [#110803]
#     what do you want to be when you grow up [#54162]
#   n what do you want it to be [#154489]
#  ## Bag 4
#   n what do you want to eat [#15871]
#     what do you want to be when you grow up [#54162]
#   n what do you want to be [#125101]
#   n what do you want to do [#40929]
#   n what do you want to know [#157347]
#  ## Bag 5
#   n where do you want to be [#331728]
#     what do you want to do before you die [#359627]
#     do you want something to drink [#143270]
#   n what do you want to learn [#329842]
#     what do you want to be when you grow up [#54162]
#     what do you want it to be [#154489]
#   n what do you want to do [#40929]
#     what you want to do [#325756]
#  ## Bag 6
#   n what do you want to drink [#225902]
#     what would you like to be when you grow up [#158047]
#     what do you want to do when you grow up [#420580]
#   n what do you want to eat [#15871]
#   n what do you want to say [#247476]
#     do you want something to drink [#143270]
#     what do you want to be when you grow up [#54162]
#   n what do you want to be [#125101]
#   n what do you want to do [#40929]
#     what you want to be when you grow up [#377774]
#  ## Bag 7
#   n what do you want to eat [#15871]
#     what do you want to be when you grow up [#54162]
#   n what do you want to be [#125101]
#     what did you want to be when you grew up [#447019]
#   n what do you want to do [#40929]
#     what you want to be when you grow up [#377774]
#   n what do you want to know [#157347]
#  ## Bag 8
#   n what do you want to drink [#225902]
#     what do you want to do when you grow up [#420580]
#   n what do you want to eat [#15871]
#     so what do you want to be when you grow up [#490129]
#   n what do you want to watch [#180946]
#   n what do you want to see [#110803]
#     what do you want to be when you grow up [#54162]
#     what did you want to be when you grew up [#447019]
#   n what do you want to do [#40929]
#   n what do you want to know [#157347]
#  ## Bag 9
#     do you want something to drink [#143270]
#     what do you want to be when you grow up [#54162]
#   n what do you want to be [#125101]
#   n what do you want to do [#40929]
#
# ### Cluster #22445, 5 quotes, total freq 869
#  ## Bag 0
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#  ## Bag 1
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#  ## Bag 2
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#  ## Bag 3
#   n back in the u s a [#285234]
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#  ## Bag 4
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#  ## Bag 5
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#  ## Bag 6
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#  ## Bag 7
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#  ## Bag 8
#   n made in the u s a [#57894]
#   n born in the u s a [#22445]
#  ## Bag 9
#   n born in the u s a [#22445]
#     back in the u s s r [#107108]
#
# ### Cluster #2146683, 23 quotes, total freq 1191
#  ## Bag 0
#   n they're not willing to give me anything except appreciation f k them [#2148420]
#   n but they're not willing to give me anything except appreciation [#2155392]
#   n they're not willing to give me anything except appreciation them [#2149767]
#   n not willing to give me anything except appreciation f them [#2146537]
#   n not willing to give me anything but appreciation [#2168884]
#   n blagojevich said he knew that the president-elect wanted senate candidate 1 for the open seat but they're not willing to give me anything except appreciation [#2146480]
#   n said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give blagojevich anything except appreciation [#2170842]
#   n blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat [#2162235]
#   n rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#   n but they're not willing to give me anything except appreciation fuck them [#2148726]
#   n they're not going to give me anything except appreciation [#2146545]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 1
#     but they're not willing to give me anything except appreciation [#2155392]
#     they're not willing to give me anything except appreciation them [#2149767]
#     not willing to give me anything except appreciation f them [#2146537]
#     blagojevich said he knew that the president-elect wanted senate candidate 1 for the open seat but they're not willing to give me anything except appreciation [#2146480]
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give blagojevich anything except appreciation [#2170842]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#   n they're not willing to give me anything but appreciation [#2185703]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 2
#     they're not willing to give me anything except appreciation f k them [#2148420]
#     they're not willing to give me anything except appreciation them [#2149767]
#   n not willing to give me anything but appreciation [#2168884]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give blagojevich anything except appreciation [#2170842]
#     rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#   n they're not willing to give me anything but appreciation [#2185703]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 3
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#     they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give me anything except appreciation [#2147828]
#   n they're not willing to give me anything but appreciation [#2185703]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 4
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 5
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#  ## Bag 6
#     they're not willing to give me anything except appreciation them [#2149767]
#     willing to give me anything except appreciation expletive them [#2291965]
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 7
#     but they're not willing to give me anything except appreciation [#2155392]
#     not willing to give me anything but appreciation [#2168884]
#     willing to give me anything except appreciation expletive them [#2291965]
#     not willing to give me anything [#2319601]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#     blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat [#2162235]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 8
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 9
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#     not willing to give me anything except appreciation [#2147828]
#
# ### Cluster #13902, 22 quotes, total freq 910
#  ## Bag 0
#   n what else can i do for you [#2731]
#   n what can i get for you [#24239]
#   n what can i get for ya [#19879]
#   n what can i do for you [#13902]
#   n now what can i do for you [#41396]
#   n what can i do for you today [#17301]
#  ## Bag 1
#   n what can brown do for you [#118681]
#   n what can i do for you [#13902]
#     now what can i do for you [#41396]
#     what can i do for you today [#17301]
#  ## Bag 2
#     so what can i do [#200585]
#   n what can i get for you [#24239]
#     what can i get you [#190796]
#   n what can brown do for you [#118681]
#   n what can i do for you [#13902]
#     what can i do for you son [#231663]
#  ## Bag 3
#     so what can i do [#200585]
#   n what can i get for you [#24239]
#     yes what can i do for you [#273488]
#     what can i get you [#190796]
#   n what can i do for you [#13902]
#     now what can i do for you [#41396]
#  ## Bag 4
#     so what can i do [#200585]
#     yes what can i do for you [#273488]
#     so what can i do for you [#303357]
#     what can i get you [#190796]
#   n what can i do for you [#13902]
#     what can i do for you today [#17301]
#     good evening gentlemen what can i do for you [#289267]
#  ## Bag 5
#     what can i get for ya [#19879]
#   n what can brown do for you [#118681]
#     what can i do for you [#13902]
#   n what can we do for you [#351822]
#     good evening gentlemen what can i do for you [#289267]
#  ## Bag 6
#     so what can i do [#200585]
#     what can i get for you [#24239]
#     yes what can i do for you [#273488]
#     so what can i do for you [#303357]
#     what can i get you [#190796]
#   n what can i do for you [#13902]
#  ## Bag 7
#   n what can i get for you [#24239]
#     what can i get you [#190796]
#   n what can brown do for you [#118681]
#     what can i do for you [#13902]
#     now what can i do for you [#41396]
#   n what can we do for you [#351822]
#     what can i do for you today [#17301]
#  ## Bag 8
#     what can i do for others [#495424]
#     what can i get you [#190796]
#   n what can i do for you [#13902]
#     what can i do for you son [#231663]
#  ## Bag 9
#     can i do anything for you [#509575]
#     what can i get you [#190796]
#   n what can brown do for you [#118681]
#     what can i do for you [#13902]
#   n what can we do for you [#351822]
#     what can i do for you today [#17301]
#
# ### Cluster #10600, 28 quotes, total freq 1548
#  ## Bag 0
#   n i've never seen anything like it [#10600]
#   n we've never seen anything like this before [#80265]
#   n i've never done anything like this before [#8]
#   n i've never seen anything like that [#66157]
#   n never seen anything like it [#17665]
#  ## Bag 1
#   n i've never seen anything like it [#10600]
#   n i've never seen anything like that [#66157]
#   n i've never seen anything like this [#98336]
#  ## Bag 2
#     i've never seen anything like that before [#217690]
#   n i've never seen anything like it [#10600]
#     we've never seen anything like this before [#80265]
#     never seen anything like this [#208167]
#     never seen anything like it [#17665]
#   n i've never seen anything like this [#98336]
#     and i've never seen anything like this [#175327]
#  ## Bag 3
#     i've never seen anything like that before [#217690]
#   n i've never seen anything like it [#10600]
#     i've never done anything like this before [#8]
#     never seen anything like it [#17665]
#     i've never seen anything like this before [#264507]
#   n i've never seen anything like this [#98336]
#  ## Bag 4
#   n i've never seen anything like it [#10600]
#     never seen anything like it [#17665]
#   n i've never seen anything like this [#98336]
#  ## Bag 5
#     i've never seen anything like this in my career for software [#324894]
#     i've never seen anything like that before [#217690]
#     1 billion marketplace at some point in time [#324079]
#     who knows maybe it will be a 1 billion marketplace at some point in time i've never seen anything like this in my career for software [#327896]
#     it will be a 1 billion marketplace at some point in time [#328325]
#   n i've never seen anything like it [#10600]
#     we've never seen anything like this before [#80265]
#     never seen anything like this in my career for software [#325317]
#     never seen anything like it [#17665]
#     i've never seen anything like this before [#264507]
#   n i've never seen anything like this [#98336]
#     who knows maybe it will be a 1 billion marketplace at some point in time [#326508]
#  ## Bag 6
#     i've never seen anything like this in my career for software [#324894]
#     who knows maybe it will be a 1 billion marketplace at some point in time i've never seen anything like this in my career for software [#327896]
#   n i've never seen anything like it [#10600]
#     i've never done anything like this before [#8]
#   n i've never seen anything like that [#66157]
#     i've never seen anything like this before [#264507]
#   n i've never seen anything like this [#98336]
#     who knows maybe it will be a 1 billion marketplace at some point in time [#326508]
#  ## Bag 7
#     i've never seen anything like this in my career for software [#324894]
#   n i've never seen anything like it [#10600]
#     i've never done anything like this before [#8]
#     never seen anything like this before [#433968]
#     never seen anything like this in my career for software [#325317]
#     who knows maybe it will be a 1bn marketplace at some point in time i've never seen anything like this in my career for software [#452722]
#     i've never seen anything like this before [#264507]
#   n i've never seen anything like this [#98336]
#     who knows maybe it will be a 1 billion marketplace at some point in time [#326508]
#  ## Bag 8
#     i've never seen anything like this in my career for software [#324894]
#   n i've never seen anything like it [#10600]
#     who knows maybe it will be a 1bn marketplace at some point in time i've never seen anything like this in my career for software [#452722]
#   n i'd never seen anything like this [#490610]
#   n i've never done anything like this [#489733]
#   n i've never seen anything like this [#98336]
#  ## Bag 9
#     i've never seen anything like this in my career for software [#324894]
#   n i've never seen anything like it [#10600]
#     i've never done anything like this before [#8]
#     who knows maybe it will be a 1bn marketplace at some point in time i've never seen anything like this in my career for software [#452722]
#   n we've never seen anything like this [#540979]
#     i've never seen anything like this before [#264507]
#   n i've never seen anything like this [#98336]
#
# ### Cluster #16694, 9 quotes, total freq 223
#  ## Bag 0
#   n by their fruits ye shall know them [#16694]
#  ## Bag 1
#   n by their fruits you shall know them [#160818]
#     by their fruits ye shall know them [#16694]
#     by their fruits you will know them [#151396]
#     by their fruits shall ye know them [#156816]
#  ## Bag 2
#     by their fruits you shall know them [#160818]
#   n by their fruits ye shall know them [#16694]
#   n by their fruits you will know them [#151396]
#   n by their fruit you shall know them [#234774]
#  ## Bag 3
#   n by their fruits you shall know them [#160818]
#     by their fruits ye shall know them [#16694]
#  ## Bag 4
#   n by their fruits you will know them [#151396]
#     by their fruits shall ye know them [#156816]
#  ## Bag 5
#   n by their fruits you shall know them [#160818]
#     by their fruits ye shall know them [#16694]
#     by their fruits you will know them [#151396]
#     by their fruits shall ye know them [#156816]
#  ## Bag 6
#     by their fruits you shall know them [#160818]
#   n by their fruits ye shall know them [#16694]
#     wherefore by their fruits ye shall know them [#419243]
#     by their fruits shall ye know them [#156816]
#  ## Bag 7
#   n by their fruits you shall know them [#160818]
#  ## Bag 8
#   n by their fruit you shall know them [#234774]
#  ## Bag 9
#   n by their fruits you shall know them [#160818]
#
# ### Cluster #57011, 14 quotes, total freq 644
#  ## Bag 0
#   n what the hell is going on [#57011]
#   n what the fuck is going on here [#110652]
#   n what the hell is going on here [#117310]
#  ## Bag 1
#     what the hell is going on [#57011]
#   n what the fuck is going on [#189573]
#   n what the fuck is going on here [#110652]
#   n what the hell is going on here [#117310]
#  ## Bag 2
#   n what the hell is going on [#57011]
#     what the fuck is going on [#189573]
#   n what the hell is going on here [#117310]
#  ## Bag 3
#     what the is going on [#266358]
#   n what the heck is going on [#254708]
#     what the hell is going on [#57011]
#   n what the fuck is going on [#189573]
#     what the hell is going on here [#117310]
#  ## Bag 4
#     what the is going on [#266358]
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#     what the hell was going on [#337472]
#     what the hell is going on here [#117310]
#  ## Bag 5
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#     what the fuck is going on here [#110652]
#     what the hell is going on here [#117310]
#  ## Bag 6
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#     what the fuck is going on here [#110652]
#     what the hell is going on here [#117310]
#  ## Bag 7
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#   n what the fuck is going on [#189573]
#     what the fuck is going on here [#110652]
#     what the hell is going on here [#117310]
#  ## Bag 8
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#   n what the fuck is going on [#189573]
#   n what the hell was going on [#337472]
#  ## Bag 9
#   n what the heck is going on [#254708]
#   n what the hell is going on [#57011]
#   n what the fuck is going on [#189573]
#     what the heck is going on here [#552978]
#
# ### Cluster #104317, 11 quotes, total freq 631
#  ## Bag 0
#   n walk softly but carry a big stick [#27671]
#  ## Bag 1
#     speak softly and carry a big stick [#104317]
#   n speak softly but carry a big stick [#154061]
#  ## Bag 2
#   n speak softly and carry a big stick [#104317]
#  ## Bag 3
#     speak softly and carry a big stick [#104317]
#   n speak softly but carry a big stick [#154061]
#  ## Bag 4
#   n speak softly and carry a big stick [#104317]
#  ## Bag 5
#     speak softly and carry a big stick [#104317]
#   n speak softly but carry a big stick [#154061]
#  ## Bag 6
#   n speak softly and carry a big stick [#104317]
#     speak softly but carry a big stick [#154061]
#  ## Bag 7
#     speak softly and carry a big stick [#104317]
#   n speak softly but carry a big stick [#154061]
#     walk softly but carry a big stick [#27671]
#  ## Bag 8
#   n speak softly and carry a big stick [#104317]
#     talk softly and carry a big stick [#471910]
#  ## Bag 9
#     speak softly and carry a big stick [#104317]
#   n speak softly but carry a big stick [#154061]
#
# ### Cluster #34058, 16 quotes, total freq 469
#  ## Bag 0
#   n he who is without sin cast the first stone [#62540]
#   n let he who is without sin cast the first stone [#34058]
#  ## Bag 1
#     he who is without sin cast the first stone [#62540]
#     he who is without sin may cast the first stone [#171700]
#     let he who is without sin cast the first stone [#34058]
#     let he who is without sin [#181213]
#   n let him who is without sin cast the first stone [#167280]
#   n let he who is without sin throw the first stone [#124473]
#     let he without sin cast the first stone [#109611]
#  ## Bag 2
#     he who is without sin [#230740]
#   n let he who is without sin cast the first stone [#34058]
#     let him who is without sin cast the first stone [#167280]
#     let he without sin cast the first stone [#109611]
#  ## Bag 3
#     he who is without sin cast the first stone [#62540]
#     let the one among you who is without sin be the first to throw a stone at her [#267352]
#     he who is without sin [#230740]
#     let he who is without sin cast the first stone [#34058]
#     let he who is without sin [#181213]
#     he that is without sin cast the first stone [#285448]
#   n let him who is without sin cast the first stone [#167280]
#     he without sin cast the first stone [#249958]
#     let he without sin cast the first stone [#109611]
#  ## Bag 4
#     he who is without sin [#230740]
#   n let he who is without sin cast the first stone [#34058]
#     let he who is without sin [#181213]
#     let he that is without sin cast the first stone [#315012]
#     let he without sin cast the first stone [#109611]
#     let him without sin cast the first stone [#291526]
#  ## Bag 5
#     he who is without sin cast the first stone [#62540]
#     let he who is without sin cast the first stone [#34058]
#   n let him who is without sin cast the first stone [#167280]
#  ## Bag 6
#   n let he who is without sin cast the first stone [#34058]
#     let he who is without sin [#181213]
#     let him who is without sin cast the first stone [#167280]
#     let him without sin cast the first stone [#291526]
#  ## Bag 7
#     he who is without sin cast the first stone [#62540]
#     let he who is without sin cast the first stone [#34058]
#   n let him who is without sin cast the first stone [#167280]
#  ## Bag 8
#     he who is without sin cast the first stone [#62540]
#   n let he who is without sin cast the first stone [#34058]
#     he without sin cast the first stone [#249958]
#     let he without sin cast the first stone [#109611]
#  ## Bag 9
#     he who is without sin cast the first stone [#62540]
#     let he who is without sin cast the first stone [#34058]
#   n let him who is without sin cast the first stone [#167280]
#     let he without sin cast the first stone [#109611]
#
# ### Cluster #59096, 17 quotes, total freq 594
#  ## Bag 0
#   n what the hell is wrong with these people [#54797]
#   n what is wrong with these people [#59096]
#   n what the hell is wrong with people [#86929]
#   n what the hell is wrong with you [#67155]
#   n what the hell is wrong with me [#20013]
#   n what is wrong with you [#7417]
#   n what the fuck is wrong with you [#73199]
#   n what is wrong with you people [#87450]
#  ## Bag 1
#   n what the hell is wrong with people [#86929]
#   n what the fuck is wrong with me [#139083]
#   n what the hell is wrong with you [#67155]
#   n what the hell is wrong with me [#20013]
#     what is wrong with you [#7417]
#   n what the fuck is wrong with people [#140009]
#   n what is wrong with you people [#87450]
#  ## Bag 2
#   n what the hell is wrong with you [#67155]
#     what is wrong with you [#7417]
#     what the hell is wrong with you people [#182295]
#   n what the fuck is wrong with you [#73199]
#  ## Bag 3
#     what is wrong with people [#266644]
#   n what the hell is wrong with you [#67155]
#   n what the hell is wrong with me [#20013]
#     what is wrong with you [#7417]
#     what the fuck is wrong with you people [#262972]
#   n what the fuck is wrong with you [#73199]
#  ## Bag 4
#   n what the hell is wrong with you [#67155]
#   n what the heck is wrong with you [#309477]
#     what is wrong with you [#7417]
#     what is wrong with you people [#87450]
#  ## Bag 5
#   n what the hell is wrong with him [#348628]
#   n what the f is wrong with you [#325940]
#   n what the hell is wrong with you [#67155]
#     what is wrong with you [#7417]
#     what the hell is wrong with you people [#182295]
#   n what the fuck is wrong with you [#73199]
#  ## Bag 6
#     what the hell is wrong with these people [#54797]
#   n what the hell is wrong with you [#67155]
#   n what the hell is wrong with me [#20013]
#     what is wrong with you [#7417]
#   n what the fuck is wrong with you [#73199]
#  ## Bag 7
#   n what the fuck is wrong with me [#139083]
#   n what the hell is wrong with me [#20013]
#     what is wrong with you [#7417]
#   n what the fuck is wrong with you [#73199]
#  ## Bag 8
#     what the hell is wrong with these people [#54797]
#   n what the hell is wrong with you [#67155]
#   n what the hell is wrong with me [#20013]
#     what is wrong with you [#7417]
#   n what the fuck is wrong with you [#73199]
#     what is wrong with you people [#87450]
#  ## Bag 9
#   n what the hell is wrong with people [#86929]
#   n what the hell is wrong with you [#67155]
#   n what the heck is wrong with you [#309477]
#     what is wrong with you [#7417]
#     what the hell is wrong with you people [#182295]
#   n what the fuck is wrong with you [#73199]
#
# ### Cluster #20239, 27 quotes, total freq 605
#  ## Bag 0
#   n what am i supposed to do with this [#40472]
#   n so what am i supposed to do [#67156]
#   n what am i going to do [#20239]
#   n what am i supposed to do next [#74906]
#   n what am i going to wear [#64253]
#   n what am i going to do today [#64251]
#   n what am i going to do now [#13827]
#  ## Bag 1
#     so what am i supposed to do [#67156]
#   n what am i going to do now [#13827]
#   n what am i supposed to do [#99764]
#   n what am i going to do with this [#145858]
#  ## Bag 2
#     so what am i supposed to do [#67156]
#     what am i to do [#175726]
#   n what am i going to do [#20239]
#     what am i going to do with my life [#175604]
#     what am i going to do now [#13827]
#     well what am i supposed to do [#229282]
#     what am i supposed to do [#99764]
#     now what am i going to do [#226377]
#  ## Bag 3
#     what am i supposed to do with this [#40472]
#     what am i going to do [#20239]
#     what am i going to do with you [#239113]
#   n what am i going to wear [#64253]
#     what am i going to do now [#13827]
#   n what am i supposed to do [#99764]
#  ## Bag 4
#   n what am i going to do [#20239]
#     what am i supposed to do here [#306936]
#     what am i going to do with you [#239113]
#     what am i going to do now [#13827]
#  ## Bag 5
#     what am i supposed to do with this [#40472]
#     what am i going to do [#20239]
#     what am i going to do with my life [#175604]
#     what else am i supposed to do [#336865]
#   n what am i going to say [#364584]
#     well what am i supposed to do [#229282]
#   n what am i supposed to do [#99764]
#  ## Bag 6
#     what am i going to do about it [#406094]
#     what am i to do [#175726]
#   n what am i going to do [#20239]
#     what am i going to do with my life [#175604]
#     what am i going to say [#364584]
#   n what am i going to wear [#64253]
#     what am i going to do today [#64251]
#     well what am i supposed to do [#229282]
#     what am i supposed to do [#99764]
#     what am i going to do with this [#145858]
#  ## Bag 7
#     what am i going to do about it [#406094]
#     what am i to do [#175726]
#     what am i going to do with you [#239113]
#   n what am i going to say [#364584]
#   n what am i going to wear [#64253]
#     what am i going to do now [#13827]
#   n what am i supposed to do [#99764]
#  ## Bag 8
#     what am i supposed to do with this [#40472]
#   n what am i going to do [#20239]
#     what am i going to do with you [#239113]
#     what am i going to do now [#13827]
#     what am i supposed to do [#99764]
#     now what am i going to do [#226377]
#  ## Bag 9
#     what am i supposed to do with this [#40472]
#     what else am i supposed to do [#336865]
#     what am i going to do with you [#239113]
#   n what am i supposed to do [#99764]
#     now what am i going to do [#226377]
#
# ### Cluster #1059814, 11 quotes, total freq 141
#  ## Bag 0
#   n why are you mad at me [#60328]
#   n are you laughing at me [#1726]
#  ## Bag 1
#   n why are you staring at me [#109142]
#  ## Bag 2
#   n why are you yelling at me [#180143]
#   n why are you looking at me [#178132]
#  ## Bag 3
#   n why are you staring at me [#109142]
#     are you looking at me [#239749]
#  ## Bag 4
#   n why are you yelling at me [#180143]
#     why are you staring at me [#109142]
#     why are you looking at me like that [#306308]
#     are you laughing at me [#1726]
#  ## Bag 5
#   n why are you looking at me [#178132]
#   n why are you staring at me [#109142]
#     are you looking at me [#239749]
#  ## Bag 6
#   n why are you mad at me [#60328]
#  ## Bag 7
#   n why are you looking at me [#178132]
#     stop looking at me like that [#458447]
#  ## Bag 8
#   n why are you staring at me [#109142]
#  ## Bag 9
#   n why are you yelling at me [#180143]
#
# ### Cluster #11463, 9 quotes, total freq 366
#  ## Bag 0
#   n what do you want for your birthday [#54024]
#   n what do you want for christmas [#11463]
#  ## Bag 1
#     what do you want for your birthday [#54024]
#   n what do you want for lunch [#114630]
#  ## Bag 2
#   n what do you want for breakfast [#233599]
#   n what do you want for christmas [#11463]
#  ## Bag 3
#     what do you want for your birthday [#54024]
#   n what do you want for christmas [#11463]
#  ## Bag 4
#     what do you want for christmas [#11463]
#   n what do you want for dinner [#303239]
#  ## Bag 5
#   n what do you want for it [#321480]
#   n what do you want for christmas [#11463]
#  ## Bag 6
#   n what do you want for breakfast [#233599]
#     what do you want for your birthday [#54024]
#   n what do you want for christmas [#11463]
#  ## Bag 7
#   n what do you want for dinner [#303239]
#  ## Bag 8
#   n what do you want for christmas [#11463]
#  ## Bag 9
#   n what do you want for it [#321480]
#     what do you want for your birthday [#54024]
#     what do you want for christmas [#11463]
#
# ### Cluster #12641, 23 quotes, total freq 923
#  ## Bag 0
#   n we are the change we've been waiting for [#40058]
#   n we've been waiting for [#83263]
#   n we are the ones we've been waiting for [#12641]
#   n we're the change we've been waiting for [#41248]
#  ## Bag 1
#   n we are the change we've been waiting for [#40058]
#   n we are the people we've been waiting for [#153764]
#     we've been waiting for [#83263]
#   n we're the ones we've been waiting for [#151695]
#     the ones we've been waiting for [#144655]
#   n we are the ones we've been waiting for [#12641]
#     the one we've been waiting for [#162988]
#  ## Bag 2
#   n we are the change we've been waiting for [#40058]
#   n we are the people we've been waiting for [#153764]
#     we are the change we seek [#174881]
#     we are the one's we've been waiting for [#231502]
#     we are the ones we've been waiting for we are the change that we seek [#187740]
#     change will not come if we wait for some other person or some other time we are the ones we've been waiting for we are the change that we seek [#177286]
#     new orleans speaks we are the ones we've been waiting for [#185196]
#   n we are the ones we've been waiting for [#12641]
#     the one we've been waiting for [#162988]
#  ## Bag 3
#   n we are the change we've been waiting for [#40058]
#     these are the numbers we've been waiting for [#257171]
#     we are the change that we seek [#273399]
#     we are the ones that we've been waiting for [#256510]
#   n we're the ones we've been waiting for [#151695]
#   n we are the ones we've been waiting for [#12641]
#     the one we've been waiting for [#162988]
#  ## Bag 4
#     change will not come if we wait for some other person or if we wait for some other time we are the ones we've been waiting for we are the change that we seek [#283203]
#   n we are the change we've been waiting for [#40058]
#   n we are the people we've been waiting for [#153764]
#     these are the numbers we've been waiting for [#257171]
#     we are the ones that we've been waiting for [#256510]
#     the ones we've been waiting for [#144655]
#   n we are the ones we've been waiting for [#12641]
#  ## Bag 5
#   n we are the change we've been waiting for [#40058]
#     these are the numbers we've been waiting for [#257171]
#   n we are the ones we've been waiting for [#12641]
#  ## Bag 6
#   n we are the change we've been waiting for [#40058]
#     change will not come if we wait for some other person or some other time we are the ones we've been waiting for we are the change that we seek [#177286]
#     the change we've been waiting for [#383424]
#     the ones we've been waiting for [#144655]
#   n we are the ones we've been waiting for [#12641]
#  ## Bag 7
#   n we are the change we've been waiting for [#40058]
#   n we are the ones we've been waiting for [#12641]
#     the one we've been waiting for [#162988]
#  ## Bag 8
#   n we are the people we've been waiting for [#153764]
#     we are the change that we seek [#273399]
#     we are the ones that we've been waiting for [#256510]
#   n we are the ones we've been waiting for [#12641]
#   n we are the one we've been waiting for [#475672]
#  ## Bag 9
#   n we are the change we've been waiting for [#40058]
#   n we are the people we've been waiting for [#153764]
#     the ones we've been waiting for [#144655]
#   n we are the ones we've been waiting for [#12641]
#
# ### Cluster #39364, 11 quotes, total freq 600
#  ## Bag 0
#   n what the fuck was that [#75441]
#   n what in the hell was that [#73417]
#   n what the bloody hell was that [#58244]
#   n what the fuck was that all about [#53582]
#   n what the hell was that [#7899]
#   n what the hell was that all about [#39364]
#  ## Bag 1
#     what in the hell was that [#73417]
#     what the bloody hell was that [#58244]
#   n what the fuck was that all about [#53582]
#   n what the hell was that [#7899]
#     what the hell was that for [#170484]
#  ## Bag 2
#     what the hell was that about [#211633]
#   n what the fuck was that [#75441]
#     what the fuck was that about [#233031]
#     what the hell was that [#7899]
#   n what the hell was that all about [#39364]
#  ## Bag 3
#     what the fuck was that [#75441]
#     what in the hell was that [#73417]
#     what the bloody hell was that [#58244]
#   n what the fuck was that all about [#53582]
#   n what the hell was that [#7899]
#     what the hell was that for [#170484]
#     what the hell was that all about [#39364]
#  ## Bag 4
#   n what the fuck was that [#75441]
#     what the hell was that [#7899]
#  ## Bag 5
#     what the fuck was that [#75441]
#   n what the hell was that [#7899]
#     what the hell was that all about [#39364]
#  ## Bag 6
#   n what the fuck was that [#75441]
#     what the hell was that [#7899]
#     what the hell was that all about [#39364]
#  ## Bag 7
#     what the hell was that about [#211633]
#     what the fuck was that [#75441]
#     what in the hell was that [#73417]
#     what the fuck was that for [#452531]
#   n what the hell was that [#7899]
#  ## Bag 8
#   n what the fuck was that [#75441]
#     what the fuck was that about [#233031]
#     what the fuck was that all about [#53582]
#     what the hell was that [#7899]
#  ## Bag 9
#     what the fuck was that [#75441]
#     what in the hell was that [#73417]
#   n what the hell was that [#7899]
#
# ### Cluster #2192, 9 quotes, total freq 1695
#  ## Bag 0
#   n if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#   n build it and they will come [#3992]
#  ## Bag 1
#   n if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     build it and they will come [#3992]
#  ## Bag 2
#   n if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     build it and they will come [#3992]
#  ## Bag 3
#     build and they will come [#259483]
#     build it they will come [#268806]
#   n if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     build it and they will come [#3992]
#  ## Bag 4
#     build and they will come [#259483]
#   n if you build it they will come [#2192]
#     build it and they will come [#3992]
#  ## Bag 5
#     build it they will come [#268806]
#     if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     build it and they will come [#3992]
#  ## Bag 6
#   n if you build it they will come [#2192]
#     if you build it he will come [#49262]
#     build it and they will come [#3992]
#  ## Bag 7
#     build and they will come [#259483]
#     if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     if you build it will they come [#442156]
#     build it and they will come [#3992]
#  ## Bag 8
#     build and they will come [#259483]
#   n if you build it they will come [#2192]
#     if you build it he will come [#49262]
#     if you build it will they come [#442156]
#     build it and they will come [#3992]
#  ## Bag 9
#     if you build it they will come [#2192]
#   n if you build it he will come [#49262]
#     if you build it will they come [#442156]
#     build it and they will come [#3992]
#
# ### Cluster #1483870, 3 quotes, total freq 228
#  ## Bag 0
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 1
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 2
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 3
#     ma'am we're voting for the n er [#1584039]
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 4
#     ma'am we're voting for the n er [#1584039]
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 5
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 6
#     ma'am we're voting for the n er [#1584039]
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 7
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 8
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 9
# ...
#     review by any court of law or any administrative agency [#1156699]
#   n sec 8 review decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068322]
#   n decisions by the treasury pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1102875]
#   n decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law of any administrative agency [#1137544]
#  ## Bag 5
#     non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1073768]
#     are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068729]
#     may not be reviewed by any court of law or any administrative agency [#1063691]
#   n decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1064280]
#   n decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administration agency [#1195423]
#     sec 8 review decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068322]
#  ## Bag 6
#     non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1073768]
#     may not be reviewed by any court of law or any administrative agency [#1063691]
#   n decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1064280]
#     decisions by the secretary pursuant to the authority are non-reviewable and may not be reviewed by any court of law or any administrative agency [#1065452]
#     sec 8 review decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068322]
#     decisions by the secretary of the treasury pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1086650]
#     may not be reviewed by any court of law or administrative agency [#1095944]
#  ## Bag 7
#     and may not be reviewed by any court of law or any administrative agency [#1092159]
#     decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion [#1092158]
#     decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1064280]
#     decisions by the secretary pursuant to the authority are non-reviewable and may not be reviewed by any court of law or any administrative agency [#1065452]
#   n decisions by the secretary pursuant to the authority of this act are nonreviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1071928]
#     sec 8 review decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068322]
#  ## Bag 8
#     by any court of law or any administrative agency [#1081359]
#     non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1073768]
#     may not be reviewed by any court of law or any administrative agency [#1063691]
#   n decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1064280]
#     sec 8 review decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1068322]
#  ## Bag 9
#     decisions by the secretary pursuant to the authority of this act are non-reviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1064280]
#   n decisions by the secretary pursuant to the authority of this act are nonreviewable and committed to agency discretion and may not be reviewed by any court of law or any administrative agency [#1071928]
#
# ### Cluster #62466, 16 quotes, total freq 1007
#  ## Bag 0
#   n you have got to be kidding me [#69636]
#   n you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#  ## Bag 1
#   n you have got to be kidding me [#69636]
#   n you have got to be shitting me [#130887]
#     you got to be kidding [#107636]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#  ## Bag 2
#     you have got to be kidding [#211468]
#   n you have got to be kidding me [#69636]
#     you have to be kidding [#186818]
#     you have got to be fucking kidding me [#214264]
#     you got to be kidding [#107636]
#     oh you have got to be kidding me [#191152]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#  ## Bag 3
#   n you have got to be kidding me [#69636]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#     you have to be kidding me [#237535]
#  ## Bag 4
#   n you have got to be kidding me [#69636]
#     you have got to be fucking kidding me [#214264]
#   n you have got to be shitting me [#130887]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#  ## Bag 5
#   n you have got to be kidding me [#69636]
#     oh you have got to be kidding me [#191152]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#  ## Bag 6
#     you have got to be kidding [#211468]
#     you got to be kidding [#107636]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#     you have to be kidding me [#237535]
#  ## Bag 7
#   n you have got to be kidding me [#69636]
#     you've got to be kidding [#5054]
#     you've got to be kidding me [#62466]
#  ## Bag 8
#     you have got to be kidding [#211468]
#     you have got to be kidding me [#69636]
#     you have got to be fucking kidding me [#214264]
#     you got to be kidding [#107636]
#     you've got to be kidding [#5054]
#   n you've got to be kidding me [#62466]
#     you have to be kidding me [#237535]
#  ## Bag 9
#   n you have got to be kidding me [#69636]
#     you got to be kidding [#107636]
#     you've got to be kidding me [#62466]
#
# ### Cluster #13891, 26 quotes, total freq 1700
#  ## Bag 0
#   n i'm the only one [#7815]
#   n i don't even know [#63942]
#   n i know what to do [#73214]
#   n i don't know what [#41527]
#   n i don't know what to do [#13891]
#   n don't know what to say [#36840]
#   n i don't know what to wear [#61521]
#   n i don't know what to think [#84856]
#   n i don't know what to say [#5849]
#  ## Bag 1
#   n i don't know what to write [#133834]
#   n i don't know what to do [#13891]
#   n i don't know what to wear [#61521]
#     this can't be real [#136618]
#     i don't even know what to say [#110628]
#   n i don't know what to say [#5849]
#  ## Bag 2
#     i'm the only one [#7815]
#     i don't even know [#63942]
#     i'm not the only one [#217356]
#   n i don't know what to write [#133834]
#   n i don't know what to do [#13891]
#   n i don't know what to say [#5849]
#     i know just what to do [#178347]
#  ## Bag 3
#     i don't even know [#63942]
#     i don't know what [#41527]
#     i'm not the one [#245594]
#   n i don't know what to do [#13891]
#     this can't be real [#136618]
#     i don't know what to say to that [#268663]
#   n i don't know what to say [#5849]
#  ## Bag 4
#     i don't even know [#63942]
#     i don't know what [#41527]
#   n i don't know what to do [#13891]
#   n i don't know what to expect [#308316]
#   n i don't know what to wear [#61521]
#   n i don't know what to think [#84856]
#     don't know what to do [#297934]
#     i don't even know what to say [#110628]
#   n i don't know what to say [#5849]
#  ## Bag 5
#     i'm the only one [#7815]
#     i know what to do [#73214]
#   n i don't know what to write [#133834]
#   n i don't know what to do [#13891]
#   n i don't know what to expect [#308316]
#     don't know what to say [#36840]
#     i don't even know what happened [#367055]
#   n i don't know what to say [#5849]
#     i honestly don't even know what to say [#319603]
#  ## Bag 6
#     i'm the only one [#7815]
#     i know what to do [#73214]
#     i don't know what [#41527]
#   n i don't know what to do [#13891]
#     i don't even know what happened [#367055]
#   n i don't know what to think [#84856]
#   n i don't know what to say [#5849]
#     i know just what to do [#178347]
#  ## Bag 7
#   n i don't know what to do [#13891]
#     i don't even know what happened [#367055]
#     i don't know what to say to that [#268663]
#     i don't even know what to say [#110628]
#   n i don't know what to say [#5849]
#  ## Bag 8
#     i'm the only one [#7815]
#     i don't even know what to feel right now [#464315]
#     i don't know what [#41527]
#     i'm not the one [#245594]
#   n i don't know what to do [#13891]
#   n i don't know what to believe [#481210]
#   n i don't know what to say [#5849]
#  ## Bag 9
#     i don't even know [#63942]
#     i'm not the only one [#217356]
#     i don't even know what to feel right now [#464315]
#   n i don't know what to write [#133834]
#   n i don't know what to do [#13891]
#   n i don't know what to believe [#481210]
#     this can't be real [#136618]
#   n i don't know what to think [#84856]
#     i don't even know what to say [#110628]
#   n i don't know what to say [#5849]
#
# ### Cluster #97200, 24 quotes, total freq 1328
#  ## Bag 0
#   n we need to be the change we wish to see in the world [#75907]
#   n be the change we wish to see in the world [#84030]
#   n be the change you want to see in the world [#5848]
#   n you must be the change you want to see in the world [#22256]
#  ## Bag 1
#     we must be the change we wish to see in the world [#160720]
#     be the change you want to see [#129343]
#     be the change you want to see in the world [#5848]
#   n be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 2
#     we must be the change we wish to see in the world [#160720]
#     be the change you want to see [#129343]
#   n be the change you want to see in the world [#5848]
#     be the change you wish to see in the world [#97200]
#     we must be the change we wish to see [#193741]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 3
#     we must be the change we wish to see in the world [#160720]
#     be the change you want to see [#129343]
#     be the change you want to see in the world [#5848]
#   n be the change you want to be in the world [#259354]
#   n be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 4
#     be the change i want to see in the world [#317560]
#     we must be the change we wish to see in the world [#160720]
#     be the change you want to see [#129343]
#   n be the change you want to see in the world [#5848]
#     be the change you wish to see in the world [#97200]
#     we must be the change we wish to see [#193741]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 5
#     we must be the change we wish to see in the world [#160720]
#     we must be the change [#336238]
#     be the change you want to see in the world [#5848]
#   n be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 6
#     we must be the change we wish to see in the world [#160720]
#     be the change that you want to see [#381699]
#   n be the change you want to see in the world [#5848]
#     be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 7
#     we must be the change we want to see in the world [#453864]
#     be the change you want to see [#129343]
#     be the change you want to see in the world [#5848]
#   n be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 8
#     we must be the change we want to see in the world [#453864]
#     be the change you wish to see [#474796]
#   n be the change you want to see in the world [#5848]
#     be the change you wish to see in the world [#97200]
#     we must be the change we wish to see [#193741]
#     you must be the change you want to see in the world [#22256]
#  ## Bag 9
#     we must be the change we wish to see in the world [#160720]
#     be the change you want to see [#129343]
#     be the change you want to see in the world [#5848]
#     we must become the change we want to see in the world [#507726]
#   n be the change you wish to see in the world [#97200]
#     you must be the change you want to see in the world [#22256]
#
# ### Cluster #26408, 18 quotes, total freq 565
#  ## Bag 0
#   n what the hell were they thinking [#65015]
#   n what the hell are you talking about [#26408]
#   n what in the world are you doing [#20132]
#   n what the fuck are you talking about [#68134]
#  ## Bag 1
#     what in the world are you talking about [#107654]
#   n what the fuck were they thinking [#114046]
#     what the fuck are you wearing [#123122]
#     what the heck are they talking about [#110653]
#   n what the hell are you talking about [#26408]
#     what in the world are you doing [#20132]
#   n what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#     what the fuck were you thinking [#130069]
#  ## Bag 2
#     what the fuck are you wearing [#123122]
#   n what the hell are you talking about [#26408]
#     what in the world are you doing [#20132]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#  ## Bag 3
#   n what the hell are you talking about [#26408]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#  ## Bag 4
#     what the hell were they thinking [#65015]
#   n what the hell are you talking about [#26408]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#  ## Bag 5
#   n what the heck are you talking about [#346515]
#     what the hell were they thinking [#65015]
#   n what the hell are you talking about [#26408]
#     what in the world are you doing [#20132]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#  ## Bag 6
#   n what the heck are you talking about [#346515]
#   n what the heck are they talking about [#110653]
#     what the hell were they thinking [#65015]
#   n what the hell are you talking about [#26408]
#     what the hell were you thinking [#107271]
#  ## Bag 7
#   n what the hell are you talking about [#26408]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#     where in the world are you [#450327]
#  ## Bag 8
#   n what the hell are you talking about [#26408]
#     what the were they thinking [#496492]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#  ## Bag 9
#   n what the heck are you talking about [#346515]
#     what the heck are they talking about [#110653]
#   n what the hell are you talking about [#26408]
#     what the hell were you thinking [#107271]
#   n what the fuck are you talking about [#68134]
#     what the fuck are you serious [#526654]

# %% [markdown]
# ## A quick check
#
# Just to have a look, here we count the average number of *new* quotes that appear in the first ten timebags of each cluster (*new* according to the definition above).

# %%
x = np.arange(1, n_tbgs_new_quotes)
y = np_new_quotes_counts.mean(0)
ci = 1.96 * np_new_quotes_counts.std(0) / np.sqrt(len(np_new_quotes_counts[:, 0]) - 1)
mpl.pyplot.plot(x, np_new_quotes_counts.mean(0))
mpl.pyplot.fill_between(x, y - ci, y + ci, alpha=0.2, color='grey')
