# %% [markdown]
# # How does the distribution of features evolve when we go through the timebags?

# %% [markdown]
# ## Some loading and prep code

# %%
# First some imports
import numpy as np
import matplotlib as mpl
import seaborn as sb
# %matplotlib inline

import settings as st
from linguistics.treetagger import get_tagger
from linguistics.wn import lemmatize as relemmatize
from datainterface.redistools import RedisReader
import datainterface.picklesaver as ps
from util.generic import ProgressInfo
tagger = get_tagger()

# %%
# Load the clusters, the features, and initialize the results
clusters = RedisReader(st.redis_mt_clusters_filtered_pref)
features = dict((fsrc, dict((ftype, ps.load(fdetails['file'].format('all')))
                            for ftype, fdetails in fsrc_details.iteritems()))
                for fsrc, fsrc_details in st.mt_analysis_features.iteritems())
empirical_features = dict((fsrc, dict((ftype, [])
                                      for ftype in fsrc_values.iterkeys()))
                          for fsrc, fsrc_values in features.iteritems())

# %%
from linguistics.distance import hamming_word
    
def is_in_sphere(ref_strings, string):
    """Whether or not `string` is in the hamming_word-sphere at
    distance 1 surrounding the `ref_strings`."""
    
    for ref_str in ref_strings:
        if hamming_word(ref_str, string) == 1:
            return True
    return False


def get_filtered_relems_and_strings(tbg, ref_strings, excl_strings):
    """List the relemmatized words (once per occurrence) appearing in `tbg`,
    and at distance one from `ref_strings`, excluding strings in `excl_strings`.
    
    Quotes are first lemmatized with the TreeTagger lemmatizer, then
    relemmatized as in the mining analysis, with the WordNet morphy
    method.
    
    Parameters
    ----------
    tbg : TimeBag
        The timebag to work on.
    ref_strings : list of strings
        The reference string from which to compute distance; if None, then ignored.
    excl_strings : list of strings
        The reference string from which to exclude; if None, then ignored.
    
    Returns
    -------
    list
        The list of relemmatized words.
    set
        The set of new strings considered to the product of this iteration.
    
    """
    
    filtered_relems = []
    new_strings = set([])

    for string, freq in zip(tbg.strings, tbg.tot_freqs):
        # If our current string is in the set of banned strings,
        # jump to next one
        if excl_strings is not None and string in excl_strings:
            continue
        
        # If our current string is not in the sphere around ref_strings,
        # jump to next one
        if ref_strings is not None and not is_in_sphere(ref_strings, string):
            continue

        new_strings.add(string)
        relems = [relemmatize(lem) for lem in tagger.Lemmatize(string)]
        filtered_relems.extend(relems * freq)

    return filtered_relems, new_strings

# %% [markdown]
# ## The analysis itself
#
# We want to look at the distribution of features in *new* quotes produced by susbtitution (i.e. not those reinjected from outside as part of the continuous process). So for each cluster, we look at the first timebag, and take it as a reference and include all quotes in the second timebag that aren't in the first but are at distance *d* from a quote in the first. We repeat this operation for each later timebag, but basing ourselves on the set of new quotes produced by the previous step. Then on each of these sets of quotes, we compute the distribution of features. This gives us the distribution of features on the novel quotes.

# %%
# Duration of a timebag, in days
timebag_size = 1.0
# Minimum number of timebags a cluster must have to be included in the analysis
min_number_of_timebags = 20
# Maximum number of timebags a cluster must have to be included in the analysis
max_number_of_timebags = 80
# Number of timebags included in 'new quotes' plot below
n_tbgs_new_quotes = 20

# %%
try:
    #raise IOError
    # See if we already computed this
    empirical_features = ps.load('data/analyses/empirical_features_recursive_max80_min20_tbgsize1_no-exclusion.pickle')
    np_new_quotes_counts = ps.load('data/analyses/new_quotes_counts_recursive_max80_min20_tbgsize1_no-exclusion.pickle')
    print 'Loaded from pickle.'
except IOError:
    n_clusters_kept = 0
    new_quotes_counts = []
    print_clusters = []
    
    # A progress indicator
    progress = ProgressInfo(len(clusters), 10, 'clusters')
    
    # For each cluster
    for c in clusters.itervalues():
        progress.next_step()
        
        # Build timebags, skip if we have too many bags
        tbgs = c.build_timebags(timebag_size)
        if len(tbgs) > max_number_of_timebags or len(tbgs) < min_number_of_timebags:
            continue
        
        print_cluster = (c, [])
        max_new_qts_per_tbg = 0
        
        n_clusters_kept += 1
        tbgs_n_new_quotes = []
        for i, tbg in enumerate(tbgs):
            # Update the set of base strings considered as we go
            filtered_relems, new_strings = get_filtered_relems_and_strings(tbg,
                                                                           None if i == 0 else new_strings,
                                                                           None)# if i == 0 else prevtbg.strings) # Exclude preceding bag
            prevtbg = tbg

            if i > 0:
                max_new_qts_per_tbg = max(max_new_qts_per_tbg, len(new_strings))
            print_cluster[1].append(([q for q in c.quotes.itervalues() if q.string in tbg.strings],
                                     [q for q in c.quotes.itervalues() if q.string in new_strings]))
            
            # Update number of new strings
            if 0 < i and i < n_tbgs_new_quotes:
                tbgs_n_new_quotes.append(len(new_strings))
            
            # For each feature
            for fsrc, fsrc_values in features.iteritems():
                for ftype, feature in fsrc_values.iteritems():
            
                    # Get the feature values for the extracted words
                    tbg_empirical_features = [feature[relem] for relem in filtered_relems if relem in feature]
                    try:
                        # Either add it to the existing list
                        empirical_features[fsrc][ftype][i].extend(tbg_empirical_features)
                    except IndexError:
                        # Or create the list for this timebag if necessary
                        empirical_features[fsrc][ftype].append(tbg_empirical_features)
                        # Then check that the item we just created was indeed for the right timebag.
                        empirical_features[fsrc][ftype][i]
                        
        new_quotes_counts.append(np.array(tbgs_n_new_quotes))
        if max_new_qts_per_tbg > 0:
            print_clusters.append(print_cluster)
    
    # Convert to numpy arrays
    print 'Kept {} clusters.'.format(n_clusters_kept)
    np_new_quotes_counts = np.array(new_quotes_counts)
    for fsrc, fsrc_values in features.iteritems():
        for ftype in fsrc_values.iterkeys():
            for i, all_tbg_empirical_features in enumerate(empirical_features[fsrc][ftype]):
                empirical_features[fsrc][ftype][i] = np.array(all_tbg_empirical_features)
    
    # Save to disk
    ps.save(empirical_features, 'data/analyses/empirical_features_recursive_max80_min20_tbgsize1_no-exclusion.pickle')
    ps.save(np_new_quotes_counts, 'data/analyses/new_quotes_counts_recursive_max80_min20_tbgsize1_no-exclusion.pickle')
# Out:
#   10 % (5548 / 55483 clusters)
#   20 % (11096 / 55483 clusters)
#   30 % (16644 / 55483 clusters)
#   40 % (22192 / 55483 clusters)
#   50 % (27740 / 55483 clusters)
#   60 % (33288 / 55483 clusters)
#   70 % (38836 / 55483 clusters)
#   80 % (44384 / 55483 clusters)
#   90 % (49932 / 55483 clusters)
#   100 % (55480 / 55483 clusters)
# Kept 10368 clusters.

# %%
import matplotlib.pyplot as plt
bins = np.linspace(0, np_new_quotes_counts.max() + 1, np_new_quotes_counts.max() + 2) - 0.5
fig, axs = plt.subplots(1, n_tbgs_new_quotes - 1, figsize=(3 * (n_tbgs_new_quotes - 1), 2), sharey=True)
for i in range(n_tbgs_new_quotes - 1):
    axs[i].hist(np_new_quotes_counts[:, i], bins=bins, log=True)
    axs[i].set_xlim(bins[0], bins[-1])

# %%
len(print_clusters)
# Out:
# 726

# %%
# Find until which timebag clusters keep having new quotes
last_tbg_new_quotes = np.zeros(len(print_clusters), dtype=int)
for i, (c, tbgs_details) in enumerate(print_clusters):
    last_tbg_new_quotes[i] = np.array([len(tbg_details[1]) for tbg_details in tbgs_details]).nonzero()[0][-1]

bins = np.linspace(- 0.5, 10 + 0.5, 10 + 2)
plt.hist(last_tbg_new_quotes, bins=bins, log=True)
print len(np.where(last_tbg_new_quotes >= 6)[0])
# Out:
# 15

# %%
def plot_cluster_novelty(c, tbgs_details):
    n_tbgs_shown = max_number_of_timebags
    blue = sb.color_palette()[5]
    red = sb.color_palette()[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(15, 3))
    ax.set_title('Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq))
    ax.set_xlim(- 0.5, n_tbgs_shown - 0.5)
    ax.set_ylim(- 0.5, c.n_quotes - 0.5)
    ax.set_xticks(range(n_tbgs_shown))
    ax.set_yticks(range(c.n_quotes))
    
    qt_coords = dict((q.id, i) for i, q in enumerate(c.quotes.itervalues()))
    for i, tbg_details in enumerate(tbgs_details[:n_tbgs_shown]):
        tbg_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[0]])
        tbg_new_qt_coords = np.array([qt_coords[q.id] for q in tbg_details[1]])
        ax.plot(np.ones_like(tbg_qt_coords) * i, tbg_qt_coords, 'o', color=blue, markersize=8)
        ax.plot(np.ones_like(tbg_new_qt_coords) * i, tbg_new_qt_coords, 'o', color=red, markersize=12)
    fig.show()


#plot_cluster_novelty(print_clusters[1][0], print_clusters[1][1])
for i in range[10]:# np.where(last_tbg_new_quotes >= 6)[0]:
    c, tbgs_details = print_clusters[i]
    plot_cluster_novelty(c, tbgs_details)
# Out:
# /home/sl/.virtualenvs/brainscopypaste/src/matplotlib/lib/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
for i in np.where(last_tbg_new_quotes >= 6)[0]:
    c, tbgs_details = print_clusters[i]
    print '### Cluster #{}, {} quotes, total freq {}'.format(c.id, c.n_quotes, c.tot_freq)
    for i, tbg_details in enumerate(tbgs_details):
        if i >= 10:
            break
        print ' ## Bag {}'.format(i)
        for q in tbg_details[0]:
            print '  {} {} [#{}]'.format('n' if q in tbg_details[1] else ' ', q.string, q.id)
    print
# Out:
# ### Cluster #2034031, 4 quotes, total freq 73
#  ## Bag 0
#   n kill till the last breath [#2023897]
#  ## Bag 1
#     to kill until the last breath [#2034031]
#     to kill till the last breath [#2029643]
#     kill till the last breath [#2023897]
#   n kill until the last breath [#2029818]
#  ## Bag 2
#     to kill until the last breath [#2034031]
#   n kill till the last breath [#2023897]
#     kill until the last breath [#2029818]
#  ## Bag 3
#     to kill until the last breath [#2034031]
#     kill till the last breath [#2023897]
#   n kill until the last breath [#2029818]
#  ## Bag 4
#     to kill until the last breath [#2034031]
#   n kill till the last breath [#2023897]
#  ## Bag 5
#   n kill until the last breath [#2029818]
#  ## Bag 6
#   n kill till the last breath [#2023897]
#  ## Bag 7
#  ## Bag 8
#  ## Bag 9
#
# ### Cluster #2101799, 2 quotes, total freq 125
#  ## Bag 0
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 1
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 2
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 3
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 4
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 5
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 6
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 7
#   n sen clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2109939]
#     senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 8
#   n senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#  ## Bag 9
#     senator clinton is pleased to learn of jon's obvious interest in the state department and is currently reviewing his application [#2101799]
#
# ### Cluster #2146683, 23 quotes, total freq 1191
#  ## Bag 0
#   n they're not willing to give me anything except appreciation f k them [#2148420]
#   n but they're not willing to give me anything except appreciation [#2155392]
#   n they're not willing to give me anything except appreciation them [#2149767]
#   n not willing to give me anything except appreciation f them [#2146537]
#   n blagojevich said he knew that the president-elect wanted senate candidate 1 for the open seat but they're not willing to give me anything except appreciation [#2146480]
#   n said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#   n but they're not willing to give me anything except appreciation fuck them [#2148726]
#   n they're not going to give me anything except appreciation [#2146545]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 1
#     they're not willing to give me anything except appreciation f k them [#2148420]
#     but they're not willing to give me anything except appreciation [#2155392]
#     they're not willing to give me anything except appreciation them [#2149767]
#     not willing to give me anything except appreciation f them [#2146537]
#   n not willing to give me anything but appreciation [#2168884]
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give blagojevich anything except appreciation [#2170842]
#     blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat [#2162235]
#     rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#     but they're not willing to give me anything except appreciation fuck them [#2148726]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 2
#     but they're not willing to give me anything except appreciation [#2155392]
#     they're not willing to give me anything except appreciation them [#2149767]
#     blagojevich said he knew that the president-elect wanted senate candidate 1 for the open seat but they're not willing to give me anything except appreciation [#2146480]
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation bleep them [#2161158]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n not willing to give blagojevich anything except appreciation [#2170842]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#   n not willing to give me anything except appreciation [#2147828]
#   n they're not willing to give me anything but appreciation [#2185703]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 3
#     they're not willing to give me anything except appreciation them [#2149767]
#     not willing to give me anything except appreciation f them [#2146537]
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#     they're not willing to give me anything but appreciation [#2185703]
#   n they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 4
#     they're not willing to give me anything except appreciation them [#2149767]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#     they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#     not willing to give blagojevich anything except appreciation [#2170842]
#     rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#     not willing to give me anything except appreciation [#2147828]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 5
#     they're not willing to give me anything except appreciation f k them [#2148420]
#     not willing to give me anything but appreciation [#2168884]
#     not going to give me anything except appreciation [#2149106]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#     rod blagojevich said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2146945]
#   n they're not willing to give me anything except appreciation expletive them [#2145575]
#     not willing to give me anything except appreciation [#2147828]
#     they're not willing to give me anything but appreciation [#2185703]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 6
#     said he knows that the president-elect wants senate candidate 1 for the senate seat but they're not willing to give me anything except appreciation [#2148027]
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#     they're not willing to give me anything but appreciation bleep them [#2148533]
#   n they're not willing to give me anything except appreciation f them [#2146881]
#     not willing to give me anything except appreciation [#2147828]
#     they're not willing to give me anything but appreciation [#2185703]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 7
#   n they're not willing to give me anything except appreciation fuck them [#2146910]
#     not willing to give me anything except appreciation [#2147828]
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 8
#     they're not willing to give me anything except appreciation [#2146683]
#  ## Bag 9
#     they're not willing to give me anything except appreciation f them [#2146881]
#
# ### Cluster #2477326, 4 quotes, total freq 172
#  ## Bag 0
#   n shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#   n shipping 3 000-odd tons of ammunition in one go is a lot this is pretty rare and we haven't seen much of it quoted in the market over the years [#2481037]
#   n this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#   n shipping 3 000-odd tonnes of ammunition in one go is a lot [#2477325]
#  ## Bag 1
#   n shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     shipping 3 000-odd tons of ammunition in one go is a lot this is pretty rare and we haven't seen much of it quoted in the market over the years [#2481037]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#   n shipping 3 000-odd tonnes of ammunition in one go is a lot [#2477325]
#  ## Bag 2
#   n shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     shipping 3 000-odd tons of ammunition in one go is a lot this is pretty rare and we haven't seen much of it quoted in the market over the years [#2481037]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#   n shipping 3 000-odd tonnes of ammunition in one go is a lot [#2477325]
#  ## Bag 3
#   n shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#  ## Bag 4
#     shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#   n shipping 3 000-odd tonnes of ammunition in one go is a lot [#2477325]
#  ## Bag 5
#   n shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#  ## Bag 6
#     shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#   n shipping 3 000-odd tonnes of ammunition in one go is a lot [#2477325]
#  ## Bag 7
#  ## Bag 8
#     shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#  ## Bag 9
#     shipping 3 000-odd tons of ammunition in one go is a lot [#2477612]
#     this kind of request is pretty rare and we haven't seen much of it quoted in the market over the years [#2477326]
#
# ### Cluster #343833, 13 quotes, total freq 999
#  ## Bag 0
#   n invaded a sovereign neighboring state [#344039]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343727]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#   n unacceptable in the 21st century [#343821]
#   n is unacceptable in the 21st century [#346344]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people [#345313]
#   n invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#   n such an action is unacceptable in the 21st century [#343435]
#   n it now appears that an effort may be under way to depose georgia's duly elected government [#344134]
#   n has invaded a sovereign neighboring state and threatens a democratic government elected by its people [#352224]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people [#343772]
#  ## Bag 1
#   n invaded a sovereign neighboring state [#344039]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343727]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#     unacceptable in the 21st century [#343821]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people [#345313]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people [#343772]
#  ## Bag 2
#     invaded a sovereign neighboring state [#344039]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343727]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#     it now appears that an effort may be under way to depose georgia's duly elected government russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#400683]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people [#345313]
#   n invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#  ## Bag 3
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#     it now appears that an effort may be under way to depose georgia's duly elected government russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#400683]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#  ## Bag 4
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343727]
#     it now appears that an effort may be under way to depose georgia's duly elected government russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#400683]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#  ## Bag 5
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#  ## Bag 6
#   n russia has invaded a sovereign neighbouring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343727]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#     russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people [#343772]
#  ## Bag 7
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#     russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people [#343772]
#  ## Bag 8
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the twenty-first century [#360393]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#     russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#     such an action is unacceptable in the 21st century [#343435]
#  ## Bag 9
#     invaded a sovereign neighboring state [#344039]
#     it now appears that an effort may be under way to depose georgia's duly elected government russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#400683]
#     unacceptable in the 21st century [#343821]
#     is unacceptable in the 21st century [#346344]
#     invaded a sovereign neighbouring state [#362278]
#   n russia has invaded a sovereign neighboring state and threatens a democratic government elected by its people such an action is unacceptable in the 21st century [#343833]
#
# ### Cluster #2162298, 2 quotes, total freq 254
#  ## Bag 0
#   n among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 1
#   n among the most pre-eminent scientists of the last 100 years [#2187139]
#     among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 2
#   n among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 3
#   n among the most pre-eminent scientists of the last 100 years [#2187139]
#     among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 4
#     among the most pre-eminent scientists of the last 100 years [#2187139]
#   n among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 5
#   n among the most pre-eminent scientists of the last 100 years [#2187139]
#     among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 6
#   n among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 7
#   n among the most pre-eminent scientists of the last 100 years [#2187139]
#  ## Bag 8
#   n among the most preeminent scientists of the last 100 years [#2162298]
#  ## Bag 9
#   n among the most pre-eminent scientists of the last 100 years [#2187139]
#     among the most preeminent scientists of the last 100 years [#2162298]
#
# ### Cluster #2147800, 11 quotes, total freq 216
#  ## Bag 0
#   n if it illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2149696]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#   n if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147510]
#   n even the most cynical agents in our office were shocked [#2147801]
#   n if it isn't the most corrupt state in the united states [#2156317]
#   n isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2148719]
#   n if it is not the most corrupt state in the united states it's certainly one hell of a competitor [#2153735]
#   n if illinois isn't the most corrupt state in the united states it is one hell of a competitor [#2147782]
#  ## Bag 1
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#   n if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147510]
#     if it isn't the most corrupt state in the united states it's one hell of a competitor [#2168639]
#     even the most cynical agents in our office were shocked [#2147801]
#   n if it is not the most corrupt state in the united states it's certainly one hell of a competitor [#2153735]
#     if illinois isn't the most corrupt state in the united states it is one hell of a competitor [#2147782]
#  ## Bag 2
#     if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor i think even the most cynical agents in our office were shocked [#2185088]
#     if it illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2149696]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#   n if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147510]
#     isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2148719]
#     if illinois isn't the most corrupt state in the united states it is one hell of a competitor [#2147782]
#  ## Bag 3
#     if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor i think even the most cynical agents in our office were shocked [#2185088]
#     if it illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2149696]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#     most corrupt state in the united states [#2198400]
#   n if it is not the most corrupt state in the united states it's certainly one hell of a competitor [#2153735]
#  ## Bag 4
#     if it illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2149696]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#     most corrupt state in the united states [#2198400]
#   n if it is not the most corrupt state in the united states it's certainly one hell of a competitor [#2153735]
#  ## Bag 5
#     if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor i think even the most cynical agents in our office were shocked [#2185088]
#     if it illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2149696]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#     most corrupt state in the united states [#2198400]
#   n if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147510]
#     if illinois isn't the most corrupt state in the united states it is one hell of a competitor [#2147782]
#  ## Bag 6
#     if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor i think even the most cynical agents in our office were shocked [#2185088]
#   n if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#  ## Bag 7
#     if it isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147800]
#   n if illinois isn't the most corrupt state in the united states it's certainly one hell of a competitor [#2147510]
#     if illinois isn't the most corrupt state in the united states it is one hell of a competitor [#2147782]
#  ## Bag 8
#  ## Bag 9
#     if it isn't the most corrupt state in the united states it's one hell of a competitor [#2168639]
#
# ### Cluster #1484115, 13 quotes, total freq 285
#  ## Bag 0
#   n the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1481108]
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1486160]
#   n the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#   n the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#   n all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#   n these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#   n the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#   n these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#   n i was in this game for the money the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1480683]
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other sides of my trades god bless america [#1481093]
#   n i was in this game for money [#1481091]
#   n i was in this game for the money [#1481872]
#  ## Bag 1
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1486160]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other sides of my trades god bless america [#1481093]
#     i was in this game for money [#1481091]
#  ## Bag 2
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1486160]
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#   n all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#     i was in this game for the money the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1480683]
#     i was in this game for the money [#1481872]
#  ## Bag 3
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1486160]
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#   n all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#     i was in this game for the money the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1480683]
#     i was in this game for money [#1481091]
#     i was in this game for the money [#1481872]
#  ## Bag 4
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#   n all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#  ## Bag 5
#   n all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1486160]
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#     all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other sides of my trades god bless america [#1547803]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#     i was in this game for money [#1481091]
#     i was in this game for the money [#1481872]
#  ## Bag 6
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#   n all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#     i was in this game for the money [#1481872]
#  ## Bag 7
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#     the low-hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484838]
#     i was in this game for the money [#1481872]
#  ## Bag 8
#     the low hanging fruit i e idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1489611]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government all of this behavior supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484839]
#  ## Bag 9
#     the low-hanging fruit ie idiots whose parents paid for prep school yale and then the harvard mba was there for the taking [#1484114]
#     all of this behaviour supporting the aristocracy only ended up making it easier for me to find people stupid enough to take the other side of my trades god bless america [#1484116]
#     these people who were often truly not worthy of the education they received or supposedly received rose to the top of companies such as aig bear stearns and lehman brothers and all levels of our government [#1484115]
#
# ### Cluster #2439415, 8 quotes, total freq 766
#  ## Bag 0
#   n go back to the ovens [#2388879]
#   n you need a big oven that's what you need [#2382678]
#  ## Bag 1
#   n go back to the oven [#2394413]
#     go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#  ## Bag 2
#     go back to the oven [#2394413]
#     go back to the ovens you need a big oven that's what you need [#2398813]
#   n go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#     go steal other lands go murderers go back to the oven you need a big oven [#2404035]
#  ## Bag 3
#   n go back to the oven [#2394413]
#     go back to the ovens [#2388879]
#     go steal other lands go murderers go back to the oven you need a big oven [#2404035]
#  ## Bag 4
#     go back to the oven [#2394413]
#     go back to the ovens you need a big oven that's what you need [#2398813]
#   n go back to the ovens [#2388879]
#  ## Bag 5
#   n go back to the oven [#2394413]
#     go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#     go steal other lands go murderers go back to the oven you need a big oven [#2404035]
#  ## Bag 6
#     murderers go back to the ovens you need a big oven [#2439912]
#     go back to the oven [#2394413]
#   n go back to the ovens [#2388879]
#     jews go back to the ovens [#2450379]
#     you need a big oven that's what you need [#2382678]
#     go back to the oven you need a big oven that's what you need [#2439415]
#     go steal other lands go murderers go back to the oven you need a big oven [#2404035]
#  ## Bag 7
#     murderers go back to the ovens you need a big oven [#2439912]
#   n go back to the oven [#2394413]
#     go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#     go back to the oven you need a big oven that's what you need [#2439415]
#     go steal other lands go murderers go back to the oven you need a big oven [#2404035]
#  ## Bag 8
#     murderers go back to the ovens you need a big oven [#2439912]
#     go back to the oven [#2394413]
#   n go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#     go back to the oven you need a big oven that's what you need [#2439415]
#  ## Bag 9
#     murderers go back to the ovens you need a big oven [#2439912]
#   n go back to the oven [#2394413]
#     go back to the ovens [#2388879]
#     you need a big oven that's what you need [#2382678]
#
# ### Cluster #2371514, 14 quotes, total freq 323
#  ## Bag 0
#   n to not hang or lynch the appointee as you try to castigate the appointer [#2376692]
#   n i would ask you to not hang or lynch the appointee while you castigate the appointer [#2373514]
#   n not to hang or lynch the appointee as you try to castigate the appointor [#2372435]
#   n not to hang or lynch the appointee as you try to castigate the appointer [#2371107]
#   n hang or lynch the appointee as you try to castigate the appointer [#2375995]
#   n not hang and lynch the appointee as you try to castigate the appointer [#2371965]
#   n i will ask you to not hang and lynch the appointee as you try to castigate the appointer [#2371514]
#   n i will ask you to not hang and lynch the appointee as you try to castigate the appointer separate if you will the appointee from the appointed [#2371951]
#   n i would ask you to not hang or lynch the appointee as you try to castigate the appointer and separate the appointee from the appointer [#2372481]
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#   n i would ask you not to hang or lynch the appointee as you try to castigate the appointer [#2372623]
#   n i would ask you to not hang or lynch the appointee as you try to castigate the appointer [#2371490]
#   n to not hang and lynch the appointee as you try to castigate the appointer [#2371990]
#   n not to hang or lynch the appointee as you castigate the appointor [#2371021]
#  ## Bag 1
#   n to not hang or lynch the appointee as you try to castigate the appointer [#2376692]
#     i would ask you to not hang or lynch the appointee while you castigate the appointer [#2373514]
#   n not to hang or lynch the appointee as you try to castigate the appointer [#2371107]
#   n hang or lynch the appointee as you try to castigate the appointer [#2375995]
#     not hang and lynch the appointee as you try to castigate the appointer [#2371965]
#     i will ask you to not hang and lynch the appointee as you try to castigate the appointer [#2371514]
#     i would ask you to not hang or lynch the appointee as you try to castigate the appointer and separate the appointee from the appointer [#2372481]
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#     i would ask you to not hang or lynch the appointee as you try to castigate the appointer [#2371490]
#  ## Bag 2
#     i would ask you to not hang or lynch the appointee while you castigate the appointer [#2373514]
#   n not to hang or lynch the appointee as you try to castigate the appointor [#2372435]
#   n hang or lynch the appointee as you try to castigate the appointer [#2375995]
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#     i would ask you to not hang or lynch the appointee as you try to castigate the appointer [#2371490]
#  ## Bag 3
#   n hang or lynch the appointee as you try to castigate the appointer [#2375995]
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#     i would ask you not to hang or lynch the appointee as you try to castigate the appointer [#2372623]
#     i would ask you to not hang or lynch the appointee as you try to castigate the appointer [#2371490]
#  ## Bag 4
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#  ## Bag 5
#     to not hang or lynch the appointee as you try to castigate the appointer [#2376692]
#   n hang or lynch the appointee as you try to castigate the appointer [#2375995]
#     i would ask you to not hang or lynch the appointee as you try to castigate the appointer [#2371490]
#  ## Bag 6
#     not to hang or lynch the appointee as you try to castigate the appointer [#2371107]
#   n hang and lynch the appointee as you try to castigate the appointer [#2371407]
#  ## Bag 7
#     i will ask you to not hang and lynch the appointee as you try to castigate the appointer [#2371514]
# ...
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed through into an inflation shock [#2005839]
#  ## Bag 5
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed through into an inflation shock [#2005839]
#  ## Bag 6
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed through into an inflation shock [#2005839]
#  ## Bag 7
#     the world is not going back to normal after the magnitude of what they have done [#2036010]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed through into an inflation shock [#2005839]
#  ## Bag 8
#     the world is not going back to normal after the magnitude of what they have done [#2036010]
#   n the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#  ## Bag 9
#     the world is not going back to normal after the magnitude of what they have done when the dust settles this will either work and the money they have pushed into the system will feed though into an inflation shock [#1993798]
#
# ### Cluster #1483870, 3 quotes, total freq 228
#  ## Bag 0
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 1
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 2
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 3
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 4
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 5
#   n we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 6
#   n we're votin for the n er [#1483870]
#  ## Bag 7
#     ma'am we're voting for the n er [#1584039]
#     we're votin for the n er [#1483870]
#   n we're voting for the n er [#1483871]
#  ## Bag 8
#     ma'am we're voting for the n er [#1584039]
#   n we're votin for the n er [#1483870]
#     we're voting for the n er [#1483871]
#  ## Bag 9
#     ma'am we're voting for the n er [#1584039]
#
# ### Cluster #2041446, 9 quotes, total freq 616
#  ## Bag 0
#   n when they were saying they had to leave that an employee got killed people were yelling [#2025361]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning [#2024258]
#   n i've been on line since friday morning [#2024738]
#   n savages when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning they kept shopping [#2020501]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning they kept shopping [#2023724]
#   n when they officials were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2022067]
#  ## Bag 1
#     when they were saying they had to leave that an employee got killed people were yelling [#2025361]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning [#2024258]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#     when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning they kept shopping [#2023724]
#     when they officials were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2022067]
#  ## Bag 2
#     i've been on line since friday morning [#2024738]
#     savages when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning they kept shopping [#2020501]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#     when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning they kept shopping [#2041446]
#     when they officials were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2022067]
#  ## Bag 3
#   n when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning [#2024258]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#     when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning they kept shopping [#2023724]
#  ## Bag 4
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#  ## Bag 5
#   n when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning [#2024258]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#  ## Bag 6
#   n when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning [#2024258]
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#  ## Bag 7
#   n when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#  ## Bag 8
#     when they were saying they had to leave that an employee got killed people were yelling i've been on line since yesterday morning [#2020469]
#     when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning they kept shopping [#2041446]
#  ## Bag 9
#     when they were saying they had to leave that an employee got killed people were yelling i've been on line since friday morning [#2023325]
#     when they were saying they had to leave that an employee got killed people were yelling i've been in line since yesterday morning they kept shopping [#2041446]
#
# ### Cluster #2467058, 3 quotes, total freq 121
#  ## Bag 0
#   n katie you're not the center of everyone's universe [#2467058]
#   n katie you're not the center of everybody's universe [#2459290]
#   n because katie you're not the center of everybody's universe [#2459770]
#  ## Bag 1
#   n katie you're not the center of everyone's universe [#2467058]
#   n katie you're not the center of everybody's universe [#2459290]
#     because katie you're not the center of everybody's universe [#2459770]
#  ## Bag 2
#   n katie you're not the center of everyone's universe [#2467058]
#   n katie you're not the center of everybody's universe [#2459290]
#  ## Bag 3
#   n katie you're not the center of everyone's universe [#2467058]
#   n katie you're not the center of everybody's universe [#2459290]
#     because katie you're not the center of everybody's universe [#2459770]
#  ## Bag 4
#   n katie you're not the center of everyone's universe [#2467058]
#  ## Bag 5
#   n katie you're not the center of everybody's universe [#2459290]
#  ## Bag 6
#   n katie you're not the center of everyone's universe [#2467058]
#     katie you're not the center of everybody's universe [#2459290]
#     because katie you're not the center of everybody's universe [#2459770]
#  ## Bag 7
#     katie you're not the center of everyone's universe [#2467058]
#  ## Bag 8
#  ## Bag 9
#     because katie you're not the center of everybody's universe [#2459770]
#
# ### Cluster #2146291, 21 quotes, total freq 735
#  ## Bag 0
#   n a fucking valuable thing you don't just give it away for nothing [#2148789]
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#   n is a f ing valuable thing you just don't give it away for nothing [#2146167]
#   n is a fucking valuable thing you don't just give it away for nothing [#2157149]
#   n is a f-ing valuable thing you just don't give it away for nothing [#2145973]
#   n a fucking valuable thing you just don't give it away for nothing [#2149598]
#   n is a f valuable thing you just don't give it away for nothing [#2146245]
#   n a valuable thing you just don't give it away for nothing [#2146291]
#   n you just don't give it away for nothing [#2146621]
#   n is a expletive valuable thing you don't just give it away for nothing [#2146572]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#   n you don't just give it away for nothing [#2146925]
#   n it's a bleeping valuable thing you just don't give it away for nothing [#2147478]
#   n valuable thing you just don't give it away for nothing [#2147040]
#   n a expletive valuable thing you just don't give it away for nothing [#2147469]
#   n expletive valuable thing you just don't give it away for nothing [#2146622]
#   n a bleeping valuable thing you just don't give it away i've got this thing and it's bleeping golden [#2147799]
#   n is a f king valuable thing you just don't give it away for nothing [#2147427]
#   n a f ing valuable thing [#2149110]
#   n it's a bleeping valuable thing thing you just don't give it away for nothing [#2148731]
#  ## Bag 1
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#   n is a f ing valuable thing you just don't give it away for nothing [#2146167]
#   n is a fucking valuable thing you don't just give it away for nothing [#2157149]
#   n is a f-ing valuable thing you just don't give it away for nothing [#2145973]
#   n a fucking valuable thing you just don't give it away for nothing [#2149598]
#   n is a f valuable thing you just don't give it away for nothing [#2146245]
#   n a valuable thing you just don't give it away for nothing [#2146291]
#     you just don't give it away for nothing [#2146621]
#   n is a expletive valuable thing you don't just give it away for nothing [#2146572]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#     you don't just give it away for nothing [#2146925]
#     it's a bleeping valuable thing you just don't give it away for nothing [#2147478]
#   n a expletive valuable thing you just don't give it away for nothing [#2147469]
#   n expletive valuable thing you just don't give it away for nothing [#2146622]
#   n is a f king valuable thing you just don't give it away for nothing [#2147427]
#     it's a bleeping valuable thing thing you just don't give it away for nothing [#2148731]
#  ## Bag 2
#     a fucking valuable thing you don't just give it away for nothing [#2148789]
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#   n is a f ing valuable thing you just don't give it away for nothing [#2146167]
#   n is a fucking valuable thing you don't just give it away for nothing [#2157149]
#   n is a f valuable thing you just don't give it away for nothing [#2146245]
#     you just don't give it away for nothing [#2146621]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#   n a expletive valuable thing you just don't give it away for nothing [#2147469]
#   n expletive valuable thing you just don't give it away for nothing [#2146622]
#  ## Bag 3
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#   n is a f-ing valuable thing you just don't give it away for nothing [#2145973]
#   n a fucking valuable thing you just don't give it away for nothing [#2149598]
#   n is a expletive valuable thing you don't just give it away for nothing [#2146572]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#     a expletive valuable thing you just don't give it away for nothing [#2147469]
#  ## Bag 4
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#     is a f ing valuable thing you just don't give it away for nothing [#2146167]
#     a fucking valuable thing you just don't give it away for nothing [#2149598]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#  ## Bag 5
#     a fucking valuable thing you don't just give it away for nothing [#2148789]
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#     is a f ing valuable thing you just don't give it away for nothing [#2146167]
#     a fucking valuable thing you just don't give it away for nothing [#2149598]
#   n is a fucking valuable thing you just don't give it away for nothing [#2146292]
#  ## Bag 6
#   n is a expletive valuable thing you just don't give it away for nothing [#2145573]
#     is a fucking valuable thing you don't just give it away for nothing [#2157149]
#   n is a f valuable thing you just don't give it away for nothing [#2146245]
#     you just don't give it away for nothing [#2146621]
#     you don't just give it away for nothing [#2146925]
#     it's a bleeping valuable thing you just don't give it away for nothing [#2147478]
#     expletive valuable thing you just don't give it away for nothing [#2146622]
#     a f ing valuable thing [#2149110]
#  ## Bag 7
#     a fucking valuable thing you don't just give it away for nothing [#2148789]
#     a valuable thing you just don't give it away for nothing [#2146291]
#  ## Bag 8
#     is a expletive valuable thing you just don't give it away for nothing [#2145573]
#     is a fucking valuable thing you just don't give it away for nothing [#2146292]
#  ## Bag 9

# %% [markdown]
# ## A quick check
#
# Just to have a look, here we count the average number of *new* quotes that appear in the first ten timebags of each cluster (*new* according to the definition above).

# %%
x = np.arange(1, n_tbgs_new_quotes)
y = np_new_quotes_counts.mean(0)
ci = 1.96 * np_new_quotes_counts.std(0) / np.sqrt(len(np_new_quotes_counts[:, 0]) - 1)
mpl.pyplot.plot(x, np_new_quotes_counts.mean(0))
mpl.pyplot.fill_between(x, y - ci, y + ci, alpha=0.2, color='grey')
