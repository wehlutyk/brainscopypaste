# %% [markdown]
# # How do features vary on substitution? What susceptibility to substitution do they induce?

# %% [markdown]
# ## Data-loading and formatting
#
# See below for graphs.

# %%
# Initial imports
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D, TransformedBbox
import numpy as np
import seaborn as sb
import pandas as pd
from pprint import pprint

from analyze.args import AnalysisArgs
from analyze.substitutions import SubstitutionsAnalyzer
from util.generic import is_twelfth_int
from linguistics.treetagger import get_tagger
tagger = get_tagger()

# %%
included_features = ['mt_frequencies',
                     'aoa_Kuperman',
                     'cmu_MNphonemes',
                     'wn_MNSyns',
                     'fa_CCs']

# Build the analysis classes
aa = AnalysisArgs({'ff': 'filtered',
                   'model': 'tbgs',
                   'POS': 'all',
                   'substrings': True,
                   'timebag_size': 1.0,
                   'features': included_features,
                   'positions': False,
                   'paths': False,
                   'save': False,
                   'overwrite': False,
                   'show': True})
sa = SubstitutionsAnalyzer(aa)

print 'Loaded the {} substitutions that have been mined.'.format(len(sa.substitutions))
# Out:
# Loading substitutions...
# OK
# Loading analysis cases... Building NX graph... Building lemma coordinates...
# OK
# Building WordNet adjacency matrix...
# OK
# OK
# OK
# Loaded the 1051 substitutions that have been mined.

# %% [markdown]
# ## Susceptibility to substitution for all the features
#
# *feature value* ~ *susceptibility value*

# %%
# Translating internal feature names to public names
tr_map = {'aoa_Kuperman': 'Age of acquisition',
          'cmu_MNphonemes': r'$\left< \right.$ \# phonemes $\left. \right>$',
          'cmu_MNsyllables': r'$\left< \right.$ \# syllables $\left. \right>$',
          'fa_BCs': 'FA log-betweenness',
          'fa_CCs': 'FA log-clustering',
          'fa_degrees': 'FA log-degree',
          'fa_PR_scores': 'FA log-pagerank',
          'mt_frequencies': 'Log-frequency',
          'mt_start_frequencies': 'Log-frequency in start quotes',
          'wn_BCs': 'WN log-betweenness',
          'wn_CCs': 'WN log-clustering',
          'wn_degrees': 'WN log-degree',
          'wn_MNSyns': r'Log $\left< \right.$ \# synonyms $\left. \right>$',
          'wn_NSigns': r'Log \# meanings',
          'wn_PR_scores': 'WN log-pagerank'}

back_tr_map = dict([(v, k) for k, v in tr_map.iteritems()])

def _translate(labels, tr):
    if isinstance(labels, list):
        return [tr[l] for l in labels]
    else:
        return tr[labels]

def translate(labels):
    """Translate a list of internal labels to human-readable ones."""
    return _translate(labels, tr_map)

def back_translate(labels):
    """Translate a list of human-readable labels to internal ones."""
    return _translate(labels, back_tr_map)

# %%
# Build susceptibilities and filter out zeros
for a in sa.analyses:
    try:
        a.f_susceptibilities
    except AttributeError:
        a.build_susceptibilities()
        # The try-except here lets us run this cell several times without overwriting
        # the original unfiltered susceptibilities each time.
        a.f_susceptibilities_orig = a.f_susceptibilities
    
    a.f_susceptibilities = a.f_susceptibilities_orig#[np.nonzero(a.f_susceptibilities_orig[:, 1])]
    # Remove MNSyns outlier
    #if a.feature.fullname == 'wn MNSyns all':
    #    a.f_susceptibilities = \
    #            a.f_susceptibilities_orig[np.nonzero(a.f_susceptibilities_orig[:, 1])][:-1]

# Set names, order and colorify analyses
for a in sa.analyses:
    a.feature.shortfullname = a.feature.fullname.replace(' ', '_').rstrip('_all')
    a.feature.publicname = translate(a.feature.shortfullname)
analyses = sorted(sa.analyses, key=lambda a: included_features.index(a.feature.shortfullname))
palette = sb.color_palette('husl', len(included_features))
palette_dict = dict(zip([a.feature.publicname for a in analyses], palette))

# Convert to DataFrame
sdata = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * 
                                                 len(a.f_susceptibilities) for a in analyses]),
                      'feature value': np.concatenate([a.f_susceptibilities[:, 0] for a in analyses]),
                      'substitution susceptibility': np.concatenate([a.f_susceptibilities[:, 1] 
                                                                     for a in analyses])})

# %%
# Don't close the figure after drawing
# %config InlineBackend.close_figures=False

nbins_suscepts = 5
n_pts_threshold = 15

bins_cache = []

# Our plotting function for a given feature
def plot_susceptibility(xvalues, svalues, **kwargs):
    color = kwargs.get('color', 'blue')
    
    #if is_twelfth_int(xvalues):
    #    bins = np.linspace(int(np.floor(xvalues.iloc[0])) - 0.5, int(np.ceil(xvalues.iloc[-1])) + 0.5,
    #                       (int(np.ceil(xvalues.iloc[-1])) - int(np.floor(xvalues.iloc[0])) + 2) / 2)
    #else:
    #    bins = np.linspace(xvalues.iloc[0], xvalues.iloc[-1], nbins)
    bins = np.linspace(xvalues.iloc[0], xvalues.iloc[-1], nbins_suscepts + 1)
    bins_cache.append(bins)
    xs = (bins[1:] + bins[:-1]) / 2
    ys = np.zeros_like(xs)
    cs = np.zeros_like(xs)
    for i in range(len(bins) - 1):
        idx = np.where((bins[i] <= xvalues) * (xvalues < bins[i + 1]))[0]
        if len(idx) > n_pts_threshold:
            yss = svalues.iloc[idx]
            ys[i] = yss.mean()
            cs[i] = 1.96 * yss.std() / np.sqrt(len(idx) - 1)
        else:
            ys[i] = np.nan
            cs[i] = np.nan
    
    #plt.hlines(0, xs[0], xs[-1], linestyles='dashed', colors=sb.desaturate(color, 0.2))
    #plt.hlines(1, xs[0], xs[-1], linestyles='dashed', colors=sb.desaturate(color, 0.2))
    plt.plot(xs, ys, '-', lw=2, color=color)
    plt.fill_between(xs, ys - cs, ys + cs, color=sb.desaturate(color, 0.2), alpha=0.2)
    plt.xlim(xs[np.isfinite(ys)][0], xs[np.isfinite(ys)][-1])
    ylim = plt.ylim()
    plt.ylim(max([0, ylim[0]]), min([1, ylim[1]]))

# Plot!
sg = sb.FacetGrid(sdata, col='feature', col_wrap=3, col_order=translate(included_features),
                  aspect=1.5, size=3, sharex=False, sharey=False, hue='feature', palette=palette_dict)
sg.map(plot_susceptibility, 'feature value', 'substitution susceptibility')
sg.set_titles('{col_name}')
# Remove the last axis and recenter the lower row
#sg.axes[1, 2].set_axis_off()
#pts02 = sg.axes[2].get_position().get_points()
#pts01 = sg.axes[1].get_position().get_points()
#trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
#box10 = sg.axes[3].get_position()
#box11 = sg.axes[4].get_position()
sg.axes[2].set_xlabel('')
#sg.axes[3].set_position(TransformedBbox(box10, trans))
#sg.axes[4].set_position(TransformedBbox(box11, trans))

# Save bins
feature_bins = {}
for i in range(5):
    feature_bins[back_translate(sg.axes[i].get_title())] = bins_cache[i]

# Figure is saved later on, once we've added the heatmap
# Out:
# /home/sl/.virtualenvs/brainscopypaste/local/lib/python2.7/site-packages/pandas/computation/expressions.py:190: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   unsupported[op_str]))

# %% [markdown]
# ### Synonyms ~ Phonemes susceptibility heatmap

# %%
analysis_names = [a.feature.fullname for a in sa.analyses]
a_syns = sa.analyses[analysis_names.index('wn MNSyns all')]
a_phonemes = sa.analyses[analysis_names.index('cmu MNphonemes all')]
a_freq = sa.analyses[analysis_names.index('mt frequencies all')]
a_cc = sa.analyses[analysis_names.index('fa CCs all')]

a_syns.build_susceptibilities()
a_phonemes.build_susceptibilities()

ws_syns = a_syns.w_susceptibilities
wf_syns = {}
wf_syns_full = a_syns.feature.data
wf_freq_full = a_freq.feature.data
wf_cc_full = a_cc.feature.data
ws_phonemes = a_phonemes.w_susceptibilities
wf_phonemes = {}
wf_phonemes_full = a_phonemes.feature.data
w_syns_phonemes = set(ws_syns.keys()).intersection(ws_phonemes.keys())

n_diff = 0
for w in w_syns_phonemes:
    n_diff += ws_syns[w] != ws_phonemes[w]
    try:
        feature_syns = a_syns.feature(w)
        feature_phonemes = a_phonemes.feature(w)
    except KeyError:
        continue
    wf_syns[w] = feature_syns
    wf_phonemes[w] = feature_phonemes

# Note, since MNSyns lemmatizes and MNphonemes does not, there are different susceptibilities values
# for some words. In what follows, we take the value from MNSyns (i.e. lemmatizing)
print("{} words (out of {}) with non-matching susceptibilities".format(n_diff,
                                                                       len(w_syns_phonemes)))
# Out:
# 158 words (out of 1642) with non-matching susceptibilities

# %%
# Build 2D data

nbins_syns = 5
nbins_phonemes = 5
n_pts_threshold = 10

#range_syns = feature_ranges['wn_MNSyns']
#range_phonemes = feature_ranges['cmu_MNphonemes']
#bins_syns = np.linspace(range_syns[0], range_syns[1], nbins_syns + 1)
#bins_phonemes = np.linspace(range_phonemes[0], range_phonemes[1], nbins_phonemes + 1)
bins_syns = feature_bins['wn_MNSyns']
bins_phonemes = feature_bins['cmu_MNphonemes']
suscepts2d = np.zeros((nbins_syns, nbins_phonemes))
freqs2d = np.zeros_like(suscepts2d)
n2d = np.zeros_like(suscepts2d)

for i in range(nbins_syns):

    bin_syns = bins_syns[i:i+2]
    w_bin_syns = set([w for w, f in wf_syns.iteritems() if bin_syns[0] <= f < bin_syns[1]])
    if i == nbins_syns:
        # On last bin, include right limit
        w_bin_syns.update([w for w, f in wf_syns.iteritems() if f == bin_syns[1]])

    for j in range(nbins_phonemes):

        bin_phonemes = bins_phonemes[j:j+2]
        w_bin_phonemes = set([w for w, f in wf_phonemes.iteritems()
                              if bin_phonemes[0] <= f < bin_phonemes[1]])
        if j == nbins_phonemes:
            # On last bin, include right limit
            w_bin_phonemes.update([w for w, f in wf_phonemes.iteritems()
                                   if f == bin_phonemes[1]])
        
        w_bin_syns_phonemes = w_bin_syns.intersection(w_bin_phonemes)
        s_bin_syns_phonemes = [ws_syns[w] for w in w_bin_syns_phonemes]
        freq_bin_syns_phonemes = [a_freq.feature(w) for w in w_bin_syns_phonemes]
        n2d[i, j] = len(s_bin_syns_phonemes)
        freqs2d[i, j] = np.mean(freq_bin_syns_phonemes)
        suscepts2d[i, j] = np.mean(s_bin_syns_phonemes) \
            if len(s_bin_syns_phonemes) >= n_pts_threshold else np.nan

print n2d
print suscepts2d
print freqs2d
# Out:
# [[   8.   21.   14.    9.    0.]
#  [  67.  122.   59.   23.    1.]
#  [ 229.  403.  196.   50.    6.]
#  [  51.   93.   47.   10.    1.]
#  [   3.    5.    4.    1.    0.]]
# [[        nan  0.03673179  0.07142857         nan         nan]
#  [ 0.14841502  0.15106865  0.20074347  0.19503106         nan]
#  [ 0.10797092  0.16907516  0.15394241  0.21563381         nan]
#  [ 0.1328213   0.27661726  0.22368794  0.2                nan]
#  [        nan         nan         nan         nan         nan]]
# [[ 9.87488606  8.61674824  7.33345486  8.06755858         nan]
#  [ 9.50500453  8.58039984  7.98270915  7.61518371  6.21060008]
#  [ 9.85377255  8.58489295  7.87586103  7.56698955  7.37504704]
#  [ 9.35023647  7.9174876   7.8993701   7.2301074   3.8286414 ]
#  [ 9.36743576  8.46983531  5.30512453  7.02108396         nan]]
# /home/sl/.virtualenvs/brainscopypaste/local/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
crop = -1

pts02 = sg.axes[2].get_position().get_points()
pts10 = sg.axes[3].get_position().get_points()
left, bottom = pts02[0, 0], pts10[0, 1]
width, height = pts02[1, 0] - pts02[0, 0], pts02[1, 1] - pts02[0, 1]
scale = 0.85
left += width * (1 - scale)
width = width * scale
ax = sg.fig.add_axes([left, bottom, width, height])

sb.heatmap(suscepts2d[:crop,:crop][::-1],
           yticklabels=[bins_syns[i:i+2] for i in range(nbins_syns + crop)[::-1]],
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes + crop)],
           mask=np.isnan(suscepts2d[:crop,:crop][::-1]),
           annot=True, fmt=".2", ax=ax)

ax.set_title('Substitution susceptibility')

ax.set_xlabel(translate('cmu_MNphonemes'))
ax.set_xticks(range(nbins_phonemes + crop + 1))
ax.set_xticklabels(map(lambda x: "${}$".format(int(x)), bins_phonemes[:crop]))

ax.set_ylabel(translate('wn_MNSyns'))
ax.set_yticks(range(nbins_syns + crop + 1))
ax.set_yticklabels(map(lambda x: "${:.1f}$".format(x), bins_syns[:crop]), rotation='horizontal')

# Add number of items per cell
from copy import copy
texts = copy(ax.texts)
for t, n in zip(texts, n2d[:crop,:crop].flat):
    x, y = t.get_position()
    if t.get_text() == '--':
        ax.text(x, y, r'\small{{($\leq$ {} w)}}'.format(n_pts_threshold),
                color='.15', ha='center', va='center')
    else:
        t.set_text(t.get_text() + '\n\\small{{({} w)}}'.format(int(n)))

# Save figure
sg.fig.savefig('data/figures_paper/feature_susceptibilities.png', bbox_inches='tight', dpi=300)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(n2d[::-1],
           yticklabels=[bins_syns[i:i+2] for i in range(nbins_syns)[::-1]],
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes)],
           annot=True, ax=axs[0])
axs[0].set_title('Number of words in each bin')
axs[0].set_ylabel('synonyms')
axs[0].set_xlabel('phonemes')
sb.heatmap(freqs2d[::-1],
           yticklabels=[''] * nbins_phonemes,
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes)],
           mask=np.isnan(freqs2d[::-1]), annot=True, fmt=".2", ax=axs[1])
axs[1].set_title(r'$\left< \right. \log$ frequency $\left. \right>$')
axs[1].set_ylabel('synonyms')
axs[1].set_xlabel('phonemes')

# %% [markdown]
# ### Words involved in substitutions

# %%
from IPython.utils import coloransi
tc = coloransi.TermColors()

def red(s):
    return tc.Red + s + tc.Normal

def blue(s):
    return tc.Blue + s + tc.Normal

def green(s):
    return tc.Green + s + tc.Normal

def black(s):
    return tc.Black + s + tc.Normal

def print_subs(subs, indent):
    for s in subs:
        tokens = tagger.Tokenize(s.mother)
        text = ' '.join(tokens[:s.idx]) + ' '
        text += red('{{{} => {}}}'.format(s.word1, s.word2))
        text += ' ' + ' '.join(tokens[s.idx+1:])
        freq = "{:.2f}".format(wf_freq_full[s.lem2]) if s.lem2 in wf_freq_full else '-'
        cc = "{:.2f}".format(wf_cc_full[s.lem2]) if s.lem2 in wf_cc_full else '-'
        text += blue(" [synonyms {}, phonemes {}, freq {}, cc {}, susceptibility {}]".format(
            wf_syns_full.get(s.lem2, '-'), wf_phonemes_full.get(s.lem2, '-'), 
            freq, cc, ws_syns.get(s.lem2, '-')))
        print indent * ' ' + text

# %%
#detail_bin_indices = [[2, 0], [1, 3]]
detail_bin_indices = [(i, j) for i in range(4) for j in range(4)]
detail_bins = [[bins_syns[i:i+2], bins_phonemes[j:j+2]] for i, j in detail_bin_indices]

for bin_syns, bin_phonemes in detail_bins:
    w_bin_syns = set([w for w, f in wf_syns.iteritems() if bin_syns[0] <= f < bin_syns[1]])
    w_bin_phonemes = set([w for w, f in wf_phonemes.iteritems()
                          if bin_phonemes[0] <= f < bin_phonemes[1]])
    w_bin_syns_phonemes = w_bin_syns.intersection(w_bin_phonemes)
    
    # TITLE
    title = "#synonyms {} --- #phonemes {}".format(bin_syns, bin_phonemes)
    print("=" * len(title))
    print(title)
    print
    
    # FOR EACH WORD
    indent = 2
    for w in w_bin_syns_phonemes:
        freq = "{:.2f}".format(wf_freq_full[w]) if w in wf_freq_full else '-'
        cc = "{:.2f}".format(wf_cc_full[w]) if w in wf_cc_full else '-'
        print (indent - 1) * '-' + " " + red(w) + \
            " (synonyms {}, phonemes {}, freq {}, cc {}, susceptibility {})".format(
                wf_syns[w], wf_phonemes[w], freq, cc, ws_syns[w]),
        
        # Find back the substitutions
        subs = [s for s in a_syns.data if s.lem1 == w or s.word1 == w]
        if len(subs) == 0:
            print '[nosubs]'
            print
            continue

        print
        print
        print_subs(subs, indent + 2)
        print
        
    print
# Out:
# ===========================================================
# #synonyms [-1.94591015 -0.98428794] --- #phonemes [ 1.  4.]
#
# - league (synonyms -1.38629436112, phonemes 3.0, freq 8.72, cc -1.82, susceptibility 0.0) [nosubs]
#
# - cup (synonyms -1.29928298413, phonemes 3.0, freq 7.82, cc -2.03, susceptibility 0.0) [nosubs]
#
# - here (synonyms -1.2527629685, phonemes 3.0, freq 11.40, cc -1.83, susceptibility 0.0) [nosubs]
#
# - thing (synonyms -1.79175946923, phonemes 3.0, freq 11.83, cc -3.09, susceptibility 0.0625)
#
#     it ' s a {thing => place} thing for me [synonyms 0.541597282433, phonemes 4.0, freq 10.74, cc -3.23, susceptibility 0.0]
#     try to make this {thing => work}  [synonyms 0.211309093667, phonemes 3.0, freq 11.80, cc -3.54, susceptibility 0.1]
#     the shape of {things => faith} to come [synonyms 0.223143551314, phonemes 3.0, freq 9.47, cc -1.33, susceptibility -]
#
# - half (synonyms -1.79175946923, phonemes 3.0, freq 9.32, cc -2.30, susceptibility 0.333333333333)
#
#     in the first {half => part} of the year [synonyms 0.893817876022, phonemes 4.0, freq 10.73, cc -2.73, susceptibility 0.0]
#
# - on (synonyms -1.60943791243, phonemes 2.0, freq 13.11, cc -2.73, susceptibility 0.0) [nosubs]
#
# - bail (synonyms -1.2527629685, phonemes 3.0, freq 8.33, cc -, susceptibility 1.0)
#
#     the increased funding we are asking for is a drop in the ocean compared to the billions of pounds the government has found for bank {bail => bailouts}  [synonyms -, phonemes 5.0, freq 8.54, cc -, susceptibility -]
#
# - size (synonyms -1.50407739678, phonemes 3.0, freq 8.47, cc -2.17, susceptibility 0.0) [nosubs]
#
#
# ===========================================================
# #synonyms [-1.94591015 -0.98428794] --- #phonemes [ 4.  7.]
#
# - sector (synonyms -1.79175946923, phonemes 5.0, freq 8.87, cc -, susceptibility 0.111111111111)
#
#      {sector => illiquidity} is raising the cost and reducing the availability of car loans student loans and credit cards [synonyms -, phonemes 10.0, freq 3.97, cc -, susceptibility -]
#
# - major (synonyms -1.46633706879, phonemes 4.0, freq 9.73, cc -2.64, susceptibility 0.0) [nosubs]
#
# - studio (synonyms -1.09861228867, phonemes 6.0, freq 7.84, cc -, susceptibility 0.0) [nosubs]
#
# - hostile (synonyms -1.09861228867, phonemes 6.0, freq 7.21, cc -, susceptibility 0.0) [nosubs]
#
# - palace (synonyms -1.38629436112, phonemes 5.0, freq 4.97, cc -1.61, susceptibility 0.0) [nosubs]
#
# - challenge (synonyms -1.09861228867, phonemes 6.0, freq 10.24, cc -2.06, susceptibility 0.0769230769231)
#
#     immediately after i become president i will confront this economic {challenge => crisis} head-on by taking all necessary steps to ease the credit crisis help hardworking families and restore growth and prosperity [synonyms -, phonemes 6.0, freq 10.98, cc -1.88, susceptibility 0.214285714286]
#
# - civil (synonyms -1.09861228867, phonemes 5.0, freq 8.88, cc -, susceptibility 0.0) [nosubs]
#
# - nuclear (synonyms -1.38629436112, phonemes 6.0, freq 9.19, cc -2.54, susceptibility 0.0) [nosubs]
#
# - self (synonyms -1.09861228867, phonemes 4.0, freq 7.15, cc -2.62, susceptibility 0.5)
#
#     israel has acted is acting and will act only according to its considerations the security needs of its citizens and its right to {self => self-defense}  [synonyms 0.69314718056, phonemes -, freq 6.75, cc -, susceptibility -]
#
# - official (synonyms -1.2527629685, phonemes 6.0, freq 9.33, cc -2.12, susceptibility 0.0) [nosubs]
#
# - least (synonyms -1.09861228867, phonemes 4.0, freq 9.65, cc -1.33, susceptibility 0.0) [nosubs]
#
# - timing (synonyms -1.94591014906, phonemes 5.0, freq 7.63, cc -, susceptibility 0.0) [nosubs]
#
# - courtesy (synonyms -1.09861228867, phonemes 6.0, freq 6.06, cc -, susceptibility 0.0) [nosubs]
#
# - moral (synonyms -1.09861228867, phonemes 5.0, freq 8.69, cc -2.87, susceptibility 0.0) [nosubs]
#
# - together (synonyms -1.2527629685, phonemes 6.0, freq 10.64, cc -3.05, susceptibility 0.0) [nosubs]
#
# - under (synonyms -1.60943791243, phonemes 4.0, freq 10.34, cc -2.53, susceptibility 0.0) [nosubs]
#
# - proper (synonyms -1.38629436112, phonemes 5.0, freq 7.95, cc -2.50, susceptibility 0.0) [nosubs]
#
# - party (synonyms -1.09861228867, phonemes 5.0, freq 10.39, cc -3.29, susceptibility 0.0833333333333)
#
#     we ca n't point the finger at any {party => side}  [synonyms -0.847297860387, phonemes 3.0, freq 10.17, cc -3.18, susceptibility 0.0]
#
# - milk (synonyms -1.94591014906, phonemes 4.0, freq 7.84, cc -2.74, susceptibility 0.0) [nosubs]
#
# - surprise (synonyms -1.09861228867, phonemes 6.0, freq 9.21, cc -2.40, susceptibility 0.0) [nosubs]
#
# - staff (synonyms -1.38629436112, phonemes 4.0, freq 9.12, cc -2.68, susceptibility 0.0) [nosubs]
#
#
# =============================================================
# #synonyms [-1.94591015 -0.98428794] --- #phonemes [  7.  10.]
#
# - colonial (synonyms -1.38629436112, phonemes 8.0, freq 5.58, cc -, susceptibility 0.0) [nosubs]
#
# - collective (synonyms -1.38629436112, phonemes 8.0, freq 7.78, cc -, susceptibility 0.0) [nosubs]
#
# - mechanical (synonyms -1.09861228867, phonemes 9.0, freq 5.96, cc -1.95, susceptibility 0.0) [nosubs]
#
# - possible (synonyms -1.38629436112, phonemes 7.0, freq 10.24, cc -2.49, susceptibility 0.0) [nosubs]
#
# - valuable (synonyms -1.09861228867, phonemes 8.0, freq 7.65, cc -1.21, susceptibility 0.0) [nosubs]
#
# - isolation (synonyms -1.60943791243, phonemes 8.0, freq 6.94, cc -, susceptibility 0.0) [nosubs]
#
# - critical (synonyms -1.2527629685, phonemes 8.0, freq 9.15, cc -2.96, susceptibility 0.0) [nosubs]
#
# - architecture (synonyms -1.38629436112, phonemes 9.0, freq 6.47, cc -1.22, susceptibility 0.0) [nosubs]
#
# - fraction (synonyms -1.38629436112, phonemes 7.0, freq 6.08, cc -, susceptibility 0.0) [nosubs]
#
# - personally (synonyms -1.60943791243, phonemes 7.33333333333, freq 8.33, cc -, susceptibility 0.0) [nosubs]
#
# - quarterly (synonyms -1.38629436112, phonemes 7.5, freq 5.89, cc -, susceptibility 0.0) [nosubs]
#
# - ammunition (synonyms -1.09861228867, phonemes 9.0, freq 6.72, cc -, susceptibility 0.0) [nosubs]
#
# - sexual (synonyms -1.09861228867, phonemes 7.0, freq 8.53, cc -, susceptibility 0.0) [nosubs]
#
# - magnitude (synonyms -1.09861228867, phonemes 8.0, freq 7.33, cc -2.35, susceptibility 1.0)
#
#     at a pace and {magnitude => dimension} that has never happened before [synonyms -0.69314718056, phonemes 8.0, freq 6.82, cc -, susceptibility -]
#
#
# =============================================================
# #synonyms [-1.94591015 -0.98428794] --- #phonemes [ 10.  13.]
#
# - democratic (synonyms -1.09861228867, phonemes 10.0, freq 9.44, cc -, susceptibility 0.0) [nosubs]
#
# - electricity (synonyms -1.09861228867, phonemes 11.0, freq 6.84, cc -1.98, susceptibility 0.0) [nosubs]
#
# - compensation (synonyms -1.09861228867, phonemes 11.0, freq 7.81, cc -, susceptibility 0.0) [nosubs]
#
# - inconsistent (synonyms -1.09861228867, phonemes 12.0, freq 6.95, cc -, susceptibility 0.0) [nosubs]
#
# - fingerprint (synonyms -1.38629436112, phonemes 10.0, freq 6.21, cc -, susceptibility 0.0) [nosubs]
#
# - department (synonyms -1.09861228867, phonemes 10.0, freq 8.90, cc -2.51, susceptibility 0.0) [nosubs]
#
# - republican (synonyms -1.60943791243, phonemes 10.0, freq 9.99, cc -2.16, susceptibility 0.2)
#
#     why are you a {republican => democrat} in 2008 [synonyms -0.69314718056, phonemes 8.0, freq 9.46, cc -1.65, susceptibility 1.0]
#     and {republicans => today} it looks like we have a rescue plan that includes these taxpayer protections [synonyms -0.69314718056, phonemes 4.0, freq 10.87, cc -2.27, susceptibility 0.0]
#
# - independence (synonyms -1.09861228867, phonemes 11.0, freq 7.87, cc -, susceptibility 0.0) [nosubs]
#
# - population (synonyms -1.60943791243, phonemes 10.0, freq 8.61, cc -2.37, susceptibility 0.0) [nosubs]
#
#
# ===========================================================
# #synonyms [-0.98428794 -0.02266574] --- #phonemes [ 1.  4.]
#
# - rad (synonyms -0.69314718056, phonemes 3.0, freq 2.83, cc -, susceptibility 0.0) [nosubs]
#
# - right (synonyms -0.117783035656, phonemes 3.0, freq 11.81, cc -2.47, susceptibility 0.0833333333333)
#
#     you should know that your acts are not at all left unnoticed rather we are closely keeping an eye on you and just waiting for the {right => proper} time to execute your bloodshed [synonyms -1.38629436112, phonemes 5.0, freq 7.95, cc -2.50, susceptibility 0.0]
#     it is not {right => fair} to take the children ' s bread and throw it to the dogs [synonyms 0.162518929498, phonemes 3.0, freq 9.04, cc -2.87, susceptibility 1.0]
#
# - feel (synonyms -0.268263986595, phonemes 3.0, freq 11.15, cc -2.19, susceptibility 0.5)
#
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.223143551314, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.223143551314, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.223143551314, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.223143551314, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#
# - fish (synonyms -0.405465108108, phonemes 3.0, freq 8.35, cc -2.89, susceptibility 0.0) [nosubs]
#
# - church (synonyms -0.510825623766, phonemes 3.0, freq 9.20, cc -2.56, susceptibility 0.0) [nosubs]
#
# - play (synonyms -0.0594234204708, phonemes 3.0, freq 10.92, cc -2.98, susceptibility 0.0) [nosubs]
#
# - walk (synonyms -0.753771802376, phonemes 3.0, freq 9.53, cc -3.10, susceptibility 0.0) [nosubs]
#
# - high (synonyms -0.182321556794, phonemes 2.0, freq 10.45, cc -3.63, susceptibility 0.0) [nosubs]
#
# - date (synonyms -0.367724780125, phonemes 3.0, freq 8.99, cc -2.83, susceptibility 0.666666666667)
#
#     but tonight because of what we did on this {date => day} in this election at this defining moment change has come to america [synonyms 0.0, phonemes 2.0, freq 11.54, cc -2.58, susceptibility 0.315789473684]
#     because of what we did on this {date => day} in this election at this defining moment change has come to america [synonyms 0.0, phonemes 2.0, freq 11.54, cc -2.58, susceptibility 0.315789473684]
#     because of what we did on this {date => day} in this election at this defining moment change has come to america [synonyms 0.0, phonemes 2.0, freq 11.54, cc -2.58, susceptibility 0.315789473684]
#     because of what we did on this {date => day} in this election at this defining moment change has come to america [synonyms 0.0, phonemes 2.0, freq 11.54, cc -2.58, susceptibility 0.315789473684]
#
# - shell (synonyms -0.0571584138399, phonemes 3.0, freq 7.34, cc -2.53, susceptibility 0.0) [nosubs]
#
# - gauge (synonyms -0.200670695462, phonemes 3.0, freq 5.62, cc -2.58, susceptibility 1.0)
#
#     as i write this he has scored 14 international hundreds against australia during his career seven in tests seven in odis and i have been on the field for many of them so i have plenty of opportunities to {gauge => guage} just how magnificent and complete a batsman he is [synonyms -, phonemes -, freq 1.95, cc -, susceptibility -]
#
# - year (synonyms -0.287682072452, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0) [nosubs]
#
# - vote (synonyms -0.510825623766, phonemes 3.0, freq 10.53, cc -2.04, susceptibility 0.0) [nosubs]
#
# - seem (synonyms -0.287682072452, phonemes 3.0, freq 10.12, cc -2.57, susceptibility 0.0) [nosubs]
#
# - heath (synonyms -0.69314718056, phonemes 3.0, freq 7.26, cc -, susceptibility 0.0) [nosubs]
#
# - ship (synonyms -0.69314718056, phonemes 3.0, freq 8.69, cc -2.47, susceptibility 0.0) [nosubs]
#
# - out (synonyms -0.125163142954, phonemes 2.0, freq 12.15, cc -4.05, susceptibility 0.0) [nosubs]
#
# - web (synonyms -0.287682072452, phonemes 3.0, freq 8.88, cc -, susceptibility 1.0)
#
#      {web => sport} times e to the t over tau [synonyms 0.893817876022, phonemes 5.0, freq 8.26, cc -2.36, susceptibility -]
#      {web => sport} times e to the t over tau [synonyms 0.893817876022, phonemes 5.0, freq 8.26, cc -2.36, susceptibility -]
#
# - goal (synonyms -0.287682072452, phonemes 3.0, freq 9.35, cc -2.55, susceptibility 0.0) [nosubs]
#
# - zone (synonyms -0.405465108108, phonemes 3.0, freq 7.92, cc -2.97, susceptibility 0.0) [nosubs]
#
# - no (synonyms -0.69314718056, phonemes 2.0, freq 12.20, cc -2.83, susceptibility 0.0) [nosubs]
#
# - knight (synonyms -0.405465108108, phonemes 3.0, freq 7.11, cc -2.14, susceptibility 1.0)
#
#     lack of respect for the {knight => king}  [synonyms 0.587786664902, phonemes 3.0, freq 9.47, cc -2.51, susceptibility 0.0]
#
# - night (synonyms -0.980829253012, phonemes 3.0, freq 10.17, cc -2.90, susceptibility 0.0) [nosubs]
#
# - long (synonyms -0.0870113769896, phonemes 3.0, freq 10.94, cc -3.44, susceptibility 1.0)
#
#      {long => decades-long} isolation from the nuclear mainstream [synonyms -, phonemes -, freq 4.22, cc -, susceptibility -]
#     i {long => yearn} for my mother ' s bread [synonyms 0.69314718056, phonemes 3.0, freq 6.36, cc -2.11, susceptibility -]
#
# - sic (synonyms -0.69314718056, phonemes 3.0, freq 7.24, cc -, susceptibility 0.0) [nosubs]
#
# - other (synonyms -0.69314718056, phonemes 3.0, freq 11.59, cc -2.13, susceptibility 0.0769230769231)
#
#     not the {other => exciting} thing it used to be [synonyms 0.864997437487, phonemes 5.0, freq 9.17, cc -, susceptibility -]
#
# - call (synonyms -0.0500104205747, phonemes 3.0, freq 10.92, cc -3.21, susceptibility 0.166666666667)
#
#     many are {called => invited} but few are chosen [synonyms 0.105360515658, phonemes 5.0, freq 8.15, cc -, susceptibility -]
#
# - rich (synonyms -0.0800427076735, phonemes 3.0, freq 8.92, cc -2.91, susceptibility 0.0) [nosubs]
#
# - time (synonyms -0.628608659422, phonemes 3.0, freq 12.33, cc -3.40, susceptibility 0.0909090909091)
#
#     i believe that 16 months is the right {time => timeframe}  [synonyms -, phonemes 7.0, freq 5.62, cc -, susceptibility -]
#     the greatest economic challenge of our {times => lifetime}  [synonyms 1.09861228867, phonemes 6.0, freq 8.59, cc -, susceptibility 0.666666666667]
#
# - new (synonyms -0.182321556794, phonemes 2.5, freq 11.58, cc -3.11, susceptibility 0.272727272727)
#
#     there ' s a {sheriff => kid} sheriff in town [synonyms 1.09861228867, phonemes 3.0, freq 9.99, cc -2.18, susceptibility 0.0]
#     you look just awesome in this {new => movie}  [synonyms 2.19722457734, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [synonyms 2.19722457734, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [synonyms 2.19722457734, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [synonyms 2.19722457734, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     it ' s about a {attitude => politics} attitude [synonyms -0.223143551314, phonemes 8.0, freq 9.93, cc -1.96, susceptibility 0.0]
#
# - sale (synonyms -0.510825623766, phonemes 3.0, freq 8.91, cc -1.82, susceptibility 0.0)
# [nosubs]
#
# - east (synonyms -0.336472236621, phonemes 3.0, freq 8.86, cc -1.25, susceptibility 0.0) [nosubs]
#
# - type (synonyms -0.470003629246, phonemes 3.0, freq 8.84, cc -2.22, susceptibility 0.5)
#
#     sometimes when you do things and people see what {type => kind} of person you really are you turn a lot of people off [synonyms 0.223143551314, phonemes 4.0, freq 10.60, cc -2.05, susceptibility 0.545454545455]
#
# - war (synonyms -0.510825623766, phonemes 3.0, freq 10.78, cc -2.94, susceptibility 0.0909090909091)
#
#     the spy who tried to stop a war katharine gun and the secret plot to sanction the iraq {war => invasion}  [synonyms -0.405465108108, phonemes 7.0, freq 8.20, cc -, susceptibility -]
#
# - hope (synonyms -0.405465108108, phonemes 3.0, freq 10.81, cc -2.38, susceptibility 0.285714285714)
#
#     there is no {hope => partner} for peace [synonyms 0.336472236621, phonemes 6.0, freq 9.14, cc -1.49, susceptibility -]
#     there is no {hope => partner} for peace [synonyms 0.336472236621, phonemes 6.0, freq 9.14, cc -1.49, susceptibility -]
#
# - more (synonyms -0.223143551314, phonemes 3.0, freq 12.03, cc -2.05, susceptibility 0.0) [nosubs]
#
# - real (synonyms -0.0800427076735, phonemes 3.0, freq 10.47, cc -2.31, susceptibility 0.0909090909091)
#
#      {real => pro-america} parts of the country [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - then (synonyms -0.510825623766, phonemes 3.0, freq 10.99, cc -1.79, susceptibility 0.0) [nosubs]
#
# - head (synonyms -0.0487901641694, phonemes 3.0, freq 9.92, cc -3.51, susceptibility 0.0)
#
#     i ' ll meet this financial {head => head-on} head [synonyms -1.38629436112, phonemes -, freq 5.66, cc -, susceptibility 0.0]
#
# - wish (synonyms -0.105360515658, phonemes 3.0, freq 9.69, cc -2.80, susceptibility 0.0) [nosubs]
#
# - way (synonyms -0.0800427076735, phonemes 2.0, freq 11.75, cc -2.93, susceptibility 0.285714285714)
#
#      {way => journey} through the depths of hell [synonyms 0.0, phonemes 4.0, freq 8.56, cc -1.57, susceptibility 0.0]
#     around the world in 80 {ways => dishes}  [synonyms 0.916290731874, phonemes 3.0, freq 5.72, cc -1.79, susceptibility -]
#
# - far (synonyms -0.916290731874, phonemes 3.0, freq 10.13, cc -2.65, susceptibility 0.0) [nosubs]
#
# - ox (synonyms -0.69314718056, phonemes 3.0, freq 5.31, cc -1.79, susceptibility 0.0) [nosubs]
#
# - kill (synonyms -0.0606246218164, phonemes 3.0, freq 10.29, cc -2.57, susceptibility 0.6)
#
#     air-raiding villages and {killing => bombing} civilians [synonyms 0.223143551314, phonemes 5.0, freq 7.64, cc -, susceptibility -]
#     just air-raiding villages and {killing => bombing} civilians [synonyms 0.223143551314, phonemes 5.0, freq 7.64, cc -, susceptibility -]
#     our palestinian brothers and sisters are being {killed => crucified}  [synonyms 0.916290731874, phonemes 7.0, freq 5.82, cc -, susceptibility -]
#
# - wave (synonyms -0.154150679827, phonemes 3.0, freq 7.94, cc -2.60, susceptibility 0.0) [nosubs]
#
# - job (synonyms -0.348306694268, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0) [nosubs]
#
# - away (synonyms -0.441832752279, phonemes 3.0, freq 10.37, cc -2.75, susceptibility 0.0) [nosubs]
#
# - tier (synonyms -0.510825623766, phonemes 3.0, freq 5.61, cc -, susceptibility 0.0) [nosubs]
#
# - ago (synonyms -0.69314718056, phonemes 3.0, freq 9.90, cc -, susceptibility 0.0) [nosubs]
#
# - boy (synonyms -0.69314718056, phonemes 2.0, freq 9.43, cc -2.87, susceptibility 0.2)
#
#     i give a lot of credit to the {boys => public}  [synonyms -0.69314718056, phonemes 6.0, freq 10.45, cc -3.40, susceptibility 0.0454545454545]
#
# - search (synonyms -0.117783035656, phonemes 3.0, freq 8.99, cc -2.17, susceptibility 0.5)
#
#     isolated negligence attenuated from the {search => arrest}  [synonyms 1.46633706879, phonemes 4.0, freq 8.04, cc -1.05, susceptibility -]
#
# - room (synonyms -0.510825623766, phonemes 3.0, freq 9.45, cc -2.92, susceptibility 0.0) [nosubs]
#
# - vice (synonyms -0.69314718056, phonemes 3.0, freq 9.35, cc -2.86, susceptibility 0.0) [nosubs]
#
# - row (synonyms -0.133531392625, phonemes 2.0, freq 7.12, cc -2.56, susceptibility 0.0) [nosubs]
#
# - shy (synonyms -0.69314718056, phonemes 2.0, freq 5.81, cc -2.48, susceptibility 0.0) [nosubs]
#
# - lose (synonyms -0.200670695462, phonemes 3.0, freq 10.57, cc -2.50, susceptibility 0.0) [nosubs]
#
# - well (synonyms -0.69314718056, phonemes 3.0, freq 11.39, cc -2.89, susceptibility 0.0) [nosubs]
#
# - up (synonyms -0.559615787935, phonemes 2.0, freq 11.82, cc -3.84, susceptibility 0.0) [nosubs]
#
# - through (synonyms -0.847297860387, phonemes 3.0, freq 10.98, cc -2.28, susceptibility 0.0) [nosubs]
#
# - page (synonyms -0.405465108108, phonemes 3.0, freq 8.64, cc -2.05, susceptibility 0.0) [nosubs]
#
# - will (synonyms -0.405465108108, phonemes 3.0, freq 13.19, cc -2.95, susceptibility 0.0) [nosubs]
#
# - write (synonyms -0.223143551314, phonemes 3.0, freq 9.57, cc -2.31, susceptibility 0.0) [nosubs]
#
# - nose (synonyms -0.441832752279, phonemes 3.0, freq 6.89, cc -3.07, susceptibility 0.0) [nosubs]
#
# - team (synonyms -0.405465108108, phonemes 3.0, freq 10.44, cc -2.37, susceptibility 0.2)
#
#     he represents a significant addition to this franchise and reflects our commitment to putting the best possible {team => product} on the field [synonyms 0.0, phonemes 7.0, freq 9.64, cc -2.27, susceptibility 0.4]
#
# - claw (synonyms -0.69314718056, phonemes 3.0, freq 5.86, cc -1.65, susceptibility 1.0)
#
#      {claw => spend} its way out of recession [synonyms 0.0, phonemes 5.0, freq 10.11, cc -1.29, susceptibility 0.25]
#
# - male (synonyms -0.182321556794, phonemes 3.0, freq 7.66, cc -2.04, susceptibility 0.333333333333)
#
#     outstanding performance by a {male => female} actor in a leading role [synonyms -0.916290731874, phonemes 5.0, freq 8.08, cc -1.69, susceptibility -]
#
# - side (synonyms -0.847297860387, phonemes 3.0, freq 10.17, cc -3.18, susceptibility 0.0) [nosubs]
#
#
# ===========================================================
# #synonyms [-0.98428794 -0.02266574] --- #phonemes [ 4.  7.]
#
# - dance (synonyms -0.336472236621, phonemes 4.0, freq 8.42, cc -3.15, susceptibility 0.0) [nosubs]
#
# - month (synonyms -0.69314718056, phonemes 4.0, freq 10.37, cc -2.36, susceptibility 0.333333333333)
#
#     dhl presents the major league baseball delivery man of the {month => year} award [synonyms -0.287682072452, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0]
#
# - attitude (synonyms -0.287682072452, phonemes 6.0, freq 7.85, cc -2.08, susceptibility 0.0)
#
#     it ' s about a {attitude => politics} attitude [synonyms -0.223143551314, phonemes 8.0, freq 9.93, cc -1.96, susceptibility 0.0]
#
# - human (synonyms -0.287682072452, phonemes 5.5, freq 9.97, cc -2.07, susceptibility 0.0) [nosubs]
#
# - mellow (synonyms -0.251314428281, phonemes 4.0, freq 5.62, cc -1.90, susceptibility 0.0) [nosubs]
#
# - believe (synonyms -0.223143551314, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333)
#
#     i do n't {believe => think} we ' re headed into a recession [synonyms 0.251314428281, phonemes 4.0, freq 12.37, cc -2.63, susceptibility 0.153846153846]
#     i do n't {believe => think} we ' re headed into a recession [synonyms 0.251314428281, phonemes 4.0, freq 12.37, cc -2.63, susceptibility 0.153846153846]
#     we {believe => feel} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.268263986595, phonemes 3.0, freq 11.15, cc -2.19, susceptibility 0.5]
#     we {believe => feel} it is inappropriate to use young private citizens for marketing purposes [synonyms -0.268263986595, phonemes 3.0, freq 11.15, cc -2.19, susceptibility 0.5]
#
# - unhappy (synonyms -0.287682072452, phonemes 6.0, freq 6.99, cc -1.29, susceptibility 0.0) [nosubs]
#
# - actually (synonyms -0.69314718056, phonemes 6.0, freq 9.81, cc -, susceptibility 0.0) [nosubs]
#
# - being (synonyms -0.068992871487, phonemes 4.0, freq 8.31, cc -1.89, susceptibility 0.0) [nosubs]
#
# - willing (synonyms -0.182321556794, phonemes 5.0, freq 9.44, cc -2.71, susceptibility 0.142857142857)
#
#     not {willing => going} to give me anything except appreciation [synonyms 0.851371185775, phonemes 2.0, freq 12.83, cc -2.92, susceptibility 0.0487804878049]
#     not {willing => going} to give me anything except appreciation [synonyms 0.851371185775, phonemes 2.0, freq 12.83, cc -2.92, susceptibility 0.0487804878049]
#
# - policy (synonyms -0.405465108108, phonemes 6.0, freq 10.49, cc -2.35, susceptibility 0.0833333333333)
#
#      {policy => develop} proposals and plans from the obama campaign for action during the obama-biden administration [synonyms 0.213574100298, phonemes 7.0, freq 9.47, cc -2.08, susceptibility 0.0]
#
# - holiday (synonyms -0.405465108108, phonemes 6.0, freq 8.39, cc -2.20, susceptibility 1.0)
#
#     what are you thankful for this {holiday => year}  [synonyms -0.287682072452, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0]
#     what are you thankful for this {holiday => year}  [synonyms -0.287682072452, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0]
#
# - local (synonyms -0.223143551314, phonemes 5.0, freq 8.67, cc -2.35, susceptibility 0.0) [nosubs]
#
# - kingdom (synonyms -0.69314718056, phonemes 6.0, freq 8.81, cc -2.24, susceptibility 0.0) [nosubs]
#
# - steel (synonyms -0.223143551314, phonemes 4.0, freq 6.51, cc -2.31, susceptibility 1.0)
#
#     top 50 {steel => wooden} roller coasters in the world [synonyms -, phonemes 5.0, freq 4.04, cc -, susceptibility -]
#     top 50 {steel => wooden} roller coasters in the world [synonyms -, phonemes 5.0, freq 4.04, cc -, susceptibility -]
#
# - overall (synonyms -0.69314718056, phonemes 5.0, freq 8.64, cc -1.79, susceptibility 0.0) [nosubs]
#
# - facial (synonyms -0.287682072452, phonemes 5.0, freq 5.93, cc -, susceptibility 0.0) [nosubs]
#
# - bank (synonyms -0.325422400435, phonemes 4.0, freq 9.99, cc -2.84, susceptibility 0.5)
#
#     centralization of credit in the {banks => hands} of the state [synonyms -0.0645385211376, phonemes 4.0, freq 10.34, cc -2.98, susceptibility 0.0]
#     centralization of credit in the {banks => hands} of the state [synonyms -0.0645385211376, phonemes 4.0, freq 10.34, cc -2.98, susceptibility 0.0]
#
# - apart (synonyms -0.470003629246, phonemes 5.0, freq 8.02, cc -1.79, susceptibility 0.0) [nosubs]
#
# - shoulder (synonyms -0.980829253012, phonemes 5.0, freq 7.95, cc -2.50, susceptibility 0.0) [nosubs]
#
# - easily (synonyms -0.405465108108, phonemes 5.0, freq 8.28, cc -, susceptibility 0.0) [nosubs]
#
# - button (synonyms -0.587786664902, phonemes 5.0, freq 7.48, cc -2.27, susceptibility 0.0) [nosubs]
#
# - banking (synonyms -0.916290731874, phonemes 6.0, freq 8.83, cc -, susceptibility 0.6)
#
#     the aftermath of {banking => financial} crises [synonyms 0.0, phonemes 8.0, freq 11.15, cc -2.17, susceptibility 0.0333333333333]
#     the aftermath of {banking => financial} crises [synonyms 0.0, phonemes 8.0, freq 11.15, cc -2.17, susceptibility 0.0333333333333]
#     the aftermath of {banking => financial} crises [synonyms 0.0, phonemes 8.0, freq 11.15, cc -2.17, susceptibility 0.0333333333333]
#
# - quarter (synonyms -0.251314428281, phonemes 5.5, freq 9.04, cc -1.74, susceptibility 0.5)
#
#     these operations are intended to address funding pressures over {quarter => quarter-end}  [synonyms -, phonemes -, freq 2.40, cc -, susceptibility -]
#
# - steal (synonyms -0.510825623766, phonemes 4.0, freq 8.43, cc -2.07, susceptibility 0.333333333333)
#
#      {steal => take} from the rich give to the poor [synonyms 0.622529613346, phonemes 3.0, freq 12.05, cc -2.82, susceptibility 0.0344827586207]
#
# - backlog (synonyms -0.69314718056, phonemes 6.0, freq 4.16, cc -, susceptibility 1.0)
#
#     a very low level of {backlog => radioactivity}  [synonyms 0.0, phonemes 13.0, freq 4.97, cc -, susceptibility -]
#
# - warner (synonyms -0.69314718056, phonemes 5.0, freq 7.27, cc -, susceptibility 0.0) [nosubs]
#
# - square (synonyms -0.274436845702, phonemes 5.0, freq 7.26, cc -2.49, susceptibility 0.0) [nosubs]
#
# - pledge (synonyms -0.117783035656, phonemes 4.0, freq 8.31, cc -2.39, susceptibility 0.0) [nosubs]
#
# - national (synonyms -0.69314718056, phonemes 6.5, freq 10.30, cc -2.21, susceptibility 0.0) [nosubs]
#
# - culture (synonyms -0.133531392625, phonemes 5.0, freq 8.98, cc -2.64, susceptibility 0.0) [nosubs]
#
# - further (synonyms -0.318453731119, phonemes 4.0, freq 10.06, cc -1.88, susceptibility 0.0) [nosubs]
#
# - special (synonyms -0.223143551314, phonemes 6.0, freq 9.28, cc -2.44, susceptibility 0.0) [nosubs]
#
# - funding (synonyms -0.470003629246, phonemes 6.0, freq 8.48, cc -, susceptibility 0.0) [nosubs]
#
# - reform (synonyms -0.587786664902, phonemes 6.0, freq 9.48, cc -, susceptibility 0.0) [nosubs]
#
# - federal (synonyms -0.182321556794, phonemes 6.0, freq 9.66, cc -1.91, susceptibility 0.0) [nosubs]
#
# - increase (synonyms -0.154150679827, phonemes 6.0, freq 9.92, cc -2.09, susceptibility 0.0) [nosubs]
#
# - outside (synonyms -0.0741079721537, phonemes 5.0, freq 9.09, cc -2.64, susceptibility 0.0) [nosubs]
#
# - health (synonyms -0.69314718056, phonemes 4.0, freq 10.07, cc -2.41, susceptibility 0.0) [nosubs]
#
# - finger (synonyms -0.336472236621, phonemes 5.0, freq 7.96, cc -2.75, susceptibility 0.0) [nosubs]
#
# - public (synonyms -0.69314718056, phonemes 6.0, freq 10.45, cc -3.40, susceptibility 0.0454545454545)
#
#     until we are positive the technology will protect the american {public => people}  [synonyms 0.0, phonemes 5.0, freq 12.45, cc -3.70, susceptibility 0.0]
#
# - salute (synonyms -0.251314428281, phonemes 5.0, freq 7.24, cc -1.73, susceptibility 1.0)
#
#     i {salute => love} each and every one of you [synonyms 1.28093384546, phonemes 3.0, freq 11.40, cc -3.29, susceptibility 0.1]
#
# - body (synonyms -0.182321556794, phonemes 4.0, freq 9.63, cc -3.11, susceptibility 0.0) [nosubs]
#
# - patient (synonyms -0.405465108108, phonemes 6.0, freq 8.84, cc -2.08, susceptibility 0.333333333333)
#
#     this is good news for {patients => parents}  [synonyms 0.287682072452, phonemes 6.0, freq 9.29, cc -2.20, susceptibility -]
#
# - bleep (synonyms -0.69314718056, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5)
#
#     they ' re not willing to give me anything except {bleep => expletive} bleep them [synonyms 1.09861228867, phonemes 9.0, freq 8.05, cc -, susceptibility 0.68]
#      {bleep => bulls-t} lindsay wears underwear all the time now she was wearing a g-string and it was america ' s fault [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - never (synonyms -0.69314718056, phonemes 4.0, freq 11.12, cc -2.39, susceptibility 0.0) [nosubs]
#
# - host (synonyms -0.318453731119, phonemes 4.0, freq 7.57, cc -1.52, susceptibility 0.0) [nosubs]
#
# - baseball (synonyms -0.69314718056, phonemes 6.0, freq 7.56, cc -2.51, susceptibility 0.0) [nosubs]
#
# - address (synonyms -0.0571584138399, phonemes 5.0, freq 9.69, cc -2.20, susceptibility 0.0) [nosubs]
#
# - change (synonyms -0.223143551314, phonemes 4.0, freq 11.34, cc -3.19, susceptibility 0.0) [nosubs]
#
# - convert (synonyms -0.405465108108, phonemes 6.0, freq 7.32, cc -, susceptibility 0.0) [nosubs]
#
# - freedom (synonyms -0.69314718056, phonemes 6.0, freq 9.38, cc -3.08, susceptibility 0.0) [nosubs]
#
# - drug (synonyms -0.405465108108, phonemes 4.0, freq 9.23, cc -2.81, susceptibility 0.0) [nosubs]
#
# - credit (synonyms -0.0800427076735, phonemes 6.0, freq 9.96, cc -2.35, susceptibility 0.0) [nosubs]
#
# - grain (synonyms -0.628608659422, phonemes 4.0, freq 6.26, cc -1.50, susceptibility 0.0) [nosubs]
#
# - massive (synonyms -0.69314718056, phonemes 5.0, freq 8.65, cc -, susceptibility 0.0) [nosubs]
#
# - threat (synonyms -0.287682072452, phonemes 4.0, freq 9.70, cc -1.97, susceptibility 0.5)
#
#     they ' re going all of these routes through {intimidation => intimation} intimidation to try to thwart the first amendment here because they do n't have an argument on merit [synonyms 0.916290731874, phonemes 9.0, freq 2.48, cc -, susceptibility -]
#
# - pillow (synonyms -0.69314718056, phonemes 4.0, freq 5.76, cc -2.32, susceptibility 0.0) [nosubs]
#
# - blind (synonyms -0.69314718056, phonemes 5.0, freq 7.79, cc -2.40, susceptibility 0.0) [nosubs]
#
# - elect (synonyms -0.916290731874, phonemes 5.0, freq 9.37, cc -1.78, susceptibility 0.428571428571)
#
#      {elect => president-elect} can do almost anything he sets his mind to [synonyms -, phonemes -, freq 9.23, cc -, susceptibility -]
#      {elect => president-elect} can do almost anything he sets his mind to [synonyms -, phonemes -, freq 9.23, cc -, susceptibility -]
#      {elect => president-elect} can do almost anything he sets his mind to [synonyms -, phonemes -, freq 9.23, cc -, susceptibility -]
#
# - private (synonyms -0.223143551314, phonemes 6.0, freq 9.41, cc -2.46, susceptibility 0.0) [nosubs]
#
# - message (synonyms -0.510825623766, phonemes 5.0, freq 9.72, cc -2.35, susceptibility 0.0) [nosubs]
#
# - open (synonyms -0.0870113769896, phonemes 4.0, freq 10.05, cc -3.31, susceptibility 0.0) [nosubs]
#
# - plot (synonyms -0.133531392625, phonemes 4.0, freq 7.86, cc -2.25, susceptibility 0.0) [nosubs]
#
# - wealth (synonyms -0.69314718056, phonemes 4.0, freq 9.02, cc -1.85, susceptibility 0.0) [nosubs]
#
# - service (synonyms -0.117783035656, phonemes 5.0, freq 10.07, cc -2.60, susceptibility 0.25)
#
#     a new spirit of {service => patriotism}  [synonyms 0.0, phonemes 11.0, freq 7.45, cc -, susceptibility 0.75]
#
# - create (synonyms -0.405465108108, phonemes 5.0, freq 10.57, cc -2.13, susceptibility 0.0) [nosubs]
#
# - system (synonyms -0.251314428281, phonemes 6.0, freq 10.71, cc -2.78, susceptibility 0.277777777778)
#
#     this is a very complicated {system => area}  [synonyms 0.405465108108, phonemes 4.0, freq 9.66, cc -2.59, susceptibility 0.666666666667]
#     this is a very complicated {system => area}  [synonyms 0.405465108108, phonemes 4.0, freq 9.66, cc -2.59, susceptibility 0.666666666667]
#     poland by deploying the {system => interceptors} is exposing itself to a strike 100 [synonyms -, phonemes 8.5, freq 2.89, cc -, susceptibility -]
#     poland by deploying the {system => interceptors} is exposing itself to a strike 100 [synonyms -, phonemes 8.5, freq 2.89, cc -, susceptibility -]
#     keep the crisis in our financial {system => industry} from spreading [synonyms 0.0, phonemes 8.0, freq 10.14, cc -1.58, susceptibility 0.142857142857]
#
# - music (synonyms -0.916290731874, phonemes 6.0, freq 9.50, cc -3.05, susceptibility 0.0) [nosubs]
#
# - basic (synonyms -0.405465108108, phonemes 5.0, freq 8.60, cc -2.66, susceptibility 0.0) [nosubs]
#
# - tragic (synonyms -0.69314718056, phonemes 6.0, freq 7.86, cc -, susceptibility 0.0) [nosubs]
#
# - today (synonyms -0.69314718056, phonemes 4.0, freq 10.87, cc -2.27, susceptibility 0.0) [nosubs]
#
# - happy (synonyms -0.287682072452, phonemes 4.0, freq 10.05, cc -3.21, susceptibility 1.0)
#
#     that kid from chicago who wanted to make everybody {happy => laugh}  [synonyms 0.559615787935, phonemes 3.0, freq 8.24, cc -2.17, susceptibility -]
#     that kid from chicago who wanted to make everybody {happy => laugh}  [synonyms 0.559615787935, phonemes 3.0, freq 8.24, cc -2.17, susceptibility -]
#
# - breathe (synonyms -0.117783035656, phonemes 4.0, freq 7.47, cc -1.92, susceptibility 0.0) [nosubs]
#
# - selling (synonyms -0.587786664902, phonemes 5.0, freq 6.43, cc -, susceptibility 0.0) [nosubs]
#
# - bulk (synonyms -0.223143551314, phonemes 4.0, freq 5.60, cc -, susceptibility 0.0)
# [nosubs]
#
# - failure (synonyms -0.559615787935, phonemes 5.0, freq 9.53, cc -2.78, susceptibility 0.0) [nosubs]
#
# - warm (synonyms -0.367724780125, phonemes 4.0, freq 8.19, cc -2.32, susceptibility 0.0) [nosubs]
#
# - hateful (synonyms -0.69314718056, phonemes 6.0, freq 6.26, cc -, susceptibility 0.0) [nosubs]
#
# - tiller (synonyms -0.916290731874, phonemes 4.0, freq 5.97, cc -, susceptibility 0.0) [nosubs]
#
# - careful (synonyms -0.223143551314, phonemes 6.0, freq 8.62, cc -2.56, susceptibility 1.0)
#
#      {careful => danger} of having a proper sterling collapse a run on the pound [synonyms -0.69314718056, phonemes 5.0, freq 8.90, cc -2.87, susceptibility -]
#      {careful => danger} of having a proper sterling collapse a run on the pound [synonyms -0.69314718056, phonemes 5.0, freq 8.90, cc -2.87, susceptibility -]
#
# - must (synonyms -0.69314718056, phonemes 4.0, freq 10.98, cc -2.43, susceptibility 0.0) [nosubs]
#
# - sound (synonyms -0.0870113769896, phonemes 4.0, freq 9.43, cc -2.23, susceptibility 0.0) [nosubs]
#
# - pride (synonyms -0.405465108108, phonemes 4.0, freq 8.25, cc -2.21, susceptibility 0.0) [nosubs]
#
# - tank (synonyms -0.133531392625, phonemes 4.0, freq 7.65, cc -2.17, susceptibility 0.0) [nosubs]
#
# - roulette (synonyms -0.405465108108, phonemes 5.0, freq 5.21, cc -, susceptibility 0.0) [nosubs]
#
# - straight (synonyms -0.100083458557, phonemes 5.0, freq 8.83, cc -2.78, susceptibility 0.6)
#
#      {straight => talk} to the american people [synonyms 0.69314718056, phonemes 3.0, freq 10.98, cc -2.90, susceptibility 0.0]
#     talk {straight => directly} to the american people [synonyms 1.17865499634, phonemes 7.0, freq 8.49, cc -, susceptibility -]
#      {straight => talk} to the american people [synonyms 0.69314718056, phonemes 3.0, freq 10.98, cc -2.90, susceptibility 0.0]
#      {straight => talk} to the american people [synonyms 0.69314718056, phonemes 3.0, freq 10.98, cc -2.90, susceptibility 0.0]
#     talk {straight => directly} to the american people [synonyms 1.17865499634, phonemes 7.0, freq 8.49, cc -, susceptibility -]
#     go {straight => directly} to the insurance company [synonyms 1.17865499634, phonemes 7.0, freq 8.49, cc -, susceptibility -]
#
# - governor (synonyms -0.69314718056, phonemes 6.0, freq 10.10, cc -1.52, susceptibility 0.75)
#
#     likely to be damaging to the {governor => administration}  [synonyms 0.916290731874, phonemes 13.0, freq 10.21, cc -, susceptibility 0.181818181818]
#     likely to be damaging to the {governor => administration}  [synonyms 0.916290731874, phonemes 13.0, freq 10.21, cc -, susceptibility 0.181818181818]
#     likely to be damaging to the {governor => administration}  [synonyms 0.916290731874, phonemes 13.0, freq 10.21, cc -, susceptibility 0.181818181818]
#
# - planet (synonyms -0.405465108108, phonemes 6.0, freq 9.02, cc -0.92, susceptibility 0.0) [nosubs]
#
# - future (synonyms -0.154150679827, phonemes 5.0, freq 10.64, cc -2.65, susceptibility 0.285714285714)
#
#     a hole ripped in the {future => history} of cinema [synonyms -0.510825623766, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0]
#     a hole ripped in the {future => history} of cinema [synonyms -0.510825623766, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0]
#
# - history (synonyms -0.510825623766, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0) [nosubs]
#
# - certain (synonyms -0.336472236621, phonemes 5.0, freq 9.36, cc -1.62, susceptibility 0.0) [nosubs]
#
# - tax (synonyms -0.223143551314, phonemes 4.0, freq 9.91, cc -2.73, susceptibility 0.0) [nosubs]
#
# - general (synonyms -0.223143551314, phonemes 6.0, freq 9.16, cc -2.58, susceptibility 1.0)
#
#     we will win this {general => election}  [synonyms -, phonemes 7.0, freq 10.23, cc -1.41, susceptibility 0.434782608696]
#
# - stroke (synonyms -0.0645385211376, phonemes 5.0, freq 7.34, cc -2.45, susceptibility 0.0) [nosubs]
#
# - faithful (synonyms -0.510825623766, phonemes 6.0, freq 7.20, cc -1.63, susceptibility 0.0) [nosubs]
#
# - prior (synonyms -0.69314718056, phonemes 4.0, freq 7.73, cc -, susceptibility 0.0) [nosubs]
#
# - perform (synonyms -0.287682072452, phonemes 6.0, freq 8.42, cc -1.51, susceptibility 0.0) [nosubs]
#
# - machine (synonyms -0.287682072452, phonemes 5.0, freq 8.20, cc -2.92, susceptibility 0.5)
#
#     know how to make a 500 {machine => computer} that ' s not a piece of junk [synonyms 1.50407739678, phonemes 8.0, freq 9.13, cc -3.43, susceptibility 0.0]
#
# - answer (synonyms -0.223143551314, phonemes 4.0, freq 9.98, cc -2.67, susceptibility 0.0) [nosubs]
#
# - several (synonyms -0.405465108108, phonemes 6.0, freq 9.26, cc -1.19, susceptibility 0.0) [nosubs]
#
# - panic (synonyms -0.287682072452, phonemes 5.0, freq 8.31, cc -1.88, susceptibility 0.0) [nosubs]
#
# - normal (synonyms -0.223143551314, phonemes 6.0, freq 9.15, cc -1.28, susceptibility 0.0) [nosubs]
#
# - price (synonyms -0.117783035656, phonemes 4.0, freq 9.95, cc -1.89, susceptibility 0.0) [nosubs]
#
# - football (synonyms -0.69314718056, phonemes 6.0, freq 9.04, cc -2.68, susceptibility 0.0) [nosubs]
#
# - southern (synonyms -0.69314718056, phonemes 5.0, freq 7.46, cc -3.96, susceptibility 0.0) [nosubs]
#
# - hand (synonyms -0.0645385211376, phonemes 4.0, freq 10.34, cc -2.98, susceptibility 0.0) [nosubs]
#
# - react (synonyms -0.405465108108, phonemes 5.0, freq 7.70, cc -, susceptibility 0.0) [nosubs]
#
# - notebook (synonyms -0.69314718056, phonemes 6.0, freq 6.90, cc -1.18, susceptibility 1.0)
#
#     momentum has been building in the {notebook => laptop} market for some time so it ' s not a complete surprise that shipments have surpassed those of desktops [synonyms 0.0, phonemes 6.0, freq 6.96, cc -, susceptibility 1.0]
#     however this marks a major event in the pc market because it marks the start of the age of the {notebook => laptop}  [synonyms 0.0, phonemes 6.0, freq 6.96, cc -, susceptibility 1.0]
#
# - purchase (synonyms -0.916290731874, phonemes 5.0, freq 8.52, cc -1.05, susceptibility 0.8)
#
#     you know what i enjoyed the most she took the luxury jet that was {purchased => acquired} by her predecessor and sold it on ebay and made a profit [synonyms 0.762140052047, phonemes 5.0, freq 7.44, cc -1.61, susceptibility 1.0]
#     she took the luxury jet that was {purchased => acquired} by her predecessor and sold it on ebay and made a profit [synonyms 0.762140052047, phonemes 5.0, freq 7.44, cc -1.61, susceptibility 1.0]
#     took the luxury jet that was {purchased => acquired} by her predecessor and sold it on ebay and made a profit [synonyms 0.762140052047, phonemes 5.0, freq 7.44, cc -1.61, susceptibility 1.0]
#     you know what i enjoyed the most she took the luxury jet that was {purchased => acquired} by her predecessor and sold it on ebay and made a profit [synonyms 0.762140052047, phonemes 5.0, freq 7.44, cc -1.61, susceptibility 1.0]
#
# - natural (synonyms -0.619039208406, phonemes 6.0, freq 8.95, cc -2.57, susceptibility 0.333333333333)
#
#     it ' s a {thing => place} thing for me [synonyms 0.541597282433, phonemes 4.0, freq 10.74, cc -3.23, susceptibility 0.0]
#
# - mobile (synonyms -0.287682072452, phonemes 5.0, freq 8.62, cc -, susceptibility 0.0) [nosubs]
#
# - baker (synonyms -0.69314718056, phonemes 4.0, freq 5.65, cc -1.49, susceptibility 1.0)
#
#      {baker => chris} was a rad guy he always had a way to get us to smile on tour no matter what situation we were in and he was truly beloved [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - opaque (synonyms -0.69314718056, phonemes 4.0, freq 5.52, cc 0.00, susceptibility 0.0) [nosubs]
#
# - drive (synonyms -0.194156014441, phonemes 4.0, freq 9.37, cc -2.59, susceptibility 0.0) [nosubs]
#
# - ocean (synonyms -0.69314718056, phonemes 4.0, freq 7.74, cc -2.37, susceptibility 0.0) [nosubs]
#
# - overnight (synonyms -0.405465108108, phonemes 6.0, freq 7.59, cc -, susceptibility 0.0) [nosubs]
#
# - pension (synonyms -0.69314718056, phonemes 6.0, freq 7.00, cc -, susceptibility 0.0) [nosubs]
#
# - clean (synonyms -0.10178269431, phonemes 4.0, freq 9.24, cc -3.00, susceptibility 0.0) [nosubs]
#
# - playing (synonyms -0.203598955241, phonemes 5.0, freq 6.61, cc -2.68, susceptibility 1.0)
#
#     i love {playing => fighting} for my country [synonyms 0.74721440183, phonemes 3.0, freq 10.48, cc -3.05, susceptibility 0.333333333333]
#
# - urgency (synonyms -0.69314718056, phonemes 6.0, freq 8.22, cc -, susceptibility 0.0) [nosubs]
#
# - usual (synonyms -0.69314718056, phonemes 6.5, freq 8.12, cc -1.14, susceptibility 0.0) [nosubs]
#
#
# =============================================================
# #synonyms [-0.98428794 -0.02266574] --- #phonemes [  7.  10.]
#
# - strongly (synonyms -0.69314718056, phonemes 7.0, freq 8.89, cc -, susceptibility 0.0) [nosubs]
#
# - projection (synonyms -0.105360515658, phonemes 9.0, freq 6.12, cc -, susceptibility 1.0)
#
#     in a worst-case scenario our research indicates an it spending increase of 2 3 percent in 2009 down from our earlier {projection => prediction} of 5 8 percent [synonyms 0.916290731874, phonemes 9.0, freq 6.38, cc -, susceptibility -]
#
# - presence (synonyms -0.405465108108, phonemes 7.0, freq 8.41, cc -2.01, susceptibility 0.0) [nosubs]
#
# - magnetic (synonyms -0.510825623766, phonemes 8.0, freq 5.49, cc -, susceptibility 0.0) [nosubs]
#
# - domestic (synonyms -0.69314718056, phonemes 8.0, freq 8.76, cc -, susceptibility 0.166666666667)
#
#     palling around with a {domestic => terrorist}  [synonyms -, phonemes 7.0, freq 10.08, cc -, susceptibility 1.0]
#
# - resistance (synonyms -0.200670695462, phonemes 9.0, freq 7.56, cc -2.71, susceptibility 0.0) [nosubs]
#
# - sexist (synonyms -0.69314718056, phonemes 7.0, freq 5.97, cc -, susceptibility 0.0) [nosubs]
#
# - commander (synonyms -0.287682072452, phonemes 7.0, freq 8.25, cc -1.38, susceptibility 0.5)
#
#     that is the kind of courage and vision we need in our next {commander => commander-in-chief}  [synonyms -, phonemes -, freq 6.47, cc -, susceptibility -]
#
# - stability (synonyms -0.405465108108, phonemes 9.0, freq 9.16, cc -, susceptibility 0.0769230769231)
#
#     ensure the {stability => security} of the british economy [synonyms -0.117783035656, phonemes 9.0, freq 10.49, cc -2.21, susceptibility 0.0]
#
# - economic (synonyms -0.916290731874, phonemes 8.0, freq 10.95, cc -2.18, susceptibility 0.153846153846)
#
#     the {economic => american} recovery and reinvestment plan [synonyms -, phonemes -, freq 11.63, cc -, susceptibility 0.133333333333]
#     global protectionism is a path to global {economic => ruin}  [synonyms 0.154150679827, phonemes 4.0, freq 7.93, cc -1.66, susceptibility -]
#
# - desperate (synonyms -0.559615787935, phonemes 7.0, freq 7.65, cc -, susceptibility 1.0)
#
#     that even the most horrendous crimes such as the genocide in gaza are treated as {desperate => discrete} events unconnected to anything that happened in the past and not associated with any ideology or system [synonyms 0.0, phonemes 7.0, freq 4.53, cc 0.00, susceptibility -]
#
# - politics (synonyms -0.223143551314, phonemes 8.0, freq 9.93, cc -1.96, susceptibility 0.0) [nosubs]
#
# - extinction (synonyms -0.182321556794, phonemes 9.5, freq 6.54, cc -, susceptibility 1.0)
#
#     ecological {extinction => extinciton} and evolution in the brave new ocean [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - standing (synonyms -0.211309093667, phonemes 7.0, freq 8.20, cc -2.56, susceptibility 0.0) [nosubs]
#
# - information (synonyms -0.223143551314, phonemes 9.5, freq 9.82, cc -3.00, susceptibility 0.0) [nosubs]
#
# - different (synonyms -0.916290731874, phonemes 7.0, freq 9.92, cc -1.91, susceptibility 0.0) [nosubs]
#
# - management (synonyms -0.69314718056, phonemes 9.0, freq 8.68, cc -2.31, susceptibility 0.0) [nosubs]
#
# - voluntary (synonyms -0.69314718056, phonemes 9.0, freq 6.80, cc -, susceptibility 0.0) [nosubs]
#
# - copyright (synonyms -0.69314718056, phonemes 7.0, freq 7.49, cc -, susceptibility 0.0) [nosubs]
#
# - temptation (synonyms -0.405465108108, phonemes 8.0, freq 7.35, cc -, susceptibility 0.0) [nosubs]
#
# - shrinkage (synonyms -0.405465108108, phonemes 7.0, freq 4.04, cc -, susceptibility 0.0) [nosubs]
#
# - hospital (synonyms -0.69314718056, phonemes 8.0, freq 8.78, cc -2.28, susceptibility 0.0) [nosubs]
#
# - negative (synonyms -0.538996500733, phonemes 7.0, freq 8.77, cc -2.15, susceptibility 0.0) [nosubs]
#
# - strategy (synonyms -0.69314718056, phonemes 8.0, freq 9.01, cc -2.22, susceptibility 0.5)
#
#     best {strategy => independent} game of the year [synonyms 0.60613580357, phonemes 11.0, freq 8.50, cc -2.22, susceptibility 0.0]
#
# - tropical (synonyms -0.69314718056, phonemes 8.0, freq 6.36, cc -1.73, susceptibility 0.0) [nosubs]
#
# - reality (synonyms -0.287682072452, phonemes 7.0, freq 9.18, cc -1.98, susceptibility 0.0) [nosubs]
#
# - correction (synonyms -0.336472236621, phonemes 7.0, freq 6.81, cc -, susceptibility 0.0) [nosubs]
#
# - momentum (synonyms -0.69314718056, phonemes 8.0, freq 7.62, cc -, susceptibility 0.0) [nosubs]
#
# - economy (synonyms -0.287682072452, phonemes 7.0, freq 11.21, cc -2.01, susceptibility 0.0714285714286)
#
#     this will help our air our health and our travel and tourism {economy => industry}  [synonyms 0.0, phonemes 8.0, freq 10.14, cc -1.58, susceptibility 0.142857142857]
#
# - material (synonyms -0.451985123743, phonemes 8.0, freq 8.44, cc -2.48, susceptibility 1.0)
#
#     he hates the american {material => physical} occupation as much as he hates the iranian moral occupation [synonyms -1.2527629685, phonemes 7.0, freq 8.31, cc -2.35, susceptibility -]
#
# - ability (synonyms -0.69314718056, phonemes 7.0, freq 9.58, cc -2.36, susceptibility 0.0) [nosubs]
#
# ...
#
#     the scientists are {virtually => practically} screaming from the rooftops [synonyms -1.09861228867, phonemes 9.5, freq 6.41, cc -, susceptibility -]
#     the scientists are {virtually => practically} screaming from the rooftops [synonyms -1.09861228867, phonemes 9.5, freq 6.41, cc -, susceptibility -]
#
# - ensure (synonyms 1.70474809224, phonemes 5.0, freq 9.74, cc -, susceptibility 0.0) [nosubs]
#
# - workout (synonyms 1.38629436112, phonemes 5.0, freq 6.27, cc -1.29, susceptibility 1.0)
#
#     one day at a time one {workout => step} at a time [synonyms 0.0465200156349, phonemes 4.0, freq 10.43, cc -2.05, susceptibility 0.0]
#
# - prick (synonyms 1.03609193169, phonemes 4.0, freq 5.82, cc -1.72, susceptibility 1.0)
#
#     i would n't call mickelson a great player cause i hate the {prick => expletive}  [synonyms 1.09861228867, phonemes 9.0, freq 8.05, cc -, susceptibility 0.68]
#     i would n't call mickelson a great player cause i hate the {prick => expletive}  [synonyms 1.09861228867, phonemes 9.0, freq 8.05, cc -, susceptibility 0.68]
#
# - outcome (synonyms 1.60943791243, phonemes 5.0, freq 8.18, cc -1.69, susceptibility 0.5)
#
#     i am delighted with the {outcome => result}  [synonyms 0.944461608841, phonemes 6.0, freq 10.08, cc -1.84, susceptibility 0.0]
#
# - abuse (synonyms 0.944461608841, phonemes 5.0, freq 9.00, cc -1.79, susceptibility 1.0)
#
#     even adolescents with no prior history of behavioral problems or family history of substance {abuse => use} problems were at risk for poor health outcomes if they used substances prior to age 15 [synonyms 0.570544858468, phonemes 3.0, freq 11.22, cc -3.61, susceptibility 0.0333333333333]
#
# - amuck (synonyms 0.980829253012, phonemes 4.0, freq 2.94, cc -, susceptibility 1.0)
#
#     the banning of these decals is political correctness run {amuck => amok} in the military [synonyms 0.980829253012, phonemes 4.0, freq 3.91, cc -, susceptibility -]
#
# - blood (synonyms 1.04145387483, phonemes 4.0, freq 8.99, cc -3.27, susceptibility 1.0)
#
#     down with the government of {blood => murderers}  [synonyms 0.69314718056, phonemes 5.0, freq 6.64, cc -1.59, susceptibility -]
#     that for several months alexei cherepanov engaged in {blood => doping}  [synonyms 1.09861228867, phonemes 3.0, freq 5.17, cc -1.69, susceptibility -]
#
# - nothing (synonyms 1.8718021769, phonemes 5.0, freq 10.83, cc -3.09, susceptibility 0.0) [nosubs]
#
# - spouse (synonyms 1.38629436112, phonemes 4.0, freq 6.01, cc -1.02, susceptibility 1.0)
#
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#     where did you meet your {spouse => husband}  [synonyms 0.916290731874, phonemes 7.0, freq 8.73, cc -1.26, susceptibility -]
#
# - totally (synonyms 1.79175946923, phonemes 6.0, freq 8.83, cc -, susceptibility 0.0) [nosubs]
#
# - assume (synonyms 1.06087196069, phonemes 4.0, freq 8.31, cc -2.45, susceptibility 0.0) [nosubs]
#
# - maybe (synonyms 1.60943791243, phonemes 4.0, freq 9.66, cc -2.61, susceptibility 0.0) [nosubs]
#
#
# =============================================================
# #synonyms [ 0.93895647  1.90057867] --- #phonemes [  7.  10.]
#
# - battlefield (synonyms 1.38629436112, phonemes 9.0, freq 7.06, cc -, susceptibility 0.0) [nosubs]
#
# - obscenity (synonyms 0.980829253012, phonemes 8.0, freq 4.37, cc -, susceptibility 1.0)
#
#     deserve a bullet in their {obscenity => heads}  [synonyms -0.0487901641694, phonemes 3.0, freq 9.92, cc -3.51, susceptibility 0.0]
#     deserve a bullet in their {obscenity => heads}  [synonyms -0.0487901641694, phonemes 3.0, freq 9.92, cc -3.51, susceptibility 0.0]
#
# - violation (synonyms 0.955511445027, phonemes 8.0, freq 8.85, cc -1.63, susceptibility 0.0) [nosubs]
#
# - recreate (synonyms 1.09861228867, phonemes 7.0, freq 5.43, cc -, susceptibility 1.0)
#
#     you ca n't just make stuff up you ca n't just {recreate => reinvent} yourself [synonyms -, phonemes 8.0, freq 6.75, cc -, susceptibility -]
#     you ca n't just make stuff up you ca n't just {recreate => reinvent} yourself [synonyms -, phonemes 8.0, freq 6.75, cc -, susceptibility -]
#
# - authority (synonyms 0.944461608841, phonemes 7.0, freq 9.59, cc -2.18, susceptibility 0.0) [nosubs]
#
# - livelihood (synonyms 1.60943791243, phonemes 8.0, freq 6.51, cc -, susceptibility 0.0) [nosubs]
#
# - society (synonyms 1.17865499634, phonemes 7.0, freq 9.00, cc -2.53, susceptibility 1.0)
#
#     detrimental to the progress of {society => humanity}  [synonyms 1.09861228867, phonemes 8.5, freq 8.21, cc -, susceptibility -]
#
# - computer (synonyms 1.50407739678, phonemes 8.0, freq 9.13, cc -3.43, susceptibility 0.0) [nosubs]
#
# - determine (synonyms 1.09861228867, phonemes 7.0, freq 9.30, cc -2.03, susceptibility 0.0) [nosubs]
#
# - superpower (synonyms 1.38629436112, phonemes 7.0, freq 6.58, cc -, susceptibility 0.0) [nosubs]
#
# - coalition (synonyms 0.980829253012, phonemes 8.0, freq 8.21, cc -, susceptibility 0.0) [nosubs]
#
# - certainly (synonyms 1.79175946923, phonemes 7.0, freq 9.49, cc -, susceptibility 0.0) [nosubs]
#
# - upheaval (synonyms 1.01160091168, phonemes 7.0, freq 4.62, cc -, susceptibility 0.0) [nosubs]
#
# - congress (synonyms 1.17865499634, phonemes 7.0, freq 10.06, cc -2.38, susceptibility 0.0) [nosubs]
#
# - liberation (synonyms 1.09861228867, phonemes 8.0, freq 6.28, cc -, susceptibility 0.0) [nosubs]
#
# - generally (synonyms 0.980829253012, phonemes 7.0, freq 7.57, cc -, susceptibility 0.0) [nosubs]
#
# - priority (synonyms 1.2527629685, phonemes 8.0, freq 9.01, cc -, susceptibility 0.0) [nosubs]
#
# - awfulness (synonyms 1.09861228867, phonemes 7.0, freq 4.73, cc -, susceptibility 0.0) [nosubs]
#
# - blatant (synonyms 1.09861228867, phonemes 7.0, freq 6.73, cc -, susceptibility 0.0) [nosubs]
#
# - homeland (synonyms 1.60943791243, phonemes 7.0, freq 7.35, cc -, susceptibility 0.0) [nosubs]
#
# - progress (synonyms 1.3437347467, phonemes 7.0, freq 9.31, cc -1.61, susceptibility 0.5)
#
#     there is no {progress => consistency} at all [synonyms 0.0, phonemes 11.0, freq 5.99, cc -, susceptibility -]
#
# - percentage (synonyms 1.09861228867, phonemes 7.5, freq 7.14, cc -2.25, susceptibility 1.0)
#
#     anywhere from three to four {percentage => months}  [synonyms -0.69314718056, phonemes 4.0, freq 10.37, cc -2.36, susceptibility 0.333333333333]
#
# - instantly (synonyms 1.79175946923, phonemes 9.0, freq 6.59, cc -, susceptibility 0.0) [nosubs]
#
# - worldwide (synonyms 1.29928298413, phonemes 7.0, freq 8.40, cc -, susceptibility 0.5)
#
#     the department faces the real possibility that one of its primary worldwide personal protective services contractors in iraq blackwater {worldwide => usa} will not receive a license to continue operating in iraq [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - expletive (synonyms 1.09861228867, phonemes 9.0, freq 8.05, cc -, susceptibility 0.68)
#
#     maybe we ca n't do this now fire those {expletives => fuckers}  [synonyms -, phonemes 4.0, freq 2.89, cc -, susceptibility -]
#     if they do n't perform {expletive => fuck} em [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     if they do n't perform {expletive => f} em [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => f} expletive them [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     not willing to give me anything except appreciation {expletive => f} them [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => fuck} expletive them [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     they ' re not willing to give me anything except {expletive => f} expletive them [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     not willing to give me anything except appreciation {expletive => f} them [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => fuck} expletive them [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     they ' re not willing to give me anything except {expletive => bleep} expletive them [synonyms -0.69314718056, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i do n't even celebrate that {expletive => shit} i ' m black [synonyms 1.90954250488, phonemes 3.0, freq 6.83, cc -2.89, susceptibility 0.5]
#     i do n't even celebrate that {expletive => shit} i ' m black [synonyms 1.90954250488, phonemes 3.0, freq 6.83, cc -2.89, susceptibility 0.5]
#     is a {expletive => f-ing} valuable thing you just do n't give it away for nothing [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     a {expletive => fucking} valuable thing you just do n't give it away for nothing [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     is a {expletive => fucking} valuable thing you just do n't give it away for nothing [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     is a {expletive => fucking} valuable thing you just do n't give it away for nothing [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     a {expletive => fucking} valuable thing you just do n't give it away for nothing [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     i ' ve got this thing and it {expletive => bleeping} s expletive golden [synonyms -0.69314718056, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i ' ve got this thing and it {expletive => fxxking} s expletive golden [synonyms -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     i ' ve got this thing and it {expletive => bleeping} s expletive golden [synonyms -0.69314718056, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i would n't call mickelson a great player cause i hate the {expletive => prick}  [synonyms 1.03609193169, phonemes 4.0, freq 5.82, cc -1.72, susceptibility 1.0]
#     i would n't call mickelson a great player cause i hate the {expletive => p}  [synonyms 0.405465108108, phonemes 2.0, freq 7.54, cc -, susceptibility 1.0]
#     i do n't know what the {expletive => fuck} i ' m going to do [synonyms 2.86220088093, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     come help a {expletive => nigger} get elected [synonyms 1.60943791243, phonemes 4.0, freq 5.42, cc -, susceptibility 1.0]
#      {expletive => f} you i wo n't do what you tell me [synonyms 0.223143551314, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#
# - solvent (synonyms 0.980829253012, phonemes 7.0, freq 5.25, cc -, susceptibility 0.0) [nosubs]
#
# - complete (synonyms 0.99325177301, phonemes 7.0, freq 9.36, cc -2.43, susceptibility 0.0)
# [nosubs]
#
# - graveyard (synonyms 1.79175946923, phonemes 8.0, freq 5.94, cc 0.00, susceptibility 1.0)
#
#     zionists should know that gaza will become their {graveyard => cemetery}  [synonyms 1.79175946923, phonemes 8.0, freq 5.50, cc -1.36, susceptibility -]
#
# - exactly (synonyms 0.980829253012, phonemes 8.0, freq 9.29, cc -, susceptibility 0.5)
#
#     is not {exactly => really} clear given the nature of the situation [synonyms 0.69314718056, phonemes 4.0, freq 11.35, cc -, susceptibility 0.1]
#
# - mentality (synonyms 1.38629436112, phonemes 9.0, freq 6.98, cc -, susceptibility 0.0) [nosubs]
#
# - ultimately (synonyms 1.38629436112, phonemes 9.0, freq 8.50, cc -, susceptibility 0.0) [nosubs]
#
# - completely (synonyms 1.09861228867, phonemes 9.0, freq 9.31, cc -, susceptibility 1.0)
#
#     i think she will do a {completely => totally} objective job [synonyms 1.79175946923, phonemes 6.0, freq 8.83, cc -, susceptibility 0.0]
#
# - probably (synonyms 1.2527629685, phonemes 7.0, freq 10.02, cc 0.00, susceptibility 0.0) [nosubs]
#
# - immediately (synonyms 1.09861228867, phonemes 9.0, freq 9.17, cc -, susceptibility 0.0) [nosubs]
#
# - mujahideen (synonyms 1.79175946923, phonemes 9.0, freq 5.82, cc -, susceptibility 1.0)
#
#     in the name of allah the indian {mujahideen => mujahidin} has struck back again [synonyms 1.79175946923, phonemes -, freq 1.79, cc -, susceptibility -]
#
# - judgment (synonyms 0.998528830111, phonemes 7.0, freq 9.09, cc -1.53, susceptibility 0.0) [nosubs]
#
# - legislature (synonyms 1.38629436112, phonemes 9.0, freq 7.01, cc -1.96, susceptibility 0.0) [nosubs]
#
# - television (synonyms 1.38629436112, phonemes 9.0, freq 8.63, cc -3.51, susceptibility 1.0)
#
#     you can still make a lot of money in network {television => tv}  [synonyms 1.70474809224, phonemes 6.5, freq 8.56, cc -, susceptibility 1.0]
#
# - substance (synonyms 1.0498221245, phonemes 8.0, freq 8.00, cc -2.30, susceptibility 0.0) [nosubs]
#
# - dangerous (synonyms 1.09861228867, phonemes 7.0, freq 9.29, cc -2.65, susceptibility 0.0) [nosubs]
#
# - uncertainty (synonyms 1.2527629685, phonemes 9.0, freq 8.41, cc -, susceptibility 0.0) [nosubs]
#
# - terrible (synonyms 1.70474809224, phonemes 7.0, freq 8.57, cc -1.63, susceptibility 0.0) [nosubs]
#
# - obviously (synonyms 1.79175946923, phonemes 8.0, freq 9.59, cc -, susceptibility 0.0) [nosubs]
#
# - definitely (synonyms 1.60943791243, phonemes 9.0, freq 9.21, cc -, susceptibility 0.333333333333)
#
#      {definitely => i} regret all the things i said about samantha [synonyms 1.09861228867, phonemes 1.0, freq 14.24, cc -1.10, susceptibility 0.0268817204301]
#
# - heartbeat (synonyms 1.38629436112, phonemes 7.0, freq 7.63, cc -, susceptibility 0.0) [nosubs]
#
# - entirely (synonyms 1.60943791243, phonemes 7.0, freq 7.82, cc -, susceptibility 0.0) [nosubs]
#
# - opinion (synonyms 0.980829253012, phonemes 7.0, freq 9.01, cc -2.55, susceptibility 0.0) [nosubs]
#
#
# =============================================================
# #synonyms [ 0.93895647  1.90057867] --- #phonemes [ 10.  13.]
#
# - constitution (synonyms 1.09861228867, phonemes 11.0, freq 9.03, cc -1.95, susceptibility 0.0) [nosubs]
#
# - abundantly (synonyms 1.09861228867, phonemes 10.0, freq 6.01, cc -, susceptibility 1.0)
#
#     made it {abundantly => absolutely} clear that voluntary regulation does not work [synonyms 0.405465108108, phonemes 9.0, freq 9.65, cc -, susceptibility 0.0]
#     made it {abundantly => absolutely} clear that voluntary regulation does not work [synonyms 0.405465108108, phonemes 9.0, freq 9.65, cc -, susceptibility 0.0]
#
# - magnificent (synonyms 1.09861228867, phonemes 11.0, freq 6.56, cc 0.00, susceptibility 0.0) [nosubs]
#
# - ridiculous (synonyms 1.38629436112, phonemes 10.0, freq 7.72, cc -1.14, susceptibility 1.0)
#
#     why would that kind of work be {ridiculous => ridiculed}  [synonyms 1.09861228867, phonemes 8.0, freq 5.38, cc -2.13, susceptibility -]
#
# - detrimental (synonyms 1.09861228867, phonemes 10.5, freq 5.74, cc -, susceptibility 0.0) [nosubs]
#
# - organization (synonyms 0.944461608841, phonemes 11.0, freq 9.14, cc -2.10, susceptibility 0.0) [nosubs]
#
# - demonstrate (synonyms 1.17865499634, phonemes 10.0, freq 8.55, cc -, susceptibility 0.0) [nosubs]
#
# - availability (synonyms 1.09861228867, phonemes 11.0, freq 7.59, cc -, susceptibility 0.0) [nosubs]
#
# - prosecutor (synonyms 1.09861228867, phonemes 10.0, freq 6.68, cc -, susceptibility 0.0) [nosubs]
#
# - therapeutic (synonyms 1.09861228867, phonemes 10.0, freq 5.28, cc -, susceptibility 0.0) [nosubs]

# %% [markdown]
# ## Feature variations on substitution

# %%
nbins_variations = 5
n_pts_threshold = 10

# Build variations
for a in analyses:
    if a.feature.fullname == 'cmu MNphonemes all':
        a.set_bins(nbins_variations, truncmax=25)
    else:
        a.set_bins(nbins_variations)
    a.build_h0()
    # Force rebuild of variations in case our n_pts_threshold has changed
    try:
        del a.daughter_d
    except AttributeError:
        pass
    a.build_variations(n_pts_threshold)

# Convert to DataFrame
vdata_binned = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * len(a.bin_middles) 
                                                        for a in analyses]),
                             'disappearing bin middles': np.concatenate([a.bin_middles
                                                                         for a in analyses]),
                             'appearing bin averages': np.concatenate([a.daughter_d
                                                                       for a in analyses]),
                             'appearing H0': np.concatenate([a.daughter_d_h0
                                                             for a in analyses]),
                             'appearing H0n': np.concatenate([a.daughter_d_h0_n
                                                              for a in analyses]),
                             'ci': np.concatenate([a.daughter_d_ci for a in analyses])})
vdata_raw = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * len(a.l2_f_mothers)
                                                     for a in analyses]),
                          'disappearing raw': np.concatenate([a.l2_f_mothers for a in analyses]),
                          'appearing raw': np.concatenate([a.l2_f_daughters for a in analyses]),
                          'appearing H0': np.concatenate([np.ones_like(a.l2_f_daughters) *
                                                          a.feature.values.mean() for a in analyses])})

# %%
with_h0n = False

def plot_variations(xvalues, avalues, h0s, h0ns, cis, **kwargs):
    color = kwargs.get('color', 'blue')
    
    plt.plot(xvalues, avalues, '-', lw=2, color=color, label=r'$\nu_{\phi}$')
    plt.plot(xvalues, h0s, linestyle='--', color=sb.desaturate(color, 0.2), 
             label=r'$\nu_{\phi}^0$')
    if with_h0n:
        plt.plot(xvalues, h0ns, linestyle='-.', color=sb.desaturate(color, 0.2), 
                 label=r'$\nu_{\phi}^{00}$')
    plt.plot(xvalues, xvalues, linestyle='dotted', color=sb.desaturate(color, 0.2), label=r'$y = x$')
    plt.fill_between(xvalues.values, avalues.values - cis.values, avalues.values + cis.values,
                     color=sb.desaturate(color, 0.2), alpha=0.2)
    xmin, xmax = xvalues.iloc[0], xvalues.iloc[-1]
    plt.xlim(xmin, xmax)
    #plt.text(xmin + (xmax - xmin) * 0.05, h0s.iloc[-1], r'$\mathcal{H}_0$', ha='left', va='center',
    #         bbox=dict(facecolor=sb.desaturate('#EAEAF2', 0.2), alpha=0.7))
    # Rescale on Y if we're touching h0, making sure the h0 line is visible
    ymin, ymax = plt.ylim()
    if ymin == h0s.min():
        ymin -= (ymax - ymin) / 10
    elif ymax == h0s.max():
        ymax += (ymax - ymin) / 10
    plt.ylim(ymin, ymax)

def plot_facetgrid():
    vg = sb.FacetGrid(vdata_binned, col='feature', col_wrap=3, 
                      col_order=translate(included_features),
                      aspect=1.5, size=3, sharex=False, sharey=False, hue='feature',
                      palette=palette_dict)#,
                      #legend=True)
    vg.map(plot_variations, 'disappearing bin middles', 'appearing bin averages', 
           'appearing H0', 'appearing H0n', 'ci')
    vg.set_titles('{col_name}')
    vg.set_xlabels(r'$f \left( \right.$ disappearing word $\left. \right)$')
    vg.set_ylabels(r'$f \left( \right.$ appearing word $\left. \right)$')
    for ax in vg.axes.ravel():
        legend = ax.legend(frameon=True, loc='upper left')
        if not legend:
            # Skip if nothing was plotted on these axes
            continue
        frame = legend.get_frame()
        frame.set_facecolor('#f2f2f2')
        frame.set_edgecolor('#000000')
    # Remove the last axis and recenter the lower row
    #vg.axes[1, 2].set_axis_off()
    pts02 = vg.axes[2].get_position().get_points()
    pts01 = vg.axes[1].get_position().get_points()
    trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
    box10 = vg.axes[3].get_position()
    box11 = vg.axes[4].get_position()
    vg.axes[2].set_xlabel('')
    vg.axes[3].set_position(TransformedBbox(box10, trans))
    vg.axes[4].set_position(TransformedBbox(box11, trans))
    
    if with_h0n:
        filename = 'data/figures_paper/feature_variations-binned-with-H00.png'
    else:
        filename = 'data/figures_paper/feature_variations-binned.png'
    vg.fig.savefig(filename, bbox_inches='tight', dpi=300)

plot_facetgrid()
with_h0n = True
plot_facetgrid()

# %%
from pprint import pprint
for a in sa.analyses:
    mothers_flist = []
    for m in set(a.mothers):
        try:
            mothers_flist.append((a.feature(m), m))
        except KeyError:
            continue
    print '========================================='
    print a.feature.fullname + ' ({} words)'.format(len(mothers_flist))
    sorted_mothers_flist = sorted(mothers_flist, reverse=True)
    pprint(sorted_mothers_flist[:20])
    print '...'
    pprint(sorted_mothers_flist[-20:])
# Out:
# =========================================
# mt frequencies all (508 words)
# [(14.240597231226223, u'i'),
#  (14.21239899132158, '<unknown>'),
#  (13.158924788515463, "n't"),
#  (12.825904232229476, u'go'),
#  (12.585980600774031, 'get'),
#  (12.377076228339964, u'know'),
#  (12.374286826252387, 'think'),
#  (12.328166376773641, 'time'),
#  (12.245269319932989, 'good'),
#  (12.206372600539172, 'just'),
#  (12.091469548505415, u'want'),
#  (12.076351128959413, 'say'),
#  (12.050061903526016, u'take'),
#  (11.940315130494184, 'see'),
#  (11.88501302202144, u'world'),
#  (11.828896115794956, 'thing'),
#  (11.814155349967278, u'right'),
#  (11.803054541065061, 'work'),
#  (11.746074791145114, 'way'),
#  (11.745385482921787, u'need')]
# ...
# [(4.3694478524670215, 'obscenity'),
#  (4.3694478524670215, 'carling'),
#  (4.3307333402863311, 'lunchtime'),
#  (4.3174881135363101, u'golfer'),
#  (4.290459441148391, u'Richardson'),
#  (4.219507705176107, u'chatty'),
#  (4.2046926193909657, u'aaah'),
#  (4.1896547420264252, 'playmate'),
#  (4.1588830833596715, 'backlog'),
#  (4.0073331852324712, u'jewellery'),
#  (3.7376696182833684, u'fraternity'),
#  (3.5835189384561099, 'well-equip'),
#  (3.5263605246161616, u'regretful'),
#  (2.9444389791664403, u'amuck'),
#  (2.8332133440562162, u'libra'),
#  (2.8332133440562162, 'gimp'),
#  (2.7080502011022101, u'decarbonisation'),
#  (2.4849066497880004, 'ancestry'),
#  (2.1972245773362196, 'plat'),
#  (1.6094379124341003, 'spirite')]
# =========================================
# cmu MNphonemes all (535 words)
# [(15.0, u'extraordinarily'),
#  (13.0, u'superconducting'),
#  (13.0, u'administrative'),
#  (13.0, u'administration'),
#  (12.0, u'unmentionable'),
#  (12.0, u'manufacturing'),
#  (12.0, u'investigating'),
#  (12.0, u'experiences'),
#  (11.5, u'fundamentals'),
#  (11.0, u'republicans'),
#  (11.0, u'patriotism'),
#  (11.0, u'intimidation'),
#  (11.0, u'institutions'),
#  (11.0, u'instability'),
#  (11.0, u'inexpensive'),
#  (11.0, u'individual'),
#  (11.0, u'disorganized'),
#  (11.0, u'development'),
#  (11.0, u'determination'),
#  (10.5, u'international')]
# ...
# [(3.0, u'allow'),
#  (3.0, u'act'),
#  (2.5, u'new'),
#  (2.0, u'way'),
#  (2.0, u'see'),
#  (2.0, u'p'),
#  (2.0, u'oil'),
#  (2.0, u'n'),
#  (2.0, u'law'),
#  (2.0, u'know'),
#  (2.0, u'j'),
#  (2.0, u'gay'),
#  (2.0, u'f'),
#  (2.0, u'eyes'),
#  (2.0, u'day'),
#  (2.0, u'd'),
#  (2.0, u'al'),
#  (2.0, u'air'),
#  (2.0, u"'s"),
#  (1.0, u'i')]
# =========================================
# fa CCs all (331 words)
# [(0.0, 'rebuild'),
#  (0.0, 'provide'),
#  (0.0, u'libra'),
#  (0.0, 'graveyard'),
#  (0.0, 'dishonor'),
#  (0.0, u'disabled'),
#  (0.0, u'commission'),
#  (-0.61090908232297325, u'booze'),
#  (-0.74193734472937733, u'inexpensive'),
#  (-0.916290731874155, u'steady'),
#  (-0.96281074750904783, 'cyclone'),
#  (-1.0163741904311376, u'spouse'),
#  (-1.0340737675305385, 'text'),
#  (-1.0498221244986778, u'purchase'),
#  (-1.0986122886681098, 'thunder'),
#  (-1.0986122886681098, 'investigate'),
#  (-1.0986122886681098, u'i'),
#  (-1.0986122886681098, u'consume'),
#  (-1.143563676530376, u'ridiculous'),
#  (-1.1451323043030026, 'terror')]
# ...
# [(-3.4019844733989726, 'time'),
#  (-3.4299467949481413, 'set'),
#  (-3.4435150313259699, 'long'),
#  (-3.4800008464920715, 'school'),
#  (-3.481382529333084, u'small'),
#  (-3.4946743803848195, 'life'),
#  (-3.5044969514999589, u'help'),
#  (-3.5095654183839371, u'television'),
#  (-3.51242301677238, 'baby'),
#  (-3.5366094074942369, 'work'),
#  (-3.5516546131540618, 'oil'),
#  (-3.5733927041546956, u'house'),
#  (-3.5818923207222255, 'bad'),
#  (-3.6109179126442243, u'use'),
#  (-3.670784791499099, u'big'),
#  (-3.6988661850035083, 'food'),
#  (-3.7679234248128766, u'movie'),
#  (-3.8059078134367281, 'money'),
#  (-3.8135563339900407, 'good'),
#  (-4.020777754153988, u'man')]
# =========================================
# aoa Kuperman all (426 words)
# [(18.33, u'marcel'),
#  (15.31, u'volatility'),
#  (14.72, u'commission'),
#  (14.5, 'plat'),
#  (14.08, u'criterion'),
#  (14.06, 'superconducting'),
#  (13.68, u'socialism'),
#  (13.53, u'commodity'),
#  (13.28, 'mainstream'),
#  (13.0, 'sector'),
#  (12.95, u'fraternity'),
#  (12.85, 'expletive'),
#  (12.84, u'casualty'),
#  (12.83, 'terrorism'),
#  (12.76, u'terrorist'),
#  (12.67, 'ideology'),
#  (12.62, 'reinstate'),
#  (12.59, u'militant'),
#  (12.56, u'economy'),
#  (12.55, u'instability')]
# ...
# [(3.55, 'good'),
#  (3.5, u'day'),
#  (3.42, 'say'),
#  (3.38, 'family'),
#  (3.37, u'go'),
#  (3.26, 'chicken'),
#  (3.26, 'arm'),
#  (3.25, 'food'),
#  (3.22, u'small'),
#  (3.17, 'get'),
#  (3.16, u'house'),
#  (3.11, u'man'),
#  (3.06, 'see'),
#  (3.06, 'grandpa'),
#  (3.05, u'fly'),
#  (2.89, u'big'),
#  (2.79, 'bad'),
#  (2.72, u'happy'),
#  (2.61, 'count'),
#  (2.22, u'mom')]
# =========================================
# wn MNSyns all (451 words)
# [(2.8622008809294686, u'fuck'),
#  (2.6390573296152584, u'goodbye'),
#  (2.1972245773362196, u'movie'),
#  (2.0794415416798357, u'mom'),
#  (2.0149030205422647, 'ancestry'),
#  (1.9095425048844386, 'shit'),
#  (1.791759469228055, u'mujahideen'),
#  (1.791759469228055, 'graveyard'),
#  (1.791759469228055, u'crap'),
#  (1.7047480922384253, 'tv'),
#  (1.6094379124341003, 'outcome'),
#  (1.6094379124341003, u'nigger'),
#  (1.6094379124341003, 'grandpa'),
#  (1.6094379124341003, u'global'),
#  (1.6094379124341003, 'definitely'),
#  (1.5581446180465499, u'attain'),
#  (1.5040773967762742, u'phony'),
#  (1.3862943611198906, 'workout'),
#  (1.3862943611198906, u'television'),
#  (1.3862943611198906, u'spouse')]
# ...
# [(-0.69314718055994529, u'boy'),
#  (-0.69314718055994529, u'bleep'),
#  (-0.69314718055994529, 'baker'),
#  (-0.69314718055994529, 'backlog'),
#  (-0.69314718055994529, 'anxiety'),
#  (-0.916290731874155, u'purchase'),
#  (-0.916290731874155, 'elect'),
#  (-0.916290731874155, 'economic'),
#  (-0.916290731874155, 'banking'),
#  (-1.0986122886681098, 'self'),
#  (-1.0986122886681098, 're-create'),
#  (-1.0986122886681098, 'party'),
#  (-1.0986122886681098, u'magnitude'),
#  (-1.0986122886681098, 'face-to-face'),
#  (-1.0986122886681098, 'challenge'),
#  (-1.2527629684953681, 'bail'),
#  (-1.6094379124341003, u'republican'),
#  (-1.791759469228055, 'thing'),
#  (-1.791759469228055, 'sector'),
#  (-1.791759469228055, 'half')]

# %%
def kdeplot(xvalues, yvalues, h0s, **kwargs):
    color = kwargs.get('color', 'blue')
    sb.kdeplot(pd.DataFrame({'X': xvalues, 'Y': yvalues}), shade=True)
    xmin, xmax = plt.xlim()
    plt.plot(xvalues, h0s, linestyle='dashed', color=sb.desaturate(color, 0.2))
    plt.xlim(xmin, xmax)

vg = sb.FacetGrid(vdata_raw, col='feature', col_wrap=3, col_order=translate(included_features),
                  aspect=1, size=4, sharex=False, sharey=False)
vg.map(kdeplot, 'disappearing raw', 'appearing raw', 'appearing H0')
vg.set_titles('{col_name}')
vg.set_xlabels(r'$f \left( \right.$ disappearing word $\left. \right)$')
vg.set_ylabels(r'$f \left( \right.$ appearing word $\left. \right)$')
# Remove the last axis and recenter the lower row
from matplotlib.transforms import Affine2D, TransformedBbox
#vg.axes[1, 2].set_axis_off()
pts02 = vg.axes[2].get_position().get_points()
pts01 = vg.axes[1].get_position().get_points()
trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
box10 = vg.axes[3].get_position()
box11 = vg.axes[4].get_position()
vg.axes[2].set_xlabel('')
vg.axes[3].set_position(TransformedBbox(box10, trans))
vg.axes[4].set_position(TransformedBbox(box11, trans))
