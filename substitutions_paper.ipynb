# %% [markdown]
# # How do features vary on substitution? What susceptibility to substitution do they induce?

# %% [markdown]
# ## Data-loading and formatting
#
# See below for graphs.

# %%
# Initial imports
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D, TransformedBbox
import numpy as np
import seaborn as sb
import pandas as pd
from pprint import pprint

from analyze.args import AnalysisArgs
from analyze.substitutions import SubstitutionsAnalyzer
from util.generic import is_twelfth_int
from linguistics.treetagger import get_tagger
tagger = get_tagger()

# %%
included_features = ['mt_frequencies',
                     'aoa_Kuperman',
                     'cmu_MNphonemes',
                     'wn_MNSyns',
                     'fa_CCs']

# Build the analysis classes
aa = AnalysisArgs({'ff': 'filtered',
                   'model': 'tbgs',
                   'POS': 'all',
                   'substrings': True,
                   'timebag_size': 1.0,
                   'features': included_features,
                   'positions': False,
                   'paths': False,
                   'save': False,
                   'overwrite': False,
                   'show': True})
sa = SubstitutionsAnalyzer(aa)

print 'Loaded the {} substitutions that have been mined.'.format(len(sa.substitutions))
# Out:
# Loading substitutions...
# OK
# Loading analysis cases... Building NX graph... Building lemma coordinates...
# OK
# Building WordNet adjacency matrix...
# OK
# OK
# OK
# Loaded the 1051 substitutions that have been mined.

# %% [markdown]
# ## Susceptibility to substitution for all the features
#
# *feature value* ~ *susceptibility value*

# %%
# Translating internal feature names to public names
tr_map = {'aoa_Kuperman': 'Age of acquisition',
          'cmu_MNphonemes': r'$\left< \right.$ \# phonemes $\left. \right>$',
          'cmu_MNsyllables': r'$\left< \right.$ \# syllables $\left. \right>$',
          'fa_BCs': 'FA log-betweenness',
          'fa_CCs': 'FA log-clustering',
          'fa_degrees': 'FA log-degree',
          'fa_PR_scores': 'FA log-pagerank',
          'mt_frequencies': 'Log-frequency',
          'mt_start_frequencies': 'Log-frequency in start quotes',
          'wn_BCs': 'WN log-betweenness',
          'wn_CCs': 'WN log-clustering',
          'wn_degrees': 'WN log-degree',
          'wn_MNSyns': r'Log $\left< \right.$ \# synonyms $\left. \right>$',
          'wn_NSigns': r'Log \# meanings',
          'wn_PR_scores': 'WN log-pagerank'}

back_tr_map = dict([(v, k) for k, v in tr_map.iteritems()])

def _translate(labels, tr):
    if isinstance(labels, list):
        return [tr[l] for l in labels]
    else:
        return tr[labels]

def translate(labels):
    """Translate a list of internal labels to human-readable ones."""
    return _translate(labels, tr_map)

def back_translate(labels):
    """Translate a list of human-readable labels to internal ones."""
    return _translate(labels, back_tr_map)

# %%
# Build susceptibilities and filter out zeros
for a in sa.analyses:
    try:
        a.f_susceptibilities
    except AttributeError:
        a.build_susceptibilities()
        # The try-except here lets us run this cell several times without overwriting
        # the original unfiltered susceptibilities each time.
        a.f_susceptibilities_orig = a.f_susceptibilities
    
    a.f_susceptibilities = a.f_susceptibilities_orig#[np.nonzero(a.f_susceptibilities_orig[:, 1])]
    # Remove MNSyns outlier
    #if a.feature.fullname == 'wn MNSyns all':
    #    a.f_susceptibilities = \
    #            a.f_susceptibilities_orig[np.nonzero(a.f_susceptibilities_orig[:, 1])][:-1]

# Set names, order and colorify analyses
for a in sa.analyses:
    a.feature.shortfullname = a.feature.fullname.replace(' ', '_').rstrip('_all')
    a.feature.publicname = translate(a.feature.shortfullname)
analyses = sorted(sa.analyses, key=lambda a: included_features.index(a.feature.shortfullname))
palette = sb.color_palette('husl', len(included_features))
palette_dict = dict(zip([a.feature.publicname for a in analyses], palette))

# Convert to DataFrame
sdata = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * 
                                                 len(a.f_susceptibilities) for a in analyses]),
                      'feature value': np.concatenate([a.f_susceptibilities[:, 0] for a in analyses]),
                      'substitution susceptibility': np.concatenate([a.f_susceptibilities[:, 1] 
                                                                     for a in analyses])})

# %%
# Don't close the figure after drawing
# %config InlineBackend.close_figures=False

nbins_suscepts = 5
n_pts_threshold = 15

bins_cache = []

# Our plotting function for a given feature
def plot_susceptibility(xvalues, svalues, **kwargs):
    color = kwargs.get('color', 'blue')
    
    #if is_twelfth_int(xvalues):
    #    bins = np.linspace(int(np.floor(xvalues.iloc[0])) - 0.5, int(np.ceil(xvalues.iloc[-1])) + 0.5,
    #                       (int(np.ceil(xvalues.iloc[-1])) - int(np.floor(xvalues.iloc[0])) + 2) / 2)
    #else:
    #    bins = np.linspace(xvalues.iloc[0], xvalues.iloc[-1], nbins)
    bins = np.linspace(xvalues.iloc[0], xvalues.iloc[-1], nbins_suscepts + 1)
    bins_cache.append(bins)
    xs = (bins[1:] + bins[:-1]) / 2
    ys = np.zeros_like(xs)
    cs = np.zeros_like(xs)
    for i in range(len(bins) - 1):
        idx = np.where((bins[i] <= xvalues) * (xvalues < bins[i + 1]))[0]
        if len(idx) > n_pts_threshold:
            yss = svalues.iloc[idx]
            ys[i] = yss.mean()
            cs[i] = 1.96 * yss.std() / np.sqrt(len(idx) - 1)
        else:
            ys[i] = np.nan
            cs[i] = np.nan
    
    #plt.hlines(0, xs[0], xs[-1], linestyles='dashed', colors=sb.desaturate(color, 0.2))
    #plt.hlines(1, xs[0], xs[-1], linestyles='dashed', colors=sb.desaturate(color, 0.2))
    plt.plot(xs, ys, '-', lw=2, color=color)
    plt.fill_between(xs, ys - cs, ys + cs, color=sb.desaturate(color, 0.2), alpha=0.2)
    plt.xlim(xs[np.isfinite(ys)][0], xs[np.isfinite(ys)][-1])
    ylim = plt.ylim()
    plt.ylim(max([0, ylim[0]]), min([1, ylim[1]]))

# Plot!
sg = sb.FacetGrid(sdata, col='feature', col_wrap=3, col_order=translate(included_features),
                  aspect=1.5, size=3, sharex=False, sharey=False, hue='feature', palette=palette_dict)
sg.map(plot_susceptibility, 'feature value', 'substitution susceptibility')
sg.set_titles('{col_name}')
# Remove the last axis and recenter the lower row
#sg.axes[1, 2].set_axis_off()
#pts02 = sg.axes[2].get_position().get_points()
#pts01 = sg.axes[1].get_position().get_points()
#trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
#box10 = sg.axes[3].get_position()
#box11 = sg.axes[4].get_position()
sg.axes[2].set_xlabel('')
#sg.axes[3].set_position(TransformedBbox(box10, trans))
#sg.axes[4].set_position(TransformedBbox(box11, trans))

# Save bins
feature_bins = {}
for i in range(5):
    feature_bins[back_translate(sg.axes[i].get_title())] = bins_cache[i]

# Figure is saved later on, once we've added the heatmap
# Out:
# /home/sl/.virtualenvs/brainscopypaste/local/lib/python2.7/site-packages/pandas/computation/expressions.py:190: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   unsupported[op_str]))

# %% [markdown]
# ### Age ~ Phonemes susceptibility heatmap

# %%
analysis_names = [a.feature.fullname for a in sa.analyses]
a_age = sa.analyses[analysis_names.index('aoa Kuperman all')]
a_phonemes = sa.analyses[analysis_names.index('cmu MNphonemes all')]
a_freq = sa.analyses[analysis_names.index('mt frequencies all')]
a_cc = sa.analyses[analysis_names.index('fa CCs all')]

a_age.build_susceptibilities()
a_phonemes.build_susceptibilities()

ws_age = a_age.w_susceptibilities
wf_age = {}
wf_age_full = a_age.feature.data
wf_freq_full = a_freq.feature.data
wf_cc_full = a_cc.feature.data
ws_phonemes = a_phonemes.w_susceptibilities
wf_phonemes = {}
wf_phonemes_full = a_phonemes.feature.data
w_age_phonemes = set(ws_age.keys()).intersection(ws_phonemes.keys())

n_diff = 0
for w in w_age_phonemes:
    n_diff += ws_age[w] != ws_phonemes[w]
    try:
        feature_age = a_age.feature(w)
        feature_phonemes = a_phonemes.feature(w)
    except KeyError:
        continue
    wf_age[w] = feature_age
    wf_phonemes[w] = feature_phonemes
# Note, since AoA lemmatizes and MNphonemes does not, there are different susceptibilities values
# for some words. In what follows, we take the value from AoA (i.e. lemmatizing)
print("{} words (out of {}) with non-matching susceptibilities".format(n_diff, len(w_age_phonemes)))
# Out:
# 158 words (out of 1642) with non-matching susceptibilities

# %%
# Build 2D data

nbins_age = 5
nbins_phonemes = 5
n_pts_threshold = 10

#range_age = feature_ranges['aoa_Kuperman']
#range_phonemes = feature_ranges['cmu_MNphonemes']
#bins_age = np.linspace(range_age[0], range_age[1], nbins_age + 1)
#bins_phonemes = np.linspace(range_phonemes[0], range_phonemes[1], nbins_phonemes + 1)
bins_age = feature_bins['aoa_Kuperman']
bins_phonemes = feature_bins['cmu_MNphonemes']
suscepts2d = np.zeros((nbins_age, nbins_phonemes))
freqs2d = np.zeros_like(suscepts2d)
n2d = np.zeros_like(suscepts2d)

for i in range(nbins_age):

    bin_age = bins_age[i:i+2]
    w_bin_age = set([w for w, f in wf_age.iteritems() if bin_age[0] <= f < bin_age[1]])
    if i == nbins_age:
        # On last bin, include right limit
        w_bin_age.update([w for w, f in wf_age.iteritems() if f == bin_age[1]])

    for j in range(nbins_phonemes):

        bin_phonemes = bins_phonemes[j:j+2]
        w_bin_phonemes = set([w for w, f in wf_phonemes.iteritems()
                              if bin_phonemes[0] <= f < bin_phonemes[1]])
        if j == nbins_phonemes:
            # On last bin, include right limit
            w_bin_phonemes.update([w for w, f in wf_phonemes.iteritems()
                                   if f == bin_phonemes[1]])
        
        w_bin_age_phonemes = w_bin_age.intersection(w_bin_phonemes)
        s_bin_age_phonemes = [ws_age[w] for w in w_bin_age_phonemes]
        freq_bin_age_phonemes = [a_freq.feature(w) for w in w_bin_age_phonemes]
        n2d[i, j] = len(s_bin_age_phonemes)
        freqs2d[i, j] = np.mean(freq_bin_age_phonemes)
        suscepts2d[i, j] = np.mean(s_bin_age_phonemes) \
            if len(s_bin_age_phonemes) >= n_pts_threshold else np.nan

print n2d
print suscepts2d
print freqs2d
# Out:
# [[ 156.  118.    8.    0.    0.]
#  [  96.  256.  111.   20.    1.]
#  [  20.  158.  151.   59.    4.]
#  [   4.   24.   48.   22.    3.]
#  [   0.    1.    0.    1.    0.]]
# [[ 0.12106363  0.18027119         nan         nan         nan]
#  [ 0.11025387  0.18321369  0.15853081  0.33775336         nan]
#  [ 0.35        0.19813894  0.174071    0.13071759         nan]
#  [        nan  0.23726852  0.21469322  0.04545455         nan]
#  [        nan         nan         nan         nan         nan]]
# [[ 9.87377621  9.07476123  6.8770686          nan         nan]
#  [ 9.07064051  8.60451837  8.51948968  7.82192575  9.74120389]
#  [ 7.91980841  7.75272791  7.55893543  7.61537023  7.36292257]
#  [ 6.3702736   7.02499425  6.93591475  6.66793463  5.34555079]
#  [        nan  7.18538702         nan  7.59538728         nan]]
# /home/sl/.virtualenvs/brainscopypaste/local/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
crop = -1

pts02 = sg.axes[2].get_position().get_points()
pts10 = sg.axes[3].get_position().get_points()
left, bottom = pts02[0, 0], pts10[0, 1]
width, height = pts02[1, 0] - pts02[0, 0], pts02[1, 1] - pts02[0, 1]
scale = 0.85
left += width * (1 - scale)
width = width * scale
ax = sg.fig.add_axes([left, bottom, width, height])

sb.heatmap(suscepts2d[:crop,:crop][::-1],
           yticklabels=[bins_age[i:i+2] for i in range(nbins_age + crop)[::-1]],
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes + crop)],
           mask=np.isnan(suscepts2d[:crop,:crop][::-1]),
           annot=True, fmt=".2", ax=ax)

ax.set_title('Substitution susceptibility')

ax.set_xlabel(translate('cmu_MNphonemes'))
ax.set_xticks(range(nbins_phonemes + crop + 1))
ax.set_xticklabels(map(lambda x: "${}$".format(int(x)), bins_phonemes[:crop]))

ax.set_ylabel(translate('aoa_Kuperman'))
ax.set_yticks(range(nbins_age + crop + 1))
ax.set_yticklabels(map(lambda x: "${:.1f}$".format(x), bins_age[:crop]), rotation='horizontal')

# Add number of items per cell
from copy import copy
texts = copy(ax.texts)
for t, n in zip(texts, n2d[:crop,:crop].flat):
    x, y = t.get_position()
    if t.get_text() == '--':
        ax.text(x, y, r'\small{{($\leq$ {} w)}}'.format(n_pts_threshold),
                color='.15', ha='center', va='center')
    else:
        t.set_text(t.get_text() + '\n\\small{{({} w)}}'.format(int(n)))

# Save figure
sg.fig.savefig('data/figures_paper/feature_susceptibilities.png', bbox_inches='tight', dpi=300)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(n2d[::-1],
           yticklabels=[bins_age[i:i+2] for i in range(nbins_age)[::-1]],
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes)],
           annot=True, ax=axs[0])
axs[0].set_title('Number of words in each bin')
axs[0].set_ylabel('age')
axs[0].set_xlabel('phonemes')
sb.heatmap(freqs2d[::-1],
           yticklabels=[''] * nbins_phonemes,
           xticklabels=[bins_phonemes[j:j+2] for j in range(nbins_phonemes)],
           mask=np.isnan(freqs2d[::-1]), annot=True, fmt=".2", ax=axs[1])
axs[1].set_title(r'$\left< \right. \log$ frequency $\left. \right>$')
axs[1].set_ylabel('age')
axs[1].set_xlabel('phonemes')

# %% [markdown]
# ### Words involved in substitutions

# %%
from IPython.utils import coloransi
tc = coloransi.TermColors()

def red(s):
    return tc.Red + s + tc.Normal

def blue(s):
    return tc.Blue + s + tc.Normal

def green(s):
    return tc.Green + s + tc.Normal

def black(s):
    return tc.Black + s + tc.Normal

def print_subs(subs, indent):
    for s in subs:
        tokens = tagger.Tokenize(s.mother)
        text = ' '.join(tokens[:s.idx]) + ' '
        text += red('{{{} => {}}}'.format(s.word1, s.word2))
        text += ' ' + ' '.join(tokens[s.idx+1:])
        freq = "{:.2f}".format(wf_freq_full[s.lem2]) if s.lem2 in wf_freq_full else '-'
        cc = "{:.2f}".format(wf_cc_full[s.lem2]) if s.lem2 in wf_cc_full else '-'
        text += blue(" [age {}, phonemes {}, freq {}, cc {}, susceptibility {}]".format(
            wf_age_full.get(s.lem2, '-'), wf_phonemes_full.get(s.lem2, '-'), 
            freq, cc, ws_age.get(s.lem2, '-')))
        print indent * ' ' + text

# %%
#detail_bin_indices = [[2, 0], [1, 3]]
detail_bin_indices = [(i, j) for i in range(4) for j in range(4)]
detail_bins = [[bins_age[i:i+2], bins_phonemes[j:j+2]] for i, j in detail_bin_indices]

for bin_age, bin_phonemes in detail_bins:
    w_bin_age = set([w for w, f in wf_age.iteritems() if bin_age[0] <= f < bin_age[1]])
    w_bin_phonemes = set([w for w, f in wf_phonemes.iteritems()
                          if bin_phonemes[0] <= f < bin_phonemes[1]])
    w_bin_age_phonemes = w_bin_age.intersection(w_bin_phonemes)
    
    # TITLE
    title = "Ages {} --- #phonemes {}".format(bin_age, bin_phonemes)
    print("=" * len(title))
    print(title)
    print
    
    # FOR EACH WORD
    indent = 2
    for w in w_bin_age_phonemes:
        freq = "{:.2f}".format(wf_freq_full[w]) if w in wf_freq_full else '-'
        cc = "{:.2f}".format(wf_cc_full[w]) if w in wf_cc_full else '-'
        print (indent - 1) * '-' + " " + red(w) + \
            " (age {}, phonemes {}, freq {}, cc {}, susceptibility {})".format(
                wf_age[w], wf_phonemes[w], freq, cc, ws_age[w]),
        
        # Find back the substitutions
        subs = [s for s in a_age.data if s.lem1 == w or s.word1 == w]
        if len(subs) == 0:
            print '[nosubs]'
            print
            continue

        print
        print
        print_subs(subs, indent + 2)
        print
        
    print
# Out:
# ============================================
# Ages [ 2.22   5.442] --- #phonemes [ 1.  4.]
#
# - birth (age 5.21, phonemes 3.0, freq 8.56, cc -2.40, susceptibility 1.0)
#
#     spend some time with the {birth => certificate}  [age 8.42, phonemes 9.0, freq 7.42, cc 0.00, susceptibility -]
#
# - shape (age 4.47, phonemes 3.0, freq 8.90, cc -2.17, susceptibility 0.0) [nosubs]
#
# - knock (age 4.63, phonemes 3.0, freq 8.23, cc -2.39, susceptibility 0.0) [nosubs]
#
# - go (age 3.37, phonemes 2.0, freq 12.83, cc -2.92, susceptibility 0.0487804878049)
#
#     not {going => willing} to give me anything except appreciation [age 8.58, phonemes 5.0, freq 9.44, cc -2.71, susceptibility 0.142857142857]
#     were not {going => able} to meet [age 7.79, phonemes 4.0, freq 10.50, cc -2.30, susceptibility -]
#
# - hell (age 5.11, phonemes 3.0, freq 9.67, cc -2.87, susceptibility 0.428571428571)
#
#     who the {hell => fuck} is sarah palin [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     who the {hell => fuck} is sarah palin [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     who the {hell => fuck} is sarah palin [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#
# - hole (age 5.05, phonemes 3.0, freq 8.28, cc -3.29, susceptibility 0.0) [nosubs]
#
# - web (age 5.37, phonemes 3.0, freq 8.88, cc -, susceptibility 1.0)
#
#      {web => sport} times e to the t over tau [age 5.74, phonemes 5.0, freq 8.26, cc -2.36, susceptibility -]
#      {web => sport} times e to the t over tau [age 5.74, phonemes 5.0, freq 8.26, cc -2.36, susceptibility -]
#
# - cut (age 4.43, phonemes 3.0, freq 9.90, cc -2.81, susceptibility 1.0)
#
#     barack obama is going to {cut => raise} your taxes [age 6.72, phonemes 3.0, freq 9.89, cc -1.76, susceptibility 0.0]
#     barack obama is going to {cut => raise} your taxes [age 6.72, phonemes 3.0, freq 9.89, cc -1.76, susceptibility 0.0]
#     barack obama is going to {cut => raise} your taxes [age 6.72, phonemes 3.0, freq 9.89, cc -1.76, susceptibility 0.0]
#
# - cup (age 3.57, phonemes 3.0, freq 7.82, cc -2.03, susceptibility 0.0) [nosubs]
#
# - hope (age 4.89, phonemes 3.0, freq 10.81, cc -2.38, susceptibility 0.285714285714)
#
#     there is no {hope => partner} for peace [age 5.85, phonemes 6.0, freq 9.14, cc -1.49, susceptibility -]
#     there is no {hope => partner} for peace [age 5.85, phonemes 6.0, freq 9.14, cc -1.49, susceptibility -]
#
# - young (age 4.61, phonemes 3.0, freq 9.95, cc -2.26, susceptibility 0.0) [nosubs]
#
# - late (age 5.28, phonemes 3.0, freq 9.33, cc -2.40, susceptibility 0.0) [nosubs]
#
# - bush (age 4.9, phonemes 3.0, freq 10.16, cc -2.53, susceptibility 0.0) [nosubs]
#
# - easy (age 5.43, phonemes 3.0, freq 9.74, cc -2.95, susceptibility 1.0)
#
#     but you said it ' s an {repair => job} repair [age 5.39, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0]
#     but you said it ' s an {repair => job} repair [age 5.39, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0]
#     but you said it ' s an {repair => job} repair [age 5.39, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0]
#     but you said it ' s an {repair => job} repair [age 5.39, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0]
#
# - save (age 5.44, phonemes 3.0, freq 9.85, cc -2.84, susceptibility 0.0) [nosubs]
#
# - kick (age 4.06, phonemes 3.0, freq 8.40, cc -2.45, susceptibility 0.0) [nosubs]
#
# - real (age 4.95, phonemes 3.0, freq 10.47, cc -2.31, susceptibility 0.0909090909091)
#
#      {real => pro-america} parts of the country [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - do (age 3.6, phonemes 2.0, freq 13.64, cc -2.89, susceptibility 0.0) [nosubs]
#
# - good (age 3.55, phonemes 3.0, freq 12.25, cc -3.81, susceptibility 0.0526315789474)
#
#     this is something that matters a lot to the palestinians it matters a lot to the palestinian people and it is obviously a sign of {good => goodwill}  [age 8.79, phonemes 6.0, freq 6.46, cc -, susceptibility -]
#
# - hit (age 4.75, phonemes 3.0, freq 9.72, cc -3.02, susceptibility 0.0) [nosubs]
#
# - get (age 3.17, phonemes 3.0, freq 12.59, cc -2.20, susceptibility 0.131147540984)
#
#     the republicans ca n't seem to {get => catch} a break when it comes to august and when it comes to the weather [age 4.61, phonemes 3.0, freq 8.78, cc -2.44, susceptibility 0.5]
#     the republicans ca n't seem to {get => catch} a break when it comes to august and when it comes to the weather [age 4.61, phonemes 3.0, freq 8.78, cc -2.44, susceptibility 0.5]
#     we ask you to help us work for that day when black will not be asked to {get => give} back when brown can stick around when yellow will be mellow when the red man can get ahead man and when white will embrace what is right [age 4.28, phonemes 3.0, freq 11.47, cc -2.73, susceptibility 0.0]
#     we ask you to help us work for that day when black will not be asked to {get => give} back when brown can stick around when yellow will be mellow when the red man can get ahead man and when white will embrace what is right [age 4.28, phonemes 3.0, freq 11.47, cc -2.73, susceptibility 0.0]
#      {get => induce} people to love their servitude [age 12.05, phonemes 5.0, freq 6.91, cc -, susceptibility -]
#     has not reached across party lines to {get => accomplish} anything significant [age 7.84, phonemes 8.0, freq 8.16, cc -1.02, susceptibility -]
#      {gotten => pretty} seriously off on the wrong track [age -, phonemes 5.0, freq 9.98, cc -2.65, susceptibility 1.0]
#     many factors that affect brain health are thought to be out of our control but this study suggests that simply adjusting our diets to {get => consume} more vitamin b12 through eating meat fish fortified cereals or milk may be something we can easily adjust to prevent brain shrinkage and so perhaps save our memory [age 11.47, phonemes 6.0, freq 7.79, cc -1.10, susceptibility 1.0]
#
# - food (age 3.25, phonemes 3.0, freq 9.23, cc -3.70, susceptibility 0.666666666667)
#
#     we should go back to a policy of maximum {food => agricultural} self-sufficiency [age 10.11, phonemes 11.0, freq 4.08, cc -, susceptibility -]
#     we should go back to a policy of maximum {food => agricultural} self-sufficiency [age 10.11, phonemes 11.0, freq 4.08, cc -, susceptibility -]
#
# - big (age 2.89, phonemes 3.0, freq 11.01, cc -3.67, susceptibility 0.25)
#
#     it does n't matter how {big => in-your-face} you are [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - watch (age 4.33, phonemes 3.0, freq 9.88, cc -3.13, susceptibility 0.25)
#
#     it will be a stirring sight to {watch => see} president obama his wife michelle and their beautiful girls step through the doors of the white house [age 3.06, phonemes 2.0, freq 11.94, cc -2.46, susceptibility 0.0952380952381]
#
# - bear (age 3.58, phonemes 3.0, freq 9.85, cc -2.52, susceptibility 0.0) [nosubs]
#
# - choice (age 5.17, phonemes 3.0, freq 9.91, cc -2.28, susceptibility 0.0) [nosubs]
#
# - game (age 4.26, phonemes 3.0, freq 10.69, cc -3.11, susceptibility 0.142857142857)
#
#     i did n't give him any {game => game-planning}  [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - know (age 4.5, phonemes 2.0, freq 12.38, cc -2.75, susceptibility 0.0571428571429)
#
#     i {know => realize} how political it is [age 8.23, phonemes 5.5, freq 9.21, cc -2.50, susceptibility -]
#     i just want to {know => try} one thing [age 3.44, phonemes 3.0, freq 11.03, cc -2.48, susceptibility 0.0]
#
# - kiss (age 3.61, phonemes 3.0, freq 8.83, cc -2.29, susceptibility 0.0) [nosubs]
#
# - day (age 3.5, phonemes 2.0, freq 11.54, cc -2.58, susceptibility 0.315789473684)
#
#     because of what we did on this {day => date} in this election at this defining moment change has come to america [age 5.84, phonemes 3.0, freq 8.99, cc -2.83, susceptibility 0.666666666667]
#     because of what we did on this {day => date} in this election at this defining moment change has come to america [age 5.84, phonemes 3.0, freq 8.99, cc -2.83, susceptibility 0.666666666667]
#     because of what we did on this {day => date} in this election at this defining moment change has come to america [age 5.84, phonemes 3.0, freq 8.99, cc -2.83, susceptibility 0.666666666667]
#     because of what we did on this {day => date} in this election at this defining moment change has come to america [age 5.84, phonemes 3.0, freq 8.99, cc -2.83, susceptibility 0.666666666667]
#      {day => everyday} american people joe six-pack hockey moms across the nation [age 5.05, phonemes 6.0, freq 7.86, cc -2.09, susceptibility -]
#      {day => everyday} american people joe six-pack hockey moms across the nation [age 5.05, phonemes 6.0, freq 7.86, cc -2.09, susceptibility -]
#
# - cool (age 4.58, phonemes 3.0, freq 8.67, cc -2.97, susceptibility 1.0)
#
#     a {cool => steady} hand at the tiller [age 6.7, phonemes 5.0, freq 7.50, cc -0.92, susceptibility 1.0]
#      {cool => steady} hand at the tiller [age 6.7, phonemes 5.0, freq 7.50, cc -0.92, susceptibility 1.0]
#
# - loss (age 5.0, phonemes 3.0, freq 9.50, cc -2.45, susceptibility 0.0) [nosubs]
#
# - meat (age 4.42, phonemes 3.0, freq 7.35, cc -2.70, susceptibility 0.0) [nosubs]
#
# - shy (age 5.32, phonemes 2.0, freq 5.81, cc -2.48, susceptibility 0.0) [nosubs]
#
# - cry (age 2.78, phonemes 3.0, freq 8.64, cc -2.37, susceptibility 0.0) [nosubs]
#
# - try (age 3.44, phonemes 3.0, freq 11.03, cc -2.48, susceptibility 0.0)
#
#     well i just want to ask you now about the issue that was raised because it ' s been a little confusing to me as {try => tried} try to sort it out here to get straight here you ' re not taking home 250 000 now am i right [age 3.44, phonemes 3.0, freq 11.03, cc -2.48, susceptibility 0.0]
#     well i just want to ask you now about the issue that was raised because it ' s been a little confusing to me as {try => tried} try to sort it out here to get straight here you ' re not taking home 250 000 now am i right [age 3.44, phonemes 3.0, freq 11.03, cc -2.48, susceptibility 0.0]
#
# - bad (age 2.79, phonemes 3.0, freq 11.05, cc -3.58, susceptibility 0.222222222222)
#
#     those who speak of change must apologise to the iranian people and try to repair their past {bad => crimes}  [age 7.67, phonemes 4.0, freq 9.31, cc -2.37, susceptibility 0.125]
#     those who speak of change must apologise to the iranian people and try to repair their past {bad => crimes}  [age 7.67, phonemes 4.0, freq 9.31, cc -2.37, susceptibility 0.125]
#
# - nose (age 2.95, phonemes 3.0, freq 6.89, cc -3.07, susceptibility 0.0) [nosubs]
#
# - rock (age 3.22, phonemes 3.0, freq 8.76, cc -3.12, susceptibility 0.0) [nosubs]
#
# - claw (age 4.7, phonemes 3.0, freq 5.86, cc -1.65, susceptibility 1.0)
#
#      {claw => spend} its way out of recession [age 6.44, phonemes 5.0, freq 10.11, cc -1.29, susceptibility 0.25]
#
# - guy (age 4.11, phonemes 2.0, freq 10.64, cc -2.00, susceptibility 0.0) [nosubs]
#
# - page (age 5.16, phonemes 3.0, freq 8.64, cc -2.05, susceptibility 0.0) [nosubs]
#
# - mean (age 4.0, phonemes 3.0, freq 10.76, cc -3.18, susceptibility 0.5)
#
#     will be forced to react and not only through diplomatic {means => demarches}  [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     react and not only through diplomatic {means => protests}  [age 9.11, phonemes 7.0, freq 7.47, cc -, susceptibility -]
#     sanctions are being considered and many other {means => measures}  [age 7.53, phonemes 4.0, freq 9.65, cc -2.56, susceptibility 0.0]
#     i {mean => guess} maybe what they ' re saying is watch out george bush [age 5.44, phonemes 3.0, freq 9.22, cc -2.34, susceptibility -]
#
# - old (age 3.72, phonemes 3.0, freq 10.26, cc -3.61, susceptibility 0.0) [nosubs]
#
# - house (age 3.16, phonemes 3.0, freq 10.57, cc -3.57, susceptibility 0.285714285714)
#
#     from my {house => ass} i can see belgium [age 7.84, phonemes 2.0, freq 6.60, cc -2.36, susceptibility -]
#     from my {house => ass} i can see belgium [age 7.84, phonemes 2.0, freq 6.60, cc -2.36, susceptibility -]
#
# - fish (age 4.05, phonemes 3.0, freq 8.35, cc -2.89, susceptibility 0.0) [nosubs]
#
# - mom (age 2.22, phonemes 3.0, freq 8.82, cc -2.46, susceptibility 0.333333333333)
#
#      {mom => mama} it ' s real hard to sing when you ' re in the second row crying [age 1.89, phonemes 4.0, freq 6.53, cc -, susceptibility -]
#
# - sign (age 4.32, phonemes 3.0, freq 9.68, cc -3.01, susceptibility 0.0) [nosubs]
#
# - see (age 3.06, phonemes 2.0, freq 11.94, cc -2.46, susceptibility 0.0952380952381)
#
#      {see => yeah} the failed policies of john mccain would be the pig [age -, phonemes 2.0, freq 8.56, cc -, susceptibility 0.0]
#     i do not {see => foresee} any improvement in these issues for at least a year [age 10.95, phonemes 5.0, freq 6.32, cc -, susceptibility 1.0]
#
# - sure (age 4.85, phonemes 3.0, freq 10.54, cc -2.17, susceptibility 0.0) [nosubs]
#
# - sight (age 5.44, phonemes 3.0, freq 8.54, cc -1.45, susceptibility 0.0) [nosubs]
#
# - year (age 5.24, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0) [nosubs]
#
# - girl (age 4.0, phonemes 3.0, freq 9.92, cc -3.20, susceptibility 0.0) [nosubs]
#
# - arm (age 3.26, phonemes 3.0, freq 9.13, cc -2.49, susceptibility 0.4)
#
#      {arm => manage} cpu architecture team for iphone [age 7.67, phonemes 5.0, freq 8.93, cc -, susceptibility -]
#      {arm => manage} cpu architecture team for iphone [age 7.67, phonemes 5.0, freq 8.93, cc -, susceptibility -]
#
# - sun (age 3.4, phonemes 3.0, freq 8.68, cc -2.79, susceptibility 0.0) [nosubs]
#
# - new (age 4.72, phonemes 2.5, freq 11.58, cc -3.11, susceptibility 0.272727272727)
#
#     there ' s a {sheriff => kid} sheriff in town [age 4.28, phonemes 3.0, freq 9.99, cc -2.18, susceptibility 0.0]
#     you look just awesome in this {new => movie}  [age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     you look just awesome in this {new => movie}  [age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     it ' s about a {attitude => politics} attitude [age 9.37, phonemes 8.0, freq 9.93, cc -1.96, susceptibility 0.0]
#
# - red (age 3.68, phonemes 3.0, freq 8.83, cc -3.73, susceptibility 0.0) [nosubs]
#
# - side (age 4.72, phonemes 3.0, freq 10.17, cc -3.18, susceptibility 0.0) [nosubs]
#
# - be (age 5.11, phonemes 2.0, freq 15.24, cc -2.89, susceptibility 0.0) [nosubs]
#
# - noise (age 4.5, phonemes 3.0, freq 7.10, cc -2.79, susceptibility 0.0) [nosubs]
#
# - run (age 4.47, phonemes 3.0, freq 10.71, cc -3.25, susceptibility 0.0) [nosubs]
#
# - night (age 3.61, phonemes 3.0, freq 10.17, cc -2.90, susceptibility 0.0) [nosubs]
#
# - job (age 5.39, phonemes 3.0, freq 10.98, cc -2.88, susceptibility 0.0) [nosubs]
#
# - let (age 4.53, phonemes 3.0, freq 11.10, cc -2.08, susceptibility 0.0) [nosubs]
#
# - put (age 3.72, phonemes 3.0, freq 11.17, cc -2.57, susceptibility 0.0714285714286)
#
#     i had morne morkel dressing me and putting my shoes on and {putting => pads}  [age 8.83, phonemes 3.0, freq 6.48, cc -2.40, susceptibility -]
#
# - sing (age 3.47, phonemes 3.0, freq 8.35, cc -1.97, susceptibility 0.0) [nosubs]
#
# - teach (age 4.67, phonemes 3.0, freq 8.90, cc -1.87, susceptibility 0.0) [nosubs]
#
# - come (age 3.32, phonemes 3.0, freq 11.95, cc -1.75, susceptibility 0.0) [nosubs]
#
# - throw (age 4.14, phonemes 3.0, freq 9.38, cc -2.87, susceptibility 0.0) [nosubs]
#
# - wait (age 4.3, phonemes 3.0, freq 10.10, cc -2.14, susceptibility 0.111111111111)
#
#     we are not going to {wait => appeal}  [age 10.21, phonemes 4.0, freq 8.28, cc -1.77, susceptibility -]
#
# - boy (age 3.67, phonemes 2.0, freq 9.43, cc -2.87, susceptibility 0.2)
#
#     i give a lot of credit to the {boys => public}  [age 8.47, phonemes 6.0, freq 10.45, cc -3.40, susceptibility 0.0454545454545]
#
# - would (age 5.28, phonemes 3.0, freq 12.18, cc -, susceptibility 0.0) [nosubs]
#
# - keep (age 4.42, phonemes 3.0, freq 10.80, cc -2.44, susceptibility 0.0) [nosubs]
#
# - thing (age 4.58, phonemes 3.0, freq 11.83, cc -3.09, susceptibility 0.0625)
#
#     it ' s a {thing => place} thing for me [age 4.95, phonemes 4.0, freq 10.74, cc -3.23, susceptibility 0.0]
#     try to make this {thing => work}  [age 5.86, phonemes 3.0, freq 11.80, cc -3.54, susceptibility 0.1]
#     the shape of {things => faith} to come [age 7.62, phonemes 3.0, freq 9.47, cc -1.33, susceptibility -]
#
# - ox (age 4.72, phonemes 3.0, freq 5.31, cc -1.79, susceptibility 0.0) [nosubs]
#
# - top (age 3.89, phonemes 3.0, freq 9.54, cc -3.15, susceptibility 0.2)
#
#     google does n't exactly bubble to the top of the list of the {top => toughest} competitors we ' ve got going in mobile [age 5.47, phonemes 3.0, freq 9.89, cc -2.14, susceptibility 0.0]
#
# - king (age 5.42, phonemes 3.0, freq 9.47, cc -2.51, susceptibility 0.0) [nosubs]
#
# - feed (age 4.17, phonemes 3.0, freq 8.55, cc -1.46, susceptibility 0.25)
#
#     the preliminary opinion experts have given us is that there is a problem with the {feed => fertilizer}  [age 7.67, phonemes 8.0, freq 3.50, cc -, susceptibility -]
#
# - love (age 5.17, phonemes 3.0, freq 11.40, cc -3.29, susceptibility 0.1)
#
#     i {love => salute} each and every one of you [age 7.42, phonemes 5.0, freq 7.24, cc -1.73, susceptibility 1.0]
#
# - feel (age 5.11, phonemes 3.0, freq 11.15, cc -2.19, susceptibility 0.5)
#
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     we {feel => believe} it is inappropriate to use young private citizens for marketing purposes [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#
# - win (age 4.22, phonemes 3.0, freq 10.59, cc -2.48, susceptibility 0.0) [nosubs]
#
# - walk (age 3.45, phonemes 3.0, freq 9.53, cc -3.10, susceptibility 0.0) [nosubs]
#
# - ask (age 2.89, phonemes 3.0, freq 10.80, cc -2.21, susceptibility 0.0) [nosubs]
#
# - church (age 5.15, phonemes 3.0, freq 9.20, cc -2.56, susceptibility 0.0) [nosubs]
#
# - boat (age 3.84, phonemes 3.0, freq 7.82, cc -2.71, susceptibility 0.0) [nosubs]
#
# - size (age 4.84, phonemes 3.0, freq 8.47, cc -2.17, susceptibility 0.0) [nosubs]
#
# - use (age 4.5, phonemes 3.0, freq 11.22, cc -3.61, susceptibility 0.0333333333333)
#
#     instead of caring about the people of gaza hamas decided to use gaza to {use => launch} rockets to kill innocent israelis [age 7.92, phonemes 4.0, freq 8.93, cc -2.20, susceptibility -]
#
# - eye (age 3.75, phonemes 1.0, freq 9.90, cc -3.16, susceptibility 0.5)
#
#     you can see it in their {eyes => faces}  [age 3.75, phonemes 3.0, freq 10.61, cc -3.05, susceptibility 0.0]
#
# - jet (age 5.39, phonemes 3.0, freq 7.74, cc -2.08, susceptibility 0.0) [nosubs]
#
# - bite (age 3.58, phonemes 3.0, freq 7.71, cc -2.59, susceptibility 0.0) [nosubs]
#
# - name (age 3.68, phonemes 3.0, freq 10.20, cc -3.24, susceptibility 0.0) [nosubs]
#
# - call (age 4.74, phonemes 3.0, freq 10.92, cc -3.21, susceptibility 0.166666666667)
#
#     many are {called => invited} but few are chosen [age 6.79, phonemes 5.0, freq 8.15, cc -, susceptibility -]
#
# - low (age 4.7, phonemes 2.0, freq 9.43, cc -3.07, susceptibility 0.0) [nosubs]
#
# - way (age 5.39, phonemes 2.0, freq 11.75, cc -2.93, susceptibility 0.285714285714)
#
#      {way => journey} through the depths of hell [age 7.67, phonemes 4.0, freq 8.56, cc -1.57, susceptibility 0.0]
#     around the world in 80 {ways => dishes}  [age 4.89, phonemes 3.0, freq 5.72, cc -1.79, susceptibility -]
#
# - white (age 4.06, phonemes 3.5, freq 10.00, cc -3.87, susceptibility 0.0) [nosubs]
#
# - man (age 3.11, phonemes 3.0, freq 11.38, cc -4.02, susceptibility 0.0454545454545)
#
#     a day off for the working {man => citizens}  [age 7.74, phonemes 7.0, freq 9.70, cc -2.97, susceptibility 0.166666666667]
#
# - tell (age 4.26, phonemes 3.0, freq 11.15, cc -2.40, susceptibility 0.0) [nosubs]
#
# - head (age 3.42, phonemes 3.0, freq 9.92, cc -3.51, susceptibility 0.0)
#
#     i ' ll meet this financial {head => head-on} head [age -, phonemes -, freq 5.66, cc -, susceptibility 0.0]
#
# - shell (age 5.22, phonemes 3.0, freq 7.34, cc -2.53, susceptibility 0.0) [nosubs]
#
# - fire (age 3.25, phonemes 3.0, freq 9.95, cc -3.29, susceptibility 0.0) [nosubs]
#
# - gas (age 5.32, phonemes 3.0, freq 9.33, cc -2.98, susceptibility 1.0)
#
#     i think god ' s will has to be done in unifying people and companies to get that {pipeline => line} pipeline built [age 4.85, phonemes 3.0, freq 9.93, cc -3.58, susceptibility 0.0]
#     i think god ' s will has to be done in unifying people and companies to get that {pipeline => line} pipeline built so pray for that [age 4.85, phonemes 3.0, freq 9.93, cc -3.58, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {pipeline => line} pipeline built so pray for that [age 4.85, phonemes 3.0, freq 9.93, cc -3.58, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#
# - hurt (age 4.0, phonemes 3.0, freq 9.34, cc -3.10, susceptibility 0.0) [nosubs]
#
# - phone (age 4.11, phonemes 3.0, freq 9.30, cc -3.18, susceptibility 0.5)
#
#     she ' s on the phone with the world food program he ' s on the {saakashvili => sakaashvili} with saakashvili [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - heat (age 5.33, phonemes 3.0, freq 8.18, cc -2.45, susceptibility 0.0) [nosubs]
#
# - hear (age 3.8, phonemes 3.0, freq 10.47, cc -1.39, susceptibility 0.0) [nosubs]
#
# - line (age 4.85, phonemes 3.0, freq 9.93, cc -3.58, susceptibility 0.0)
#
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#     god ' s will has to be done in unifying people and companies to get that {line => pipeline} line built [age 10.06, phonemes 6.0, freq 6.85, cc -, susceptibility 0.0]
#
# - pig (age 3.84, phonemes 3.0, freq 9.10, cc -2.49, susceptibility 0.0) [nosubs]
#
# - town (age 5.11, phonemes 3.0, freq 9.25, cc -1.68, susceptibility 0.0) [nosubs]
#
# - pull (age 4.79, phonemes 3.0, freq 9.19, cc -3.21, susceptibility 0.4)
#
#     if we {pull => pool} our votes together we will win this election [age 5.15, phonemes 3.0, freq 6.49, cc -2.65, susceptibility -]
#     if we {pull => pool} our votes together we will win this election [age 5.15, phonemes 3.0, freq 6.49, cc -2.65, susceptibility -]
#
# - word (age 4.42, phonemes 3.0, freq 10.35, cc -2.92, susceptibility 0.0) [nosubs]
#
# - room (age 4.22, phonemes 3.0, freq 9.45, cc -2.92, susceptibility 0.0)
# [nosubs]
#
# - wish (age 3.79, phonemes 3.0, freq 9.69, cc -2.80, susceptibility 0.0) [nosubs]
#
# - air (age 3.94, phonemes 2.0, freq 9.08, cc -2.85, susceptibility 0.333333333333)
#
#     he was martyred and left me with six children to feed on my own and obama wo n't repair our house that was damaged in the {air => raids}  [age 9.53, phonemes 3.0, freq 6.95, cc -, susceptibility -]
#
# - can (age 4.32, phonemes 3.0, freq 12.45, cc -2.57, susceptibility 0.0) [nosubs]
#
# - fun (age 3.67, phonemes 3.0, freq 9.48, cc -3.35, susceptibility 0.0) [nosubs]
#
# - meet (age 4.74, phonemes 3.0, freq 10.30, cc -2.61, susceptibility 0.1)
#
#     at the highest levels of the {met => pentagon}  [age -, phonemes 7.5, freq 7.54, cc -, susceptibility -]
#
# - piece (age 4.89, phonemes 3.0, freq 9.13, cc -2.44, susceptibility 0.0) [nosubs]
#
# - give (age 4.28, phonemes 3.0, freq 11.47, cc -2.73, susceptibility 0.0) [nosubs]
#
# - share (age 4.84, phonemes 3.0, freq 9.68, cc -2.20, susceptibility 0.0) [nosubs]
#
# - sad (age 3.24, phonemes 3.0, freq 8.88, cc -2.76, susceptibility 0.0) [nosubs]
#
# - high (age 4.58, phonemes 2.0, freq 10.45, cc -3.63, susceptibility 0.0) [nosubs]
#
# - say (age 3.42, phonemes 2.0, freq 12.08, cc -2.02, susceptibility 0.333333333333)
#
#      {said => ahhh} i think i support the president ' s policy [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#      {said => ahhh} i think i support the president ' s policy [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#      {said => ahhh} i think i support the president ' s policy [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     this {says => means} a lot for our country [age 4.0, phonemes 3.0, freq 10.76, cc -3.18, susceptibility 0.5]
#      {said => please} do n't let them get me [age -, phonemes 4.0, freq 9.73, cc -2.25, susceptibility -]
#      {said => please} do n't let them get me [age -, phonemes 4.0, freq 9.73, cc -2.25, susceptibility -]
#
# - have (age 3.72, phonemes 3.0, freq 13.97, cc -1.95, susceptibility 0.0) [nosubs]
#
# - need (age 3.56, phonemes 3.0, freq 11.75, cc -2.49, susceptibility 0.161290322581)
#
#     we {need => want} to spread the wealth [age 4.16, phonemes 4.0, freq 12.09, cc -2.17, susceptibility 0.142857142857]
#     we {need => want} to spread the wealth [age 4.16, phonemes 4.0, freq 12.09, cc -2.17, susceptibility 0.142857142857]
#     we have taken some major action to date and we will {need => take} further action [age 4.37, phonemes 3.0, freq 12.05, cc -2.82, susceptibility 0.0344827586207]
#     we have taken some major action to date and we will {need => take} further action [age 4.37, phonemes 3.0, freq 12.05, cc -2.82, susceptibility 0.0344827586207]
#     he ' s going to {you-not => help} you-not [age 3.65, phonemes 4.0, freq 11.17, cc -3.50, susceptibility 0.214285714286]
#
# - ship (age 5.33, phonemes 3.0, freq 8.69, cc -2.47, susceptibility 0.0) [nosubs]
#
# - car (age 3.37, phonemes 3.0, freq 9.49, cc -4.01, susceptibility 0.0) [nosubs]
#
# - huge (age 4.9, phonemes 3.5, freq 9.26, cc -1.73, susceptibility 1.0)
#
#     it ' s a {honour => turn-on} honour for me [age -, phonemes -, freq 2.48, cc -, susceptibility -]
#
# - end (age 4.28, phonemes 3.0, freq 11.04, cc -3.26, susceptibility 0.0) [nosubs]
#
# - turn (age 4.11, phonemes 3.0, freq 10.26, cc -2.82, susceptibility 0.0) [nosubs]
#
# - make (age 4.68, phonemes 3.0, freq 12.29, cc -2.98, susceptibility 0.0) [nosubs]
#
# - snow (age 4.11, phonemes 3.0, freq 7.83, cc -2.56, susceptibility 0.0) [nosubs]
#
# - write (age 4.89, phonemes 3.0, freq 9.57, cc -2.31, susceptibility 0.0) [nosubs]
#
# - other (age 5.33, phonemes 3.0, freq 11.59, cc -2.13, susceptibility 0.0769230769231)
#
#     not the {other => exciting} thing it used to be [age 6.61, phonemes 5.0, freq 9.17, cc -, susceptibility -]
#
# - take (age 4.37, phonemes 3.0, freq 12.05, cc -2.82, susceptibility 0.0344827586207)
#
#      {take => use} all necessary measures that are appropriate in somalia [age 4.5, phonemes 3.0, freq 11.22, cc -3.61, susceptibility 0.0333333333333]
#
# - sick (age 4.05, phonemes 3.0, freq 8.19, cc -2.73, susceptibility 0.0) [nosubs]
#
# - beach (age 4.8, phonemes 3.0, freq 7.65, cc -2.45, susceptibility 0.0) [nosubs]
#
# - roll (age 4.47, phonemes 3.0, freq 8.60, cc -3.07, susceptibility 0.5)
#
#     would make lincoln {roll => turn} over in his grave [age 4.11, phonemes 3.0, freq 10.26, cc -2.82, susceptibility 0.0]
#
# - week (age 5.11, phonemes 3.0, freq 10.50, cc -1.29, susceptibility 0.0) [nosubs]
#
# - play (age 4.1, phonemes 3.0, freq 10.92, cc -2.98, susceptibility 0.0) [nosubs]
#
# - ball (age 2.9, phonemes 3.0, freq 8.78, cc -3.11, susceptibility 0.0) [nosubs]
#
# - pain (age 4.26, phonemes 3.0, freq 8.91, cc -3.56, susceptibility 0.0) [nosubs]
#
# - mess (age 4.28, phonemes 3.0, freq 8.72, cc -2.64, susceptibility 0.0) [nosubs]
#
# - stay (age 4.22, phonemes 3.0, freq 9.79, cc -2.21, susceptibility 0.0) [nosubs]
#
# - wrong (age 4.22, phonemes 3.0, freq 10.28, cc -2.84, susceptibility 0.0) [nosubs]
#
# - mouth (age 3.58, phonemes 3.0, freq 8.00, cc -2.77, susceptibility 0.0) [nosubs]
#
# - fat (age 5.15, phonemes 3.0, freq 7.91, cc -2.89, susceptibility 0.0) [nosubs]
#
# - wave (age 4.26, phonemes 3.0, freq 7.94, cc -2.60, susceptibility 0.0) [nosubs]
#
# - grow (age 4.79, phonemes 3.0, freq 9.92, cc -2.62, susceptibility 0.0) [nosubs]
#
# - kid (age 4.28, phonemes 3.0, freq 9.99, cc -2.18, susceptibility 0.0) [nosubs]
#
# - age (age 4.38, phonemes 2.0, freq 9.54, cc -2.98, susceptibility 0.0) [nosubs]
#
# - dog (age 2.8, phonemes 3.0, freq 9.27, cc -3.93, susceptibility 0.0) [nosubs]
#
# - face (age 3.75, phonemes 3.0, freq 10.61, cc -3.05, susceptibility 0.0) [nosubs]
#
# - look (age 4.05, phonemes 3.0, freq 11.48, cc -2.83, susceptibility 0.0) [nosubs]
#
# - allow (age 5.32, phonemes 3.0, freq 10.14, cc -2.07, susceptibility 1.0)
#
#     we will not {allow => accept} this situation [age 6.74, phonemes 6.0, freq 9.49, cc -2.20, susceptibility -]
#
# - time (age 5.16, phonemes 3.0, freq 12.33, cc -3.40, susceptibility 0.0909090909091)
#
#     i believe that 16 months is the right {time => timeframe}  [age -, phonemes 7.0, freq 5.62, cc -, susceptibility -]
#     the greatest economic challenge of our {times => lifetime}  [age 9.0, phonemes 6.0, freq 8.59, cc -, susceptibility 0.666666666667]
#
# - talk (age 3.68, phonemes 3.0, freq 10.98, cc -2.90, susceptibility 0.0) [nosubs]
#
#
# ============================================
# Ages [ 2.22   5.442] --- #phonemes [ 4.  7.]
#
# - think (age 4.75, phonemes 4.0, freq 12.37, cc -2.63, susceptibility 0.153846153846)
#
#     i do n't {think => believe} we ' re headed into a recession [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     our economy i {think => believe} still the fundamentals of our economy are strong [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     i do n't even {think => worry} about it [age 6.61, phonemes 3.0, freq 9.80, cc -2.25, susceptibility -]
#     i {think => know} that she will bring enormous energy and intellect and skill to the position [age 4.5, phonemes 2.0, freq 12.38, cc -2.75, susceptibility 0.0571428571429]
#     they {think => believe} it ' s the right thing to do [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#     i think the world should {think => watch}  [age 4.33, phonemes 3.0, freq 9.88, cc -3.13, susceptibility 0.25]
#
# - forget (age 4.78, phonemes 5.5, freq 9.11, cc -2.69, susceptibility 0.0) [nosubs]
#
# - dance (age 4.63, phonemes 4.0, freq 8.42, cc -3.15, susceptibility 0.0) [nosubs]
#
# - money (age 5.11, phonemes 4.0, freq 10.76, cc -3.81, susceptibility 0.25)
#
#      {money => requires} multiple upgrades and additional external devices putting a burden on the wallet and adds clutter to the entertainment center [age 8.67, phonemes 6.0, freq 9.64, cc -, susceptibility 0.5]
#
# - queen (age 4.42, phonemes 4.0, freq 7.22, cc -2.20, susceptibility 0.0) [nosubs]
#
# - yellow (age 3.2, phonemes 4.0, freq 6.73, cc -3.00, susceptibility 0.0) [nosubs]
#
# - bring (age 4.42, phonemes 4.0, freq 10.61, cc -1.62, susceptibility 0.0) [nosubs]
#
# - sleep (age 2.79, phonemes 4.0, freq 8.68, cc -2.89, susceptibility 0.0) [nosubs]
#
# - human (age 4.83, phonemes 5.5, freq 9.97, cc -2.07, susceptibility 0.0) [nosubs]
#
# - part (age 5.11, phonemes 4.0, freq 10.73, cc -2.73, susceptibility 0.0) [nosubs]
#
# - chicken (age 3.26, phonemes 5.0, freq 7.71, cc -2.82, susceptibility 1.0)
#
#     in congress we have a red button a green button and a yellow button alright green means yes red means no and yellow means you ' re a {shit => s} shit [age -, phonemes -, freq 10.25, cc -, susceptibility 0.0779220779221]
#
# - milk (age 3.37, phonemes 4.0, freq 7.84, cc -2.74, susceptibility 0.0) [nosubs]
#
# - ground (age 4.89, phonemes 5.0, freq 9.41, cc -2.89, susceptibility 0.5)
#
#     do n't be diverted by the {ground => crowd} noise and the static [age 7.14, phonemes 4.0, freq 8.55, cc -2.29, susceptibility 1.0]
#
# - police (age 5.05, phonemes 5.0, freq 9.33, cc -2.88, susceptibility 0.111111111111)
#
#     and seven {police => policemen} charged with security at the interior ministry have been detained for an attempted coup [age 4.44, phonemes 8.0, freq 6.73, cc -2.24, susceptibility -]
#
# - mother (age 2.63, phonemes 4.0, freq 9.57, cc -2.28, susceptibility 0.0) [nosubs]
#
# - father (age 4.11, phonemes 4.0, freq 10.01, cc -2.36, susceptibility 0.0) [nosubs]
#
# - unhappy (age 4.89, phonemes 6.0, freq 6.99, cc -1.29, susceptibility 0.0) [nosubs]
#
# - black (age 3.56, phonemes 4.0, freq 9.90, cc -3.73, susceptibility 0.0) [nosubs]
#
# - hockey (age 5.44, phonemes 4.0, freq 8.05, cc -2.73, susceptibility 0.0) [nosubs]
#
# - smile (age 3.51, phonemes 4.0, freq 8.01, cc -2.17, susceptibility 0.0) [nosubs]
#
# - sorry (age 3.44, phonemes 4.0, freq 9.35, cc -1.76, susceptibility 0.0) [nosubs]
#
# - holiday (age 5.19, phonemes 6.0, freq 8.39, cc -2.20, susceptibility 1.0)
#
#     what are you thankful for this {holiday => year}  [age 5.24, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0]
#     what are you thankful for this {holiday => year}  [age 5.24, phonemes 3.0, freq 11.83, cc -1.69, susceptibility 0.0]
#
# - stop (age 2.89, phonemes 4.0, freq 10.41, cc -3.27, susceptibility 0.0) [nosubs]
#
# - break (age 5.3, phonemes 4.0, freq 10.05, cc -3.22, susceptibility 0.0) [nosubs]
#
# - world (age 5.32, phonemes 4.0, freq 11.89, cc -2.95, susceptibility 0.172413793103)
#
#     the {world => global} economy is entering a major downturn [age 9.78, phonemes 6.0, freq 10.33, cc -, susceptibility 0.222222222222]
#     while he is deeply saddened by the events he is thankful for all of the love and support he has been receiving from fans and friends {world => worldwide}  [age -, phonemes 7.0, freq 8.40, cc -, susceptibility 0.5]
#     not as a misconception but as a {world => world-view}  [age -, phonemes -, freq 1.61, cc -, susceptibility -]
#     the united states will lose its superpower status in the {world => global} financial system [age 9.78, phonemes 6.0, freq 10.33, cc -, susceptibility 0.222222222222]
#     the {world => global} financial system will become more multi-polar [age 9.78, phonemes 6.0, freq 10.33, cc -, susceptibility 0.222222222222]
#
# - shadow (age 5.0, phonemes 4.0, freq 7.96, cc -2.36, susceptibility 0.0) [nosubs]
#
# - lady (age 3.68, phonemes 4.0, freq 8.92, cc -2.42, susceptibility 0.0) [nosubs]
#
# - bread (age 3.58, phonemes 4.0, freq 7.57, cc -2.57, susceptibility 0.0) [nosubs]
#
# - shoulder (age 4.5, phonemes 5.0, freq 7.95, cc -2.50, susceptibility 0.0) [nosubs]
#
# - school (age 3.89, phonemes 4.0, freq 9.51, cc -3.48, susceptibility 0.111111111111)
#
#     she wanted to get people who believed in creationism on the {school => board}  [age 6.37, phonemes 4.0, freq 9.27, cc -3.50, susceptibility -]
#
# - heaven (age 4.22, phonemes 5.0, freq 9.13, cc -2.58, susceptibility 0.0) [nosubs]
#
# - button (age 4.78, phonemes 5.0, freq 7.48, cc -2.27, susceptibility 0.0) [nosubs]
#
# - drop (age 3.26, phonemes 4.0, freq 8.78, cc -2.62, susceptibility 0.0) [nosubs]
#
# - brother (age 3.63, phonemes 5.0, freq 9.26, cc -1.66, susceptibility 0.333333333333)
#
#     reduce risk associated with a potential lehman {brothers => bankruptcy}  [age 11.11, phonemes 9.5, freq 8.28, cc -, susceptibility -]
#
# - naked (age 4.68, phonemes 5.0, freq 7.72, cc -1.66, susceptibility 0.0) [nosubs]
#
# - sand (age 4.63, phonemes 4.0, freq 7.61, cc -2.30, susceptibility 1.0)
#
#     the size of a grain of {sand => rice}  [age 3.72, phonemes 3.0, freq 6.84, cc -2.19, susceptibility -]
#
# - stuff (age 5.0, phonemes 4.0, freq 9.22, cc -3.14, susceptibility 0.0) [nosubs]
#
# - truth (age 4.42, phonemes 4.0, freq 10.03, cc -2.55, susceptibility 0.5)
#
#      {truth => sweetie} we need to know the truth [age 6.55, phonemes 5.0, freq 4.32, cc -, susceptibility -]
#
# - small (age 3.22, phonemes 4.0, freq 9.99, cc -3.48, susceptibility 0.75)
#
#     they needed a {small => short} victorious war [age 4.32, phonemes 4.0, freq 9.47, cc -2.87, susceptibility -]
#     they needed a {small => short} victorious war [age 4.32, phonemes 4.0, freq 9.47, cc -2.87, susceptibility -]
#     they needed a {small => short} victorious war [age 4.32, phonemes 4.0, freq 9.47, cc -2.87, susceptibility -]
#
# - heavy (age 4.05, phonemes 4.0, freq 8.09, cc -2.68, susceptibility 0.0) [nosubs]
#
# - square (age 4.11, phonemes 5.0, freq 7.26, cc -2.49, susceptibility 0.0) [nosubs]
#
# - people (age 3.52, phonemes 5.0, freq 12.45, cc -3.70, susceptibility 0.0) [nosubs]
#
# - hard (age 4.39, phonemes 4.0, freq 10.56, cc -3.54, susceptibility 0.0) [nosubs]
#
# - playmate (age 5.21, phonemes 6.0, freq 4.19, cc -, susceptibility 1.0)
#
#     i think that ' s what set things at the very beginning what set the {centerfolds => centrefolds} centerfolds apart [age -, phonemes -, freq 3.26, cc -, susceptibility 0.0]
#     we do n't go for glamour what we are looking for is a very natural girl-next-door look i think that ' s what set things at the very beginning what set the {centerfolds => centrefolds} centerfolds apart [age -, phonemes -, freq 3.26, cc -, susceptibility 0.0]
#     we do n't go for glamour what we are looking for is a very natural girl-next-door look i think that ' s what set things at the very beginning what set the {centrefolds => centerfolds} centrefolds apart [age 10.8, phonemes 9.0, freq 2.94, cc -, susceptibility 0.0]
#     i think that ' s what set things at the very beginning what set the {centerfolds => centrefolds} centerfolds apart [age -, phonemes -, freq 3.26, cc -, susceptibility 0.0]
#     i think that ' s what set things at the very beginning what set the {centerfolds => centrefolds} centerfolds apart [age -, phonemes -, freq 3.26, cc -, susceptibility 0.0]
#
# - second (age 4.68, phonemes 5.5, freq 9.58, cc -2.40, susceptibility 0.0) [nosubs]
#
# - street (age 4.58, phonemes 5.0, freq 10.16, cc -2.39, susceptibility 0.0) [nosubs]
#
# - mirror (age 4.89, phonemes 4.0, freq 7.32, cc -2.11, susceptibility 0.0) [nosubs]
#
# - close (age 4.5, phonemes 4.0, freq 9.90, cc -2.94, susceptibility 0.0) [nosubs]
#
# - happen (age 5.26, phonemes 5.0, freq 11.18, cc -2.45, susceptibility 0.0) [nosubs]
#
# - special (age 5.0, phonemes 6.0, freq 9.28, cc -2.44, susceptibility 0.0) [nosubs]
#
# - gross (age 5.21, phonemes 4.0, freq 7.23, cc -2.84, susceptibility 0.0) [nosubs]
#
# - movie (age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8)
#
#     you look just awesome in this new {movie => video}  [age 8.06, phonemes 5.0, freq 8.75, cc -2.37, susceptibility 1.0]
#     you look just awesome in this new {movie => video}  [age 8.06, phonemes 5.0, freq 8.75, cc -2.37, susceptibility 1.0]
#     you look just awesome in this new {movie => video}  [age 8.06, phonemes 5.0, freq 8.75, cc -2.37, susceptibility 1.0]
#     you look just awesome in this new {movie => video}  [age 8.06, phonemes 5.0, freq 8.75, cc -2.37, susceptibility 1.0]
#
# - finger (age 3.43, phonemes 5.0, freq 7.96, cc -2.75, susceptibility 0.0) [nosubs]
#
# - bunch (age 4.89, phonemes 4.0, freq 8.06, cc -2.16, susceptibility 0.0) [nosubs]
#
# - body (age 4.28, phonemes 4.0, freq 9.63, cc -3.11, susceptibility 0.0) [nosubs]
#
# - little (age 3.95, phonemes 5.0, freq 10.78, cc -2.45, susceptibility 0.3)
#
#     giving them a {little => state} of their own [age 6.39, phonemes 4.0, freq 11.59, cc -2.74, susceptibility 0.0384615384615]
#     i started looking for a beach house the day i found out i had this {little => disease}  [age 7.55, phonemes 5.0, freq 8.70, cc -2.24, susceptibility 0.0]
#     i started looking for a beach house the day i found out i had this {little => disease}  [age 7.55, phonemes 5.0, freq 8.70, cc -2.24, susceptibility 0.0]
#
# - step (age 4.11, phonemes 4.0, freq 10.43, cc -2.05, susceptibility 0.0) [nosubs]
#
# - baseball (age 4.83, phonemes 6.0, freq 7.56, cc -2.51, susceptibility 0.0) [nosubs]
#
# - address (age 5.15, phonemes 5.0, freq 9.69, cc -2.20, susceptibility 0.0) [nosubs]
#
# - alone (age 4.94, phonemes 4.0, freq 9.13, cc -2.83, susceptibility 0.0) [nosubs]
#
# - strong (age 4.58, phonemes 5.0, freq 10.49, cc -3.09, susceptibility 0.0) [nosubs]
#
# - change (age 4.26, phonemes 4.0, freq 11.34, cc -3.19, susceptibility 0.0) [nosubs]
#
# - great (age 5.05, phonemes 4.0, freq 11.51, cc -2.74, susceptibility 0.230769230769)
#
#     i applaud the american people for their {great => courage}  [age 8.42, phonemes 4.0, freq 8.27, cc -1.67, susceptibility 0.0]
#      {greatest => biggest} organized crime threat to the united states [age 2.89, phonemes 3.0, freq 11.01, cc -3.67, susceptibility 0.25]
#     on the {great => tough} race that he has fought [age 5.47, phonemes 3.0, freq 9.89, cc -2.14, susceptibility 0.0]
#     the body was in {great => good} condition [age 3.55, phonemes 3.0, freq 12.25, cc -3.81, susceptibility 0.0526315789474]
#     will you appoint a special prosecutor ideally patrick fitzgerald to independently investigate the {greatest => gravest} crimes of the bush administration including torture and warrantless wiretapping [age 7.06, phonemes 4.0, freq 8.46, cc -1.61, susceptibility 0.8]
#     the {greatest => gravest} crimes of the bush administration including torture and warrantless wiretapping [age 7.06, phonemes 4.0, freq 8.46, cc -1.61, susceptibility 0.8]
#
# - bible (age 4.95, phonemes 5.0, freq 7.70, cc -1.73, susceptibility 0.0)
# [nosubs]
#
# - wolf (age 4.5, phonemes 4.0, freq 7.03, cc -2.25, susceptibility 0.0) [nosubs]
#
# - stand (age 4.39, phonemes 5.0, freq 10.51, cc -2.68, susceptibility 0.0) [nosubs]
#
# - argue (age 4.61, phonemes 5.0, freq 7.98, cc -1.85, susceptibility 0.0) [nosubs]
#
# - pillow (age 3.47, phonemes 4.0, freq 5.76, cc -2.32, susceptibility 0.0) [nosubs]
#
# - family (age 3.38, phonemes 5.5, freq 11.08, cc -2.55, susceptibility 0.2)
#
#     he should have done right by his {family => family-if} a person is unhappy in their marriage and spending all their personal time with someone else you need to do right by your marriage [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#
# - point (age 4.55, phonemes 4.0, freq 10.50, cc -3.37, susceptibility 0.0) [nosubs]
#
# - number (age 3.94, phonemes 5.0, freq 10.17, cc -3.27, susceptibility 0.0) [nosubs]
#
# - open (age 5.0, phonemes 4.0, freq 10.05, cc -3.31, susceptibility 0.0) [nosubs]
#
# - cloud (age 3.63, phonemes 4.0, freq 8.38, cc -2.34, susceptibility 1.0)
#
#     dr king and a great {cloud => crowd} of witnesses are shouting in heaven [age 7.14, phonemes 4.0, freq 8.55, cc -2.29, susceptibility 1.0]
#
# - speak (age 3.56, phonemes 4.0, freq 10.05, cc -1.97, susceptibility 0.333333333333)
#
#      {speak => directly} to the american people [age -, phonemes 7.0, freq 8.49, cc -, susceptibility -]
#
# - story (age 3.89, phonemes 5.0, freq 9.82, cc -2.55, susceptibility 1.0)
#
#     it was like a horror {story => movie}  [age 3.56, phonemes 4.0, freq 9.55, cc -3.77, susceptibility 0.8]
#     a man whose {story => history} reflects the enduring promise of our land [age 6.42, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0]
#     standing on the steps of the capitol will be a man whose {story => history} reflects the enduring promise of our land [age 6.42, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0]
#     a man whose {story => history} reflects the enduring promise of our land [age 6.42, phonemes 6.0, freq 10.42, cc -2.30, susceptibility 0.0]
#
# - silent (age 4.42, phonemes 6.0, freq 7.35, cc -2.16, susceptibility 0.0) [nosubs]
#
# - help (age 3.65, phonemes 4.0, freq 11.17, cc -3.50, susceptibility 0.214285714286)
#
#     we must resist the dangerous temptation of economic isolationism and continue the policies of open markets that have lifted standards of living and {helped => held} millions of people escape poverty around the world [age 4.67, phonemes 4.0, freq 10.13, cc -2.92, susceptibility 0.0]
#     we must resist the dangerous temptation of economic isolationism and continue the policies of open markets that have lifted standards of living and {helped => held} millions of people escape poverty around the world [age 4.67, phonemes 4.0, freq 10.13, cc -2.92, susceptibility 0.0]
#     i did n't hear a single word about health care i did n't hear a single word about {helping => education}  [age 6.7, phonemes 8.5, freq 8.94, cc -1.38, susceptibility -]
#
# - angry (age 4.45, phonemes 5.0, freq 8.49, cc -1.98, susceptibility 0.5)
#
#     i do n't know why they get {angry => hostile}  [age 9.9, phonemes 6.0, freq 7.21, cc -, susceptibility 0.0]
#
# - start (age 4.37, phonemes 5.0, freq 10.61, cc -2.11, susceptibility 0.0) [nosubs]
#
# - secret (age 5.39, phonemes 6.0, freq 8.99, cc -2.79, susceptibility 0.0) [nosubs]
#
# - music (age 3.81, phonemes 6.0, freq 9.50, cc -3.05, susceptibility 0.0) [nosubs]
#
# - bubble (age 3.79, phonemes 5.0, freq 6.89, cc -1.82, susceptibility 0.0) [nosubs]
#
# - happy (age 2.72, phonemes 4.0, freq 10.05, cc -3.21, susceptibility 1.0)
#
#     that kid from chicago who wanted to make everybody {happy => laugh}  [age 3.79, phonemes 3.0, freq 8.24, cc -2.17, susceptibility -]
#     that kid from chicago who wanted to make everybody {happy => laugh}  [age 3.79, phonemes 3.0, freq 8.24, cc -2.17, susceptibility -]
#
# - breathe (age 4.11, phonemes 4.0, freq 7.47, cc -1.92, susceptibility 0.0) [nosubs]
#
# - warm (age 4.65, phonemes 4.0, freq 8.19, cc -2.32, susceptibility 0.0) [nosubs]
#
# - grandpa (age 3.06, phonemes 6.33333333333, freq 5.60, cc -1.41, susceptibility 1.0)
#
#      {grandpa => bye} god save you yeah that ' s great [age -, phonemes 2.0, freq 5.41, cc -, susceptibility -]
#
# - stick (age 3.89, phonemes 4.0, freq 8.89, cc -3.46, susceptibility 0.0) [nosubs]
#
# - baby (age 3.84, phonemes 4.0, freq 9.82, cc -3.51, susceptibility 0.4)
#
#      {baby => i} sleep two hours wake up and cry sleep two hours wake up and cry [age -, phonemes 1.0, freq 14.24, cc -1.10, susceptibility 0.0268817204301]
#      {baby => i} sleep two hours wake up and cry [age -, phonemes 1.0, freq 14.24, cc -1.10, susceptibility 0.0268817204301]
#
# - careful (age 5.09, phonemes 6.0, freq 8.62, cc -2.56, susceptibility 1.0)
#
#      {careful => danger} of having a proper sterling collapse a run on the pound [age 4.61, phonemes 5.0, freq 8.90, cc -2.87, susceptibility -]
#      {careful => danger} of having a proper sterling collapse a run on the pound [age 4.61, phonemes 5.0, freq 8.90, cc -2.87, susceptibility -]
#
# - must (age 4.58, phonemes 4.0, freq 10.98, cc -2.43, susceptibility 0.0) [nosubs]
#
# - sound (age 3.72, phonemes 4.0, freq 9.43, cc -2.23, susceptibility 0.0) [nosubs]
#
# - kind (age 4.89, phonemes 4.0, freq 10.60, cc -2.05, susceptibility 0.545454545455)
#
#     any {kind => hint} of unethical activity [age 5.95, phonemes 4.0, freq 6.79, cc -1.52, susceptibility -]
#     any {kind => hint} of unethical activity [age 5.95, phonemes 4.0, freq 6.79, cc -1.52, susceptibility -]
#     all-out war against hamas and its {kind => branches}  [age 5.11, phonemes 5.0, freq 7.73, cc -2.26, susceptibility 1.0]
#     sometimes when you do things and people see what {kind => type} of person you really are you turn a lot of people off [age 6.58, phonemes 3.0, freq 8.84, cc -2.22, susceptibility 0.5]
#     sometimes when you do things and people see what {kind => type} of person you really are you turn a lot of people off [age 6.58, phonemes 3.0, freq 8.84, cc -2.22, susceptibility 0.5]
#     sometimes when you do things and people see what {kind => type} of person you really are you turn a lot of people off [age 6.58, phonemes 3.0, freq 8.84, cc -2.22, susceptibility 0.5]
#
# - sadness (age 5.0, phonemes 6.0, freq 7.01, cc -, susceptibility 1.0)
#
#     it would be a terrible {sadness => blow}  [age 4.0, phonemes 3.0, freq 8.95, cc -2.79, susceptibility -]
#
# ...
#     momentum has been building in the {laptop => notebook} market for some time so it ' s not a complete surprise that shipments have surpassed those of desktops [age 6.37, phonemes 6.0, freq 6.90, cc -1.18, susceptibility 1.0]
#
# - enjoin (age 13.15, phonemes 5.0, freq 4.16, cc -, susceptibility 0.0) [nosubs]
#
# - sanction (age 12.68, phonemes 6.5, freq 7.53, cc -, susceptibility 0.0) [nosubs]
#
# - autism (age 14.21, phonemes 6.0, freq 6.39, cc -, susceptibility 0.0) [nosubs]
#
# - regime (age 13.0, phonemes 5.0, freq 8.40, cc -, susceptibility 0.0) [nosubs]
#
# - opaque (age 13.95, phonemes 4.0, freq 5.52, cc 0.00, susceptibility 0.0) [nosubs]
#
# - federal (age 13.5, phonemes 6.0, freq 9.66, cc -1.91, susceptibility 0.0) [nosubs]
#
# - swagger (age 12.0, phonemes 5.0, freq 5.21, cc -, susceptibility 1.0)
#
#     he has a lot of {swagger => swag} about himself he ' s very confident when he ' s up there performing it ' s all about him [age 12.95, phonemes -, freq 4.03, cc -, susceptibility -]
#
# - turmoil (age 12.84, phonemes 5.0, freq 8.43, cc -, susceptibility 0.0) [nosubs]
#
# - buffer (age 12.37, phonemes 4.0, freq 5.70, cc -, susceptibility 0.0) [nosubs]
#
# - cholera (age 12.69, phonemes 5.0, freq 6.84, cc -, susceptibility 0.0) [nosubs]
#
# - yahoo (age 12.11, phonemes 4.0, freq 8.63, cc -, susceptibility 0.0) [nosubs]
#
# - wireless (age 14.05, phonemes 6.0, freq 6.83, cc -, susceptibility 0.0) [nosubs]
#
# - reaffirm (age 11.89, phonemes 6.0, freq 7.12, cc -, susceptibility 0.333333333333)
#
#     we {reaffirm => believe} that the risks associated with antipsychotic use in patients with dementia generally outweigh the potential benefits and in this patient group use of antipsychotic drugs should be avoided wherever possible [age 5.78, phonemes 5.0, freq 11.32, cc -2.17, susceptibility 0.333333333333]
#
# - elite (age 12.39, phonemes 4.0, freq 7.73, cc -, susceptibility 0.0) [nosubs]
#
# - affirm (age 12.24, phonemes 4.0, freq 6.83, cc -, susceptibility 1.0)
#
#     we {affirm => reaffirm} our strong and shared commitment to protect the integrity of the international financial system and facilitate liquid smooth functioning markets which are essential for supporting the health of the world economy [age 11.89, phonemes 6.0, freq 7.12, cc -, susceptibility 0.333333333333]
#     the legislature {affirms => reaffirms} that each public officer holds office as a public trust and any effort to benefit a personal or financial interest through official action is a violation of that trust [age 11.89, phonemes 6.0, freq 7.12, cc -, susceptibility 0.333333333333]
#
# - roulette (age 12.82, phonemes 5.0, freq 5.21, cc -, susceptibility 0.0) [nosubs]
#
# - reform (age 12.74, phonemes 6.0, freq 9.48, cc -, susceptibility 0.0) [nosubs]
#
# - pension (age 13.28, phonemes 6.0, freq 7.00, cc -, susceptibility 0.0) [nosubs]
#
# - deadlock (age 11.89, phonemes 6.0, freq 5.85, cc -, susceptibility 1.0)
#
#     a way out of the {deadlock => wilderness}  [age 8.95, phonemes 8.0, freq 6.07, cc -1.62, susceptibility -]
#
# - backlog (age 12.43, phonemes 6.0, freq 4.16, cc -, susceptibility 1.0)
#
#     a very low level of {backlog => radioactivity}  [age 12.06, phonemes 13.0, freq 4.97, cc -, susceptibility -]
#
#
# ================================================
# Ages [ 11.886  15.108] --- #phonemes [  7.  10.]
#
# - directive (age 13.88, phonemes 7.75, freq 4.43, cc -, susceptibility 0.0) [nosubs]
#
# - stringent (age 14.4, phonemes 9.0, freq 5.12, cc -, susceptibility 0.0) [nosubs]
#
# - negligence (age 12.16, phonemes 9.0, freq 4.77, cc -, susceptibility 0.0) [nosubs]
#
# - expletive (age 12.85, phonemes 9.0, freq 8.05, cc -, susceptibility 0.68)
#
#     maybe we ca n't do this now fire those {expletives => fuckers}  [age 10.89, phonemes 4.0, freq 2.89, cc -, susceptibility -]
#     if they do n't perform {expletive => fuck} em [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     if they do n't perform {expletive => f} em [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => f} expletive them [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     not willing to give me anything except appreciation {expletive => f} them [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => fuck} expletive them [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     they ' re not willing to give me anything except {expletive => f} expletive them [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     not willing to give me anything except appreciation {expletive => f} them [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#     they ' re not willing to give me anything except {expletive => fuck} expletive them [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     they ' re not willing to give me anything except {expletive => bleep} expletive them [age 9.47, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i do n't even celebrate that {expletive => shit} i ' m black [age 6.53, phonemes 3.0, freq 6.83, cc -2.89, susceptibility 0.5]
#     i do n't even celebrate that {expletive => shit} i ' m black [age 6.53, phonemes 3.0, freq 6.83, cc -2.89, susceptibility 0.5]
#     is a {expletive => f-ing} valuable thing you just do n't give it away for nothing [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     a {expletive => fucking} valuable thing you just do n't give it away for nothing [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     is a {expletive => fucking} valuable thing you just do n't give it away for nothing [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     is a {expletive => fucking} valuable thing you just do n't give it away for nothing [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     a {expletive => fucking} valuable thing you just do n't give it away for nothing [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     i ' ve got this thing and it {expletive => bleeping} s expletive golden [age 9.47, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i ' ve got this thing and it {expletive => fxxking} s expletive golden [age -, phonemes -, freq 14.21, cc -, susceptibility 0.175983436853]
#     i ' ve got this thing and it {expletive => bleeping} s expletive golden [age 9.47, phonemes 4.0, freq 6.64, cc -, susceptibility 0.5]
#     i would n't call mickelson a great player cause i hate the {expletive => prick}  [age 8.79, phonemes 4.0, freq 5.82, cc -1.72, susceptibility 1.0]
#     i would n't call mickelson a great player cause i hate the {expletive => p}  [age -, phonemes 2.0, freq 7.54, cc -, susceptibility 1.0]
#     i do n't know what the {expletive => fuck} i ' m going to do [age 11.22, phonemes 3.0, freq 8.37, cc -, susceptibility 0.833333333333]
#     come help a {expletive => nigger} get elected [age 8.29, phonemes 4.0, freq 5.42, cc -, susceptibility 1.0]
#      {expletive => f} you i wo n't do what you tell me [age -, phonemes 2.0, freq 8.23, cc -, susceptibility 0.818181818182]
#
# - bandwidth (age 14.94, phonemes 8.0, freq 5.61, cc -, susceptibility 0.0) [nosubs]
#
# - economic (age 12.0, phonemes 8.0, freq 10.95, cc -2.18, susceptibility 0.153846153846)
#
#     the {economic => american} recovery and reinvestment plan [age -, phonemes -, freq 11.63, cc -, susceptibility 0.133333333333]
#     global protectionism is a path to global {economic => ruin}  [age 7.16, phonemes 4.0, freq 7.93, cc -1.66, susceptibility -]
#
# - electorate (age 13.8, phonemes 8.0, freq 4.97, cc -, susceptibility 0.0) [nosubs]
#
# - dementia (age 12.32, phonemes 8.0, freq 5.93, cc -, susceptibility 0.0) [nosubs]
#
# - contempt (age 12.44, phonemes 8.0, freq 6.34, cc -, susceptibility 0.0) [nosubs]
#
# - recession (age 13.74, phonemes 7.0, freq 9.48, cc -, susceptibility 0.0) [nosubs]
#
# - terrorist (age 12.76, phonemes 7.0, freq 10.08, cc -, susceptibility 1.0)
#
#     i would join a {terrorist => terror} organization [age 8.79, phonemes 4.0, freq 8.86, cc -1.15, susceptibility 1.0]
#
# - upheaval (age 12.76, phonemes 7.0, freq 4.62, cc -, susceptibility 0.0) [nosubs]
#
# - copyright (age 12.33, phonemes 7.0, freq 7.49, cc -, susceptibility 0.0) [nosubs]
#
# - commission (age 14.72, phonemes 7.0, freq 8.55, cc 0.00, susceptibility 1.0)
#
#     i am disappointed that the {commission => sec} chose to bring this case based upon its enforcement staff ' s win-at-any-cost ambitions the staff ' s process was result-oriented facts be damned the government ' s claims are false and they will be proven to be so [age 9.61, phonemes 3.0, freq 6.99, cc -, susceptibility 0.666666666667]
#
# - partisan (age 14.05, phonemes 8.0, freq 8.06, cc -, susceptibility 0.0) [nosubs]
#
# - socialism (age 13.68, phonemes 9.0, freq 7.95, cc -, susceptibility 1.0)
#
#     this is {socialism => welfare} for the rich [age 11.11, phonemes 6.0, freq 7.97, cc -1.95, susceptibility -]
#     this is {socialism => welfare} for the rich [age 11.11, phonemes 6.0, freq 7.97, cc -1.95, susceptibility -]
#     this is {socialism => welfare} for the rich [age 11.11, phonemes 6.0, freq 7.97, cc -1.95, susceptibility -]
#     this is {socialism => welfare} for the rich [age 11.11, phonemes 6.0, freq 7.97, cc -1.95, susceptibility -]
#
# - liberation (age 13.45, phonemes 8.0, freq 6.28, cc -, susceptibility 0.0) [nosubs]
#
# - blatant (age 12.28, phonemes 7.0, freq 6.73, cc -, susceptibility 0.0) [nosubs]
#
# - discretion (age 12.67, phonemes 9.0, freq 7.65, cc -, susceptibility 0.0) [nosubs]
#
# - objective (age 12.72, phonemes 8.0, freq 8.51, cc -1.88, susceptibility 0.0) [nosubs]
#
# - terrorism (age 12.83, phonemes 8.0, freq 9.19, cc -, susceptibility 0.4)
#
#     this is clearly the kind of {terrorism => terror} in which al qaeda participates [age 8.79, phonemes 4.0, freq 8.86, cc -1.15, susceptibility 1.0]
#     this is clearly the kind of {terrorism => terror} in which al qaeda participates [age 8.79, phonemes 4.0, freq 8.86, cc -1.15, susceptibility 1.0]
#
# - reinstate (age 12.62, phonemes 8.0, freq 5.99, cc -, susceptibility 1.0)
#
#     everything must be done to {reinstate => renew} the truce [age 10.06, phonemes 4.0, freq 8.11, cc -1.79, susceptibility -]
#
# - economy (age 12.56, phonemes 7.0, freq 11.21, cc -2.01, susceptibility 0.0714285714286)
#     this will help our air our health and our travel and tourism {economy => industry}  [age 10.44, phonemes 8.0, freq 10.14, cc -1.58, susceptibility 0.142857142857]
#
# - predecessor (age 13.83, phonemes 9.0, freq 6.86, cc -, susceptibility 0.0) [nosubs]
#
# - solvent (age 12.65, phonemes 7.0, freq 5.25, cc -, susceptibility 0.0) [nosubs]
#
# - mainstream (age 13.28, phonemes 8.0, freq 7.77, cc -, susceptibility 0.5)
#
#     the filter of the {mainstream => media}  [age 7.67, phonemes 6.0, freq 9.64, cc -1.96, susceptibility 0.0]
#
# - marketing (age 12.25, phonemes 8.0, freq 7.39, cc -, susceptibility 0.0) [nosubs]
#
# - behavioral (age 11.89, phonemes 9.0, freq 5.89, cc -, susceptibility 0.0) [nosubs]
#
# - immigration (age 12.63, phonemes 9.0, freq 7.41, cc -, susceptibility 0.0) [nosubs]
#
# - warrantless (age 13.63, phonemes 9.0, freq 5.25, cc -, susceptibility 0.0) [nosubs]
#
# - franchise (age 12.58, phonemes 7.0, freq 7.79, cc -, susceptibility 0.0) [nosubs]
#
# - aftermath (age 12.05, phonemes 7.0, freq 6.30, cc -, susceptibility 0.0) [nosubs]
#
# - unethical (age 14.3, phonemes 8.0, freq 6.67, cc -, susceptibility 0.0) [nosubs]
#
# - discernible (age 12.56, phonemes 9.0, freq 5.35, cc -, susceptibility 0.0) [nosubs]
#
# - prolific (age 12.44, phonemes 8.0, freq 4.69, cc -, susceptibility 0.0) [nosubs]
#
# - judicial (age 13.15, phonemes 7.0, freq 6.98, cc -, susceptibility 0.0) [nosubs]
#
# - uncertainty (age 12.25, phonemes 9.0, freq 8.41, cc -, susceptibility 0.0) [nosubs]
#
# - coalition (age 13.94, phonemes 8.0, freq 8.21, cc -, susceptibility 0.0) [nosubs]
#
# - theology (age 12.72, phonemes 7.0, freq 5.53, cc -, susceptibility 0.0) [nosubs]
#
# - ideology (age 12.67, phonemes 8.0, freq 8.13, cc -, susceptibility 0.5)
#
#     a new declaration of independence from {ideology => divisiveness}  [age 15.12, phonemes 10.0, freq 3.43, cc -, susceptibility -]
#
# - magnitude (age 12.3, phonemes 8.0, freq 7.33, cc -2.35, susceptibility 1.0)
#
#     at a pace and {magnitude => dimension} that has never happened before [age 10.26, phonemes 8.0, freq 6.82, cc -, susceptibility -]
#
# - genocide (age 13.2, phonemes 7.0, freq 7.18, cc -, susceptibility 0.0) [nosubs]
#
# - elective (age 12.11, phonemes 7.0, freq 5.00, cc -, susceptibility 1.0)
#
#     it turns out the human body is not affected by magnetic fields it is affected by {elective => electric} fields so what we are doing is transmitting energy using the magnetic field not the electric field [age 6.36, phonemes 8.0, freq 6.96, cc -2.61, susceptibility 0.333333333333]
#
# - fraternity (age 12.95, phonemes 9.0, freq 3.74, cc -2.17, susceptibility 1.0)
#
#     messenger of peace and {fraternity => brotherhood}  [age 9.44, phonemes 8.0, freq 5.98, cc -, susceptibility -]
#     a messenger of peace and {fraternity => brotherhood}  [age 9.44, phonemes 8.0, freq 5.98, cc -, susceptibility -]
#
# - editorial (age 13.7, phonemes 9.0, freq 6.82, cc -1.36, susceptibility 0.0) [nosubs]
#
# - implement (age 12.11, phonemes 9.0, freq 8.28, cc -, susceptibility 1.0)
#
#     going forward we ' ll use jquery as one of the libraries used to {higher-level => higher} higher-level [age 4.58, phonemes 2.0, freq 10.45, cc -3.63, susceptibility 0.0]
#
# - imprudent (age 12.88, phonemes 9.0, freq 5.58, cc -, susceptibility 0.0) [nosubs]
#
# - facilitate (age 12.84, phonemes 9.0, freq 7.13, cc -, susceptibility 0.0) [nosubs]
#
#
# ================================================
# Ages [ 11.886  15.108] --- #phonemes [ 10.  13.]
#
# - unsustainable (age 13.72, phonemes 12.0, freq 6.42, cc -, susceptibility 0.0) [nosubs]
#
# - extremism (age 14.24, phonemes 11.0, freq 7.60, cc -, susceptibility 0.0) [nosubs]
#
# - homosexual (age 12.37, phonemes 12.0, freq 6.92, cc -, susceptibility 0.0) [nosubs]
#
# - impropriety (age 13.21, phonemes 11.0, freq 6.07, cc -, susceptibility 0.0) [nosubs]
#
# - credibility (age 12.37, phonemes 11.0, freq 7.40, cc -, susceptibility 0.0) [nosubs]
#
# - specification (age 12.39, phonemes 12.0, freq 5.51, cc -, susceptibility 0.0) [nosubs]
#
# - impartiality (age 12.83, phonemes 12.0, freq 6.08, cc -, susceptibility 0.0) [nosubs]
#
# - reinvestment (age 14.7, phonemes 11.5, freq 5.87, cc -, susceptibility 0.0) [nosubs]
#
# - detrimental (age 12.16, phonemes 10.5, freq 5.74, cc -, susceptibility 0.0) [nosubs]
#
# - catastrophic (age 12.11, phonemes 11.0, freq 7.88, cc -, susceptibility 0.0) [nosubs]
#
# - creationism (age 12.26, phonemes 11.0, freq 6.38, cc -, susceptibility 0.0) [nosubs]
#
# - infrastructure (age 13.41, phonemes 12.0, freq 8.44, cc -, susceptibility 0.0) [nosubs]
#
# - comprehensive (age 12.74, phonemes 12.0, freq 8.30, cc -, susceptibility 0.0) [nosubs]
#
# - ecological (age 13.39, phonemes 10.0, freq 5.16, cc -, susceptibility 0.0) [nosubs]
#
# - unqualified (age 12.17, phonemes 10.0, freq 7.21, cc -, susceptibility 0.0) [nosubs]
#
# - preliminary (age 12.28, phonemes 11.0, freq 7.07, cc -, susceptibility 0.0) [nosubs]
#
# - isolationism (age 12.35, phonemes 12.0, freq 5.42, cc -, susceptibility 0.0) [nosubs]
#
# - humanitarian (age 12.56, phonemes 12.5, freq 8.73, cc -, susceptibility 0.0) [nosubs]
#
# - diplomatic (age 12.21, phonemes 10.0, freq 7.79, cc -, susceptibility 0.0) [nosubs]
#
# - instability (age 12.55, phonemes 11.0, freq 6.65, cc -, susceptibility 1.0)
#
#     while market imbalances will feed {instability => volatility} the era of cheap oil is over [age 15.31, phonemes 10.0, freq 7.60, cc -, susceptibility 1.0]
#
# - substandard (age 13.84, phonemes 10.0, freq 4.79, cc -, susceptibility 0.0) [nosubs]
#
# - therapeutic (age 12.39, phonemes 10.0, freq 5.28, cc -, susceptibility 0.0) [nosubs]

# %% [markdown]
# ## Feature variations on substitution

# %%
nbins_variations = 5
n_pts_threshold = 10

# Build variations
for a in analyses:
    if a.feature.fullname == 'cmu MNphonemes all':
        a.set_bins(nbins_variations, truncmax=25)
    else:
        a.set_bins(nbins_variations)
    a.build_h0()
    # Force rebuild of variations in case our n_pts_threshold has changed
    try:
        del a.daughter_d
    except AttributeError:
        pass
    a.build_variations(n_pts_threshold)

# Convert to DataFrame
vdata_binned = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * len(a.bin_middles) 
                                                        for a in analyses]),
                             'disappearing bin middles': np.concatenate([a.bin_middles
                                                                         for a in analyses]),
                             'appearing bin averages': np.concatenate([a.daughter_d
                                                                       for a in analyses]),
                             'appearing H0': np.concatenate([a.daughter_d_h0
                                                             for a in analyses]),
                             'appearing H0n': np.concatenate([a.daughter_d_h0_n
                                                              for a in analyses]),
                             'ci': np.concatenate([a.daughter_d_ci for a in analyses])})
vdata_raw = pd.DataFrame({'feature': np.concatenate([[a.feature.publicname] * len(a.l2_f_mothers)
                                                     for a in analyses]),
                          'disappearing raw': np.concatenate([a.l2_f_mothers for a in analyses]),
                          'appearing raw': np.concatenate([a.l2_f_daughters for a in analyses]),
                          'appearing H0': np.concatenate([np.ones_like(a.l2_f_daughters) *
                                                          a.feature.values.mean() for a in analyses])})

# %%
with_h0n = False

def plot_variations(xvalues, avalues, h0s, h0ns, cis, **kwargs):
    color = kwargs.get('color', 'blue')
    
    plt.plot(xvalues, avalues, '-', lw=2, color=color, label=r'$\nu_{\phi}$')
    plt.plot(xvalues, h0s, linestyle='--', color=sb.desaturate(color, 0.2), 
             label=r'$\nu_{\phi}^0$')
    if with_h0n:
        plt.plot(xvalues, h0ns, linestyle='-.', color=sb.desaturate(color, 0.2), 
                 label=r'$\nu_{\phi}^{00}$')
    plt.plot(xvalues, xvalues, linestyle='dotted', color=sb.desaturate(color, 0.2), label=r'$y = x$')
    plt.fill_between(xvalues.values, avalues.values - cis.values, avalues.values + cis.values,
                     color=sb.desaturate(color, 0.2), alpha=0.2)
    xmin, xmax = xvalues.iloc[0], xvalues.iloc[-1]
    plt.xlim(xmin, xmax)
    #plt.text(xmin + (xmax - xmin) * 0.05, h0s.iloc[-1], r'$\mathcal{H}_0$', ha='left', va='center',
    #         bbox=dict(facecolor=sb.desaturate('#EAEAF2', 0.2), alpha=0.7))
    # Rescale on Y if we're touching h0, making sure the h0 line is visible
    ymin, ymax = plt.ylim()
    if ymin == h0s.min():
        ymin -= (ymax - ymin) / 10
    elif ymax == h0s.max():
        ymax += (ymax - ymin) / 10
    plt.ylim(ymin, ymax)

def plot_facetgrid():
    vg = sb.FacetGrid(vdata_binned, col='feature', col_wrap=3, 
                      col_order=translate(included_features),
                      aspect=1.5, size=3, sharex=False, sharey=False, hue='feature',
                      palette=palette_dict)#,
                      #legend=True)
    vg.map(plot_variations, 'disappearing bin middles', 'appearing bin averages', 
           'appearing H0', 'appearing H0n', 'ci')
    vg.set_titles('{col_name}')
    vg.set_xlabels(r'$f \left( \right.$ disappearing word $\left. \right)$')
    vg.set_ylabels(r'$f \left( \right.$ appearing word $\left. \right)$')
    for ax in vg.axes.ravel():
        legend = ax.legend(frameon=True, loc='upper left')
        if not legend:
            # Skip if nothing was plotted on these axes
            continue
        frame = legend.get_frame()
        frame.set_facecolor('#f2f2f2')
        frame.set_edgecolor('#000000')
    # Remove the last axis and recenter the lower row
    #vg.axes[1, 2].set_axis_off()
    pts02 = vg.axes[2].get_position().get_points()
    pts01 = vg.axes[1].get_position().get_points()
    trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
    box10 = vg.axes[3].get_position()
    box11 = vg.axes[4].get_position()
    vg.axes[2].set_xlabel('')
    vg.axes[3].set_position(TransformedBbox(box10, trans))
    vg.axes[4].set_position(TransformedBbox(box11, trans))
    
    if with_h0n:
        filename = 'data/figures_paper/feature_variations-binned-with-H00.png'
    else:
        filename = 'data/figures_paper/feature_variations-binned.png'
    vg.fig.savefig(filename, bbox_inches='tight', dpi=300)

plot_facetgrid()
with_h0n = True
plot_facetgrid()

# %%
from pprint import pprint
for a in sa.analyses:
    mothers_flist = []
    for m in set(a.mothers):
        try:
            mothers_flist.append((a.feature(m), m))
        except KeyError:
            continue
    print '========================================='
    print a.feature.fullname + ' ({} words)'.format(len(mothers_flist))
    sorted_mothers_flist = sorted(mothers_flist, reverse=True)
    pprint(sorted_mothers_flist[:20])
    print '...'
    pprint(sorted_mothers_flist[-20:])
# Out:
# =========================================
# mt frequencies all (508 words)
# [(14.240597231226223, u'i'),
#  (14.21239899132158, '<unknown>'),
#  (13.158924788515463, "n't"),
#  (12.825904232229476, u'go'),
#  (12.585980600774031, 'get'),
#  (12.377076228339964, u'know'),
#  (12.374286826252387, 'think'),
#  (12.328166376773641, 'time'),
#  (12.245269319932989, 'good'),
#  (12.206372600539172, 'just'),
#  (12.091469548505415, u'want'),
#  (12.076351128959413, 'say'),
#  (12.050061903526016, u'take'),
#  (11.940315130494184, 'see'),
#  (11.88501302202144, u'world'),
#  (11.828896115794956, 'thing'),
#  (11.814155349967278, u'right'),
#  (11.803054541065061, 'work'),
#  (11.746074791145114, 'way'),
#  (11.745385482921787, u'need')]
# ...
# [(4.3694478524670215, 'obscenity'),
#  (4.3694478524670215, 'carling'),
#  (4.3307333402863311, 'lunchtime'),
#  (4.3174881135363101, u'golfer'),
#  (4.290459441148391, u'Richardson'),
#  (4.219507705176107, u'chatty'),
#  (4.2046926193909657, u'aaah'),
#  (4.1896547420264252, 'playmate'),
#  (4.1588830833596715, 'backlog'),
#  (4.0073331852324712, u'jewellery'),
#  (3.7376696182833684, u'fraternity'),
#  (3.5835189384561099, 'well-equip'),
#  (3.5263605246161616, u'regretful'),
#  (2.9444389791664403, u'amuck'),
#  (2.8332133440562162, u'libra'),
#  (2.8332133440562162, 'gimp'),
#  (2.7080502011022101, u'decarbonisation'),
#  (2.4849066497880004, 'ancestry'),
#  (2.1972245773362196, 'plat'),
#  (1.6094379124341003, 'spirite')]
# =========================================
# cmu MNphonemes all (535 words)
# [(15.0, u'extraordinarily'),
#  (13.0, u'superconducting'),
#  (13.0, u'administrative'),
#  (13.0, u'administration'),
#  (12.0, u'unmentionable'),
#  (12.0, u'manufacturing'),
#  (12.0, u'investigating'),
#  (12.0, u'experiences'),
#  (11.5, u'fundamentals'),
#  (11.0, u'republicans'),
#  (11.0, u'patriotism'),
#  (11.0, u'intimidation'),
#  (11.0, u'institutions'),
#  (11.0, u'instability'),
#  (11.0, u'inexpensive'),
#  (11.0, u'individual'),
#  (11.0, u'disorganized'),
#  (11.0, u'development'),
#  (11.0, u'determination'),
#  (10.5, u'international')]
# ...
# [(3.0, u'allow'),
#  (3.0, u'act'),
#  (2.5, u'new'),
#  (2.0, u'way'),
#  (2.0, u'see'),
#  (2.0, u'p'),
#  (2.0, u'oil'),
#  (2.0, u'n'),
#  (2.0, u'law'),
#  (2.0, u'know'),
#  (2.0, u'j'),
#  (2.0, u'gay'),
#  (2.0, u'f'),
#  (2.0, u'eyes'),
#  (2.0, u'day'),
#  (2.0, u'd'),
#  (2.0, u'al'),
#  (2.0, u'air'),
#  (2.0, u"'s"),
#  (1.0, u'i')]
# =========================================
# fa CCs all (331 words)
# [(0.0, 'rebuild'),
#  (0.0, 'provide'),
#  (0.0, u'libra'),
#  (0.0, 'graveyard'),
#  (0.0, 'dishonor'),
#  (0.0, u'disabled'),
#  (0.0, u'commission'),
#  (-0.61090908232297325, u'booze'),
#  (-0.74193734472937733, u'inexpensive'),
#  (-0.916290731874155, u'steady'),
#  (-0.96281074750904783, 'cyclone'),
#  (-1.0163741904311376, u'spouse'),
#  (-1.0340737675305385, 'text'),
#  (-1.0498221244986778, u'purchase'),
#  (-1.0986122886681098, 'thunder'),
#  (-1.0986122886681098, 'investigate'),
#  (-1.0986122886681098, u'i'),
#  (-1.0986122886681098, u'consume'),
#  (-1.143563676530376, u'ridiculous'),
#  (-1.1451323043030026, 'terror')]
# ...
# [(-3.4019844733989726, 'time'),
#  (-3.4299467949481413, 'set'),
#  (-3.4435150313259699, 'long'),
#  (-3.4800008464920715, 'school'),
#  (-3.481382529333084, u'small'),
#  (-3.4946743803848195, 'life'),
#  (-3.5044969514999589, u'help'),
#  (-3.5095654183839371, u'television'),
#  (-3.51242301677238, 'baby'),
#  (-3.5366094074942369, 'work'),
#  (-3.5516546131540618, 'oil'),
#  (-3.5733927041546956, u'house'),
#  (-3.5818923207222255, 'bad'),
#  (-3.6109179126442243, u'use'),
#  (-3.670784791499099, u'big'),
#  (-3.6988661850035083, 'food'),
#  (-3.7679234248128766, u'movie'),
#  (-3.8059078134367281, 'money'),
#  (-3.8135563339900407, 'good'),
#  (-4.020777754153988, u'man')]
# =========================================
# aoa Kuperman all (426 words)
# [(18.33, u'marcel'),
#  (15.31, u'volatility'),
#  (14.72, u'commission'),
#  (14.5, 'plat'),
#  (14.08, u'criterion'),
#  (14.06, 'superconducting'),
#  (13.68, u'socialism'),
#  (13.53, u'commodity'),
#  (13.28, 'mainstream'),
#  (13.0, 'sector'),
#  (12.95, u'fraternity'),
#  (12.85, 'expletive'),
#  (12.84, u'casualty'),
#  (12.83, 'terrorism'),
#  (12.76, u'terrorist'),
#  (12.67, 'ideology'),
#  (12.62, 'reinstate'),
#  (12.59, u'militant'),
#  (12.56, u'economy'),
#  (12.55, u'instability')]
# ...
# [(3.55, 'good'),
#  (3.5, u'day'),
#  (3.42, 'say'),
#  (3.38, 'family'),
#  (3.37, u'go'),
#  (3.26, 'chicken'),
#  (3.26, 'arm'),
#  (3.25, 'food'),
#  (3.22, u'small'),
#  (3.17, 'get'),
#  (3.16, u'house'),
#  (3.11, u'man'),
#  (3.06, 'see'),
#  (3.06, 'grandpa'),
#  (3.05, u'fly'),
#  (2.89, u'big'),
#  (2.79, 'bad'),
#  (2.72, u'happy'),
#  (2.61, 'count'),
#  (2.22, u'mom')]
# =========================================
# wn MNSyns all (451 words)
# [(2.8622008809294686, u'fuck'),
#  (2.6390573296152584, u'goodbye'),
#  (2.1972245773362196, u'movie'),
#  (2.0794415416798357, u'mom'),
#  (2.0149030205422647, 'ancestry'),
#  (1.9095425048844386, 'shit'),
#  (1.791759469228055, u'mujahideen'),
#  (1.791759469228055, 'graveyard'),
#  (1.791759469228055, u'crap'),
#  (1.7047480922384253, 'tv'),
#  (1.6094379124341003, 'outcome'),
#  (1.6094379124341003, u'nigger'),
#  (1.6094379124341003, 'grandpa'),
#  (1.6094379124341003, u'global'),
#  (1.6094379124341003, 'definitely'),
#  (1.5581446180465499, u'attain'),
#  (1.5040773967762742, u'phony'),
#  (1.3862943611198906, 'workout'),
#  (1.3862943611198906, u'television'),
#  (1.3862943611198906, u'spouse')]
# ...
# [(-0.69314718055994529, u'boy'),
#  (-0.69314718055994529, u'bleep'),
#  (-0.69314718055994529, 'baker'),
#  (-0.69314718055994529, 'backlog'),
#  (-0.69314718055994529, 'anxiety'),
#  (-0.916290731874155, u'purchase'),
#  (-0.916290731874155, 'elect'),
#  (-0.916290731874155, 'economic'),
#  (-0.916290731874155, 'banking'),
#  (-1.0986122886681098, 'self'),
#  (-1.0986122886681098, 're-create'),
#  (-1.0986122886681098, 'party'),
#  (-1.0986122886681098, u'magnitude'),
#  (-1.0986122886681098, 'face-to-face'),
#  (-1.0986122886681098, 'challenge'),
#  (-1.2527629684953681, 'bail'),
#  (-1.6094379124341003, u'republican'),
#  (-1.791759469228055, 'thing'),
#  (-1.791759469228055, 'sector'),
#  (-1.791759469228055, 'half')]

# %%
def kdeplot(xvalues, yvalues, h0s, **kwargs):
    color = kwargs.get('color', 'blue')
    sb.kdeplot(pd.DataFrame({'X': xvalues, 'Y': yvalues}), shade=True)
    xmin, xmax = plt.xlim()
    plt.plot(xvalues, h0s, linestyle='dashed', color=sb.desaturate(color, 0.2))
    plt.xlim(xmin, xmax)

vg = sb.FacetGrid(vdata_raw, col='feature', col_wrap=3, col_order=translate(included_features),
                  aspect=1, size=4, sharex=False, sharey=False)
vg.map(kdeplot, 'disappearing raw', 'appearing raw', 'appearing H0')
vg.set_titles('{col_name}')
vg.set_xlabels(r'$f \left( \right.$ disappearing word $\left. \right)$')
vg.set_ylabels(r'$f \left( \right.$ appearing word $\left. \right)$')
# Remove the last axis and recenter the lower row
from matplotlib.transforms import Affine2D, TransformedBbox
#vg.axes[1, 2].set_axis_off()
pts02 = vg.axes[2].get_position().get_points()
pts01 = vg.axes[1].get_position().get_points()
trans = Affine2D().translate((pts02[1, 0] - pts01[1, 0]) / 2, 0)
box10 = vg.axes[3].get_position()
box11 = vg.axes[4].get_position()
vg.axes[2].set_xlabel('')
vg.axes[3].set_position(TransformedBbox(box10, trans))
vg.axes[4].set_position(TransformedBbox(box11, trans))
